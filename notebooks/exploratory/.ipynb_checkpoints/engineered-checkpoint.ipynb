# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Package Imports & Setup

# %%
# setting project path
import os
import sys

gparent = os.path.join(os.pardir, os.pardir)
sys.path.append(gparent)

# imports
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.compose import make_column_selector
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import make_scorer, plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.base import clone
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline as make_sm_pipeline

from boruta import BorutaPy

from src import classes as c
from src import functions as f
import matplotlib.pyplot as plt
import seaborn as sns

# setting style
sns.set_theme('talk')
plt.style.use('fivethirtyeight')
sns.set_palette(palette='Blues_r')

# %% [markdown]
# ## Importing the Data

# %%
path = os.path.join(gparent, 'data/processed', 'modeling.csv')
df = pd.read_csv(path, keep_default_na=False)

# %% [markdown]
# ## Preprocessing and Harness Objects

# %%
string_selector = make_column_selector(dtype_include='object')
number_selector = make_column_selector(dtype_include='number', dtype_exclude='object')

preprocessing_ss = make_column_transformer((OneHotEncoder
                                         (handle_unknown='ignore'),string_selector),
                                          (StandardScaler(), number_selector))
preprocessing_mm = make_column_transformer((OneHotEncoder
                                         (handle_unknown='ignore'),string_selector),
                                          (MinMaxScaler(), number_selector))
sm = SMOTE(random_state=2021)

# %%
# creating f1 scorer
f1 = f.f1

# %%
modeling = c.Harness(f1)

# %% [markdown]
# ## Baseline Dataframe

# %% [markdown]
# Dropping engineered features to establish the baseline score.

# %%
# dropd2 
df = df[(df['Subject Perceived Race']!='NA') &\
            (df['Officer Race']!='NA')]

# %%
df.head()
# Out:
#    Target Subject Age Group Weapon Type Officer ID  Officer YOB  \
# 0       1                NA        None       7500         1984
# 2       0                NA        None       4844         1961
# 4       0                NA        None       6973         1977
# 5       0                NA        None       7402         1973
# 6       0                NA        None       7591         1985
#
#   Officer Gender Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0              M        Black                  Asian                     Male
# 2              M        White                  White                     Male
# 4              M        White                  Black                     Male
# 5              M        White                  Black                     Male
# 6              M     Hispanic                  Other                   Female
#
#   Initial Call Type  ...             Officer Squad Frisk Flag Precinct  \
# 0                NA  ...  SOUTH PCT 1ST W - ROBERT          0    South
# 2                NA  ...                        NA          0       NA
# 4                NA  ...                        NA          0       NA
# 5                NA  ...                        NA          0       NA
# 6                NA  ...     WEST PCT 3RD W - MARY          0       NA
#
#    Weapon Flag Reported Year  Reported Month  Day of Month  Day of Week  \
# 0            1          2015              10            16            4
# 2            1          2015               3            21            5
# 4            1          2015               4             3            4
# 5            1          2015               4             5            6
# 6            1          2015               5            20            2
#
#    Reported Hour  Beat Flag
# 0             11          1
# 2             19          0
# 4              0          0
# 5             23          0
# 6             21          0
#
# [5 rows x 22 columns]

# %%
# features engineered during eda
feature_list = ['Weapon Flag', 'Reported Year', 'Reported Month',
                'Day of Month', 'Day of Week', 'Reported Hour', 'Beat Flag']

# %%
# excluding Officer ID, 'Final Call Type', and Frisk Flag
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag']

# %%
baseline_df = f.framer(df, [], excluded)

# %%
baseline_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type  Officer YOB Officer Gender  \
# 0       1                NA        None         1984              M
# 2       0                NA        None         1961              M
#
#   Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0        Black                  Asian                     Male
# 2        White                  White                     Male
#
#   Initial Call Type Call Type             Officer Squad Precinct
# 0                NA        NA  SOUTH PCT 1ST W - ROBERT    South
# 2                NA        NA                        NA       NA

# %%
X, y = f.Xy(baseline_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Baseline Logistic Regression

# %%
LR = LogisticRegression(max_iter=1000, random_state = 2021, verbose=2)

# %%
baseline = make_pipeline(preprocessing_mm, LR)

# %%
baseline.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline.predict(X_train), y_train)
# Out:
# 0.33292704161588016

# %%
# checking cross val scores
modeling.report(baseline, X_train, y_train, 'LR Baseline', 'Log Reg, min/max')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR Baseline has an average F1 of 0.3189871021729027
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s finished
# array([0.33204633, 0.32747535, 0.31859167, 0.31453744, 0.30228471])

# %% [markdown]
# ## Sub-Splitting the Training Data

# %%
f.subsplit_test(X_train, y_train, baseline)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s finished
#    Train F1   Test F1
# 0  0.340244  0.312697

# %% [markdown]
# ## Baseline Logistic Regression w/smote

# %%
baseline_smote = make_sm_pipeline(preprocessing_mm, sm, LR)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5369104579630894

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR Baseline SMOTE', 'Log Reg min/max')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR Baseline SMOTE has an average F1 of 0.5220253556914993
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# array([0.51851852, 0.52690009, 0.52131701, 0.52583979, 0.51755137])

# %%
modeling.history
# Out:
#                 Name  Accuracy             Notes
# 0        LR Baseline  0.318987  Log Reg, min/max
# 1  LR Baseline SMOTE  0.522025   Log Reg min/max

# %% [markdown]
# ## Sub-Splitting the Training Data

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s finished
#    Train F1   Test F1
# 0  0.539171  0.522962

# %% [markdown]
# ## Investigating the Data More Closely

# %%
cols = baseline_df.columns
for col in cols:
    print(f'{df[col].value_counts()}\n')
# Out:
# 0    32618
# 1    11067
# Name: Target, dtype: int64
#
# 26 - 35         14651
# 36 - 45          9360
# 18 - 25          8828
# 46 - 55          5693
# 56 and Above     2228
# 1 - 17           1853
# NA               1072
# Name: Subject Age Group, dtype: int64
#
# None                                    30763
# NA                                      10307
# Lethal Cutting Instrument                1417
# Knife/Cutting/Stabbing Instrument         575
# Handgun                                   269
# Firearm Other                              94
# Blunt Object/Striking Implement            78
# Club, Blackjack, Brass Knuckles            46
# Firearm                                    33
# Mace/Pepper Spray                          24
# Other Firearm                              18
# Firearm (unk type)                         15
# Taser/Stun Gun                             10
# Club                                        8
# None/Not Applicable                         7
# Rifle                                       6
# Fire/Incendiary Device                      6
# Shotgun                                     3
# Personal Weapons (hands, feet, etc.)        2
# Automatic Handgun                           2
# Blackjack                                   1
# Brass Knuckles                              1
# Name: Weapon Type, dtype: int64
#
# 1986    3165
# 1987    2831
# 1984    2590
# 1991    2395
# 1992    2320
# 1985    2243
# 1990    2160
# 1989    1887
# 1988    1868
# 1983    1647
# 1982    1641
# 1993    1389
# 1981    1340
# 1979    1281
# 1978    1100
# 1995    1058
# 1971    1033
# 1977     965
# 1976     964
# 1973     855
# 1994     823
# 1980     796
# 1967     694
# 1996     581
# 1968     574
# 1970     551
# 1974     522
# 1969     506
# 1975     481
# 1962     446
# 1964     420
# 1965     401
# 1972     399
# 1997     379
# 1963     253
# 1961     211
# 1958     210
# 1966     209
# 1959     171
# 1960     106
# 1954      44
# 1957      42
# 1953      32
# 1900      25
# 1955      21
# 1956      17
# 1948      11
# 1998      11
# 1952       9
# 1949       5
# 1946       2
# 1951       1
# Name: Officer YOB, dtype: int64
#
# M    38661
# F     5003
# N       21
# Name: Officer Gender, dtype: int64
#
# White           34103
# Hispanic         2603
# Multi-Racial     2533
# Asian            1915
# Black            1771
# P_Islander        432
# N_American        303
# Unknown            25
# Name: Officer Race, dtype: int64
#
# White           22389
# Black           13536
# Unknown          2470
# Hispanic         1627
# Asian            1481
# N_American       1312
# Multi-Racial      672
# Other             143
# P_Islander         55
# Name: Subject Perceived Race, dtype: int64
#
# Male              34558
# Female             8871
# Undetermined        215
# Unknown              21
# NA                   14
# Gender Diverse        6
# Name: Subject Perceived Gender, dtype: int64
#
# NA                                                12416
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW         2857
# SUSPICIOUS PERSON, VEHICLE OR INCIDENT             2737
# DISTURBANCE, MISCELLANEOUS/OTHER                   2268
# ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)     1875
#                                                   ...
# ORDER - ASSIST DV VIC W/SRVC OF COURT ORDER           1
# KNOWN KIDNAPPNG                                       1
# ALARM - ATM MACHINE, FREE STANDING                    1
# WARRANT PICKUP - FROM OTHER AGENCY                    1
# PROPERTY - FOUND GUN, SHELLCASINGS                    1
# Name: Initial Call Type, Length: 166, dtype: int64
#
# 911                              19746
# NA                               12416
# ONVIEW                            8137
# TELEPHONE OTHER, NOT 911          3062
# ALARM CALL (NOT POLICE ALARM)      317
# TEXT MESSAGE                         7
# Name: Call Type, dtype: int64
#
# TRAINING - FIELD TRAINING SQUAD      4731
# WEST PCT 1ST W - DAVID/MARY          1511
# WEST PCT 2ND W - D/M RELIEF           988
# SOUTHWEST PCT 2ND W - FRANK           936
# NORTH PCT 2ND WATCH - NORTH BEATS     865
#                                      ...
# NAVIGATION TEAM - SQUAD B               1
# DV SQUAD D - ORDER SERVICE              1
# BURG/THEFT/JUV - EAST                   1
# BURG/THEFT/JUV - NORTH                  1
# SOUTHWEST PCT OPS - BURG/THEFT          1
# Name: Officer Squad, Length: 168, dtype: int64
#
# West         10695
# North         9777
# NA            9273
# East          5685
# South         5107
# Southwest     3148
# Name: Precinct, dtype: int64

# %%
baseline_df['Officer YOB'].describe()
# Out:
# count    43685.000000
# mean      1982.946572
# std          9.035325
# min       1900.000000
# 25%       1978.000000
# 50%       1985.000000
# 75%       1990.000000
# max       1998.000000
# Name: Officer YOB, dtype: float64

# %% [markdown]
# ## Creating & Testing Officer Age Feature
# Creating `Officer Age` feature, dropping invalid ages and `Officer YOB` feature.

# %%
df['Officer Age'] = df['Reported Year'] - df['Officer YOB']
df['Officer Age'] = df['Officer Age'].apply(lambda x: np.nan if x > 100 else x)
df.dropna(subset = ['Officer Age'], inplace=True)

# %%
df.drop('Officer YOB', axis=1, inplace=True)

# %%
age_df = f.framer(df, [], excluded)

# %%
age_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None              M        Black
# 2       0                NA        None              M        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct  Officer Age
# 0  SOUTH PCT 1ST W - ROBERT    South         31.0
# 2                        NA       NA         54.0

# %%
age_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43660 entries, 0 to 46959
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    43660 non-null  int64
#  1   Subject Age Group         43660 non-null  object
#  2   Weapon Type               43660 non-null  object
#  3   Officer Gender            43660 non-null  object
#  4   Officer Race              43660 non-null  object
#  5   Subject Perceived Race    43660 non-null  object
#  6   Subject Perceived Gender  43660 non-null  object
#  7   Initial Call Type         43660 non-null  object
#  8   Call Type                 43660 non-null  object
#  9   Officer Squad             43660 non-null  object
#  10  Precinct                  43660 non-null  object
#  11  Officer Age               43660 non-null  float64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 4.3+ MB

# %%
X, y = f.Xy(age_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5399632619932505

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE', 'Log Reg mm, officer age')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE has an average F1 of 0.5238746692203137
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.52695389, 0.52906237, 0.52914988, 0.52506994, 0.50913727])

# %%
modeling.history
# Out:
#                 Name  Accuracy                    Notes
# 0        LR Baseline  0.318987         Log Reg, min/max
# 1  LR Baseline SMOTE  0.522025          Log Reg min/max
# 2           LR SMOTE  0.523875  Log Reg mm, officer age

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
#    Train F1   Test F1
# 0  0.540827  0.520472

# %% [markdown]
# ## Creating Racial Affinity Feature

# %%
df['Racial Affinity'] = [1 if df['Subject Perceived Race'][row]\
                         == df['Officer Race'][row] else 0 for row in df.index]

# %%
df.head(3)
# Out:
#    Target Subject Age Group Weapon Type Officer ID Officer Gender  \
# 0       1                NA        None       7500              M
# 2       0                NA        None       4844              M
# 4       0                NA        None       6973              M
#
#   Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0        Black                  Asian                     Male
# 2        White                  White                     Male
# 4        White                  Black                     Male
#
#   Initial Call Type Final Call Type  ... Precinct Weapon Flag  Reported Year  \
# 0                NA              NA  ...    South           1           2015
# 2                NA              NA  ...       NA           1           2015
# 4                NA              NA  ...       NA           1           2015
#
#   Reported Month  Day of Month  Day of Week  Reported Hour  Beat Flag  \
# 0             10            16            4             11          1
# 2              3            21            5             19          0
# 4              4             3            4              0          0
#
#    Officer Age  Racial Affinity
# 0         31.0                0
# 2         54.0                1
# 4         38.0                0
#
# [3 rows x 23 columns]

# %%
# excluding Officer ID, 'Final Call Type', and Frisk Flag
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age']

# %%
RA_df = f.framer(df, [], excluded)

# %%
RA_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None              M        Black
# 2       0                NA        None              M        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct  Racial Affinity
# 0  SOUTH PCT 1ST W - ROBERT    South                0
# 2                        NA       NA                1

# %%
X, y = f.Xy(RA_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5355088825459039

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE ', 'Log Reg, mm, racial affinity')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE  has an average F1 of 0.5213930960426445
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
# array([0.52923343, 0.52016044, 0.52238176, 0.52404572, 0.51114413])

# %%
modeling.history
# Out:
#                 Name  Accuracy                         Notes
# 0        LR Baseline  0.318987              Log Reg, min/max
# 3          LR SMOTE   0.521393  Log Reg, mm, racial affinity
# 1  LR Baseline SMOTE  0.522025               Log Reg min/max
# 2           LR SMOTE  0.523875       Log Reg mm, officer age

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
#    Train F1   Test F1
# 0  0.536019  0.520661

# %% [markdown]
# ## Gender Affinity Feature

# %%
df['Officer Gender'].value_counts()
# Out:
# M    38657
# F     5003
# Name: Officer Gender, dtype: int64

# %%
df['Officer Gender'] = df['Officer Gender'].apply(lambda x: 'Male' if x=='M' else 'Female')

# %%
df['Gender Affinity'] = [1 if df['Subject Perceived Gender'][row]\
                         == df['Officer Gender'][row] else 0 for row in df.index]

# %%
df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer ID Officer Gender  \
# 0       1                NA        None       7500           Male
# 2       0                NA        None       4844           Male
#
#   Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0        Black                  Asian                     Male
# 2        White                  White                     Male
#
#   Initial Call Type Final Call Type  ... Weapon Flag Reported Year  \
# 0                NA              NA  ...           1          2015
# 2                NA              NA  ...           1          2015
#
#    Reported Month Day of Month  Day of Week  Reported Hour  Beat Flag  \
# 0              10           16            4             11          1
# 2               3           21            5             19          0
#
#    Officer Age  Racial Affinity  Gender Affinity
# 0         31.0                0                1
# 2         54.0                1                1
#
# [2 rows x 24 columns]

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity']

# %%
GA_df = f.framer(df, [], excluded)

# %%
GA_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None           Male        Black
# 2       0                NA        None           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct  Gender Affinity
# 0  SOUTH PCT 1ST W - ROBERT    South                1
# 2                        NA       NA                1

# %%
X, y = f.Xy(GA_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5350903294367694

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE ', 'Log Reg, mm, gender affinity')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE  has an average F1 of 0.5221593045072792
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.52747728, 0.52113271, 0.5235381 , 0.52695127, 0.51169715])

# %%
modeling.history
# Out:
#                 Name  Accuracy                         Notes
# 0        LR Baseline  0.318987              Log Reg, min/max
# 1          LR SMOTE   0.521393  Log Reg, mm, racial affinity
# 2  LR Baseline SMOTE  0.522025               Log Reg min/max
# 4          LR SMOTE   0.522159  Log Reg, mm, gender affinity
# 3           LR SMOTE  0.523875       Log Reg mm, officer age

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
#    Train F1   Test F1
# 0  0.536358  0.518237

# %% [markdown]
# ### Weapon Type

# %%
# checking weapon types
df['Weapon Type'].unique()
# Out:
# array(['None', 'Firearm Other', 'Handgun', 'Lethal Cutting Instrument',
#        'NA', 'Club, Blackjack, Brass Knuckles',
#        'Knife/Cutting/Stabbing Instrument', 'Other Firearm',
#        'Fire/Incendiary Device', 'Blunt Object/Striking Implement',
#        'Firearm (unk type)', 'Mace/Pepper Spray', 'None/Not Applicable',
#        'Club', 'Rifle', 'Firearm', 'Taser/Stun Gun', 'Shotgun',
#        'Brass Knuckles', 'Automatic Handgun', 'Blackjack',
#        'Personal Weapons (hands, feet, etc.)'], dtype=object)

# %%
NONE= ['None', 'NA','None/Not Applicable']

GUN = ['Firearm Other', 'Handgun', 'Other Firearm',
        'Rifle', 'Firearm (unk type)', 'Firearm',
        'Shotgun', 'Automatic Handgun']

KNIFE = ['Lethal Cutting Instrument', 'Knife/Cutting/Stabbing Instrument']

OTHER = ['Club, Blackjack, Brass Knuckles',
         'Fire/Incendiary Device', 'Blunt Object/Striking Implement',
         'Mace/Pepper Spray', 'Club', 'Taser/Stun Gun',
         'Brass Knuckles','Blackjack',
         'Personal Weapons (hands, feet, etc.)']

# %%
df['Weapon Bins'] = df['Weapon Type'].copy()

# %%
df['Weapon Bins']
# Out:
# 0                                     None
# 2                                     None
# 4                                     None
# 5                                     None
# 6                                     None
#                        ...
# 46955    Knife/Cutting/Stabbing Instrument
# 46956                                   NA
# 46957                        Other Firearm
# 46958                                   NA
# 46959                                   NA
# Name: Weapon Bins, Length: 43660, dtype: object

# %%
for type in NONE:
    df['Weapon Bins'].replace(type, 'NONE', inplace=True)
for type in GUN:
    df['Weapon Bins'].replace(type, 'GUN', inplace=True)
for type in KNIFE:
    df['Weapon Bins'].replace(type, 'KNIFE', inplace=True)
for type in OTHER:
    df['Weapon Bins'].replace(type, 'OTHER', inplace=True)

# %%
df['Weapon Bins'].value_counts(normalize=True)
# Out:
# NONE     0.940289
# KNIFE    0.045602
# GUN      0.010078
# OTHER    0.004031
# Name: Weapon Bins, dtype: float64

# %% [markdown]
# ## 94% of Subjects Are Unarmed and Only 1% Have a Gun.

# %%
df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer ID Officer Gender  \
# 0       1                NA        None       7500           Male
# 2       0                NA        None       4844           Male
#
#   Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0        Black                  Asian                     Male
# 2        White                  White                     Male
#
#   Initial Call Type Final Call Type  ... Reported Year Reported Month  \
# 0                NA              NA  ...          2015             10
# 2                NA              NA  ...          2015              3
#
#    Day of Month Day of Week  Reported Hour  Beat Flag  Officer Age  \
# 0            16           4             11          1         31.0
# 2            21           5             19          0         54.0
#
#    Racial Affinity  Gender Affinity  Weapon Bins
# 0                0                1         NONE
# 2                1                1         NONE
#
# [2 rows x 25 columns]

# %%
excluded = ['Weapon Type', 'Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity']

# %%
WB_df = f.framer(df, [], excluded)

# %%
WB_df.head(2)
# Out:
#    Target Subject Age Group Officer Gender Officer Race  \
# 0       1                NA           Male        Black
# 2       0                NA           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct Weapon Bins
# 0  SOUTH PCT 1ST W - ROBERT    South        NONE
# 2                        NA       NA        NONE

# %%
X, y = f.Xy(WB_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5350340136054421

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE ', 'Log Reg, mm, Weapon Bins')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE  has an average F1 of 0.5217121278639294
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s finished
# array([0.52365522, 0.52064027, 0.52589641, 0.52511317, 0.51325557])

# %%
modeling.history
# Out:
#                 Name  Accuracy                         Notes
# 0        LR Baseline  0.318987              Log Reg, min/max
# 1          LR SMOTE   0.521393  Log Reg, mm, racial affinity
# 5          LR SMOTE   0.521712      Log Reg, mm, Weapon Bins
# 2  LR Baseline SMOTE  0.522025               Log Reg min/max
# 3          LR SMOTE   0.522159  Log Reg, mm, gender affinity
# 4           LR SMOTE  0.523875       Log Reg mm, officer age

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
#    Train F1   Test F1
# 0   0.53598  0.521229

# %% [markdown]
# ## Testing Weapon Flag
# The weapon flag (0 = no weapon) has been excluded from tests up to this point.

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Type', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins']

# %%
WF_df = f.framer(df, [], excluded)

# %%
WF_df.head(2)
# Out:
#    Target Subject Age Group Officer Gender Officer Race  \
# 0       1                NA           Male        Black
# 2       0                NA           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct  Weapon Flag
# 0  SOUTH PCT 1ST W - ROBERT    South            1
# 2                        NA       NA            1

# %%
X, y = f.Xy(WF_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5295109612141653

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE ', 'Log Reg, mm, weapon flag')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE  has an average F1 of 0.5175088402017757
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.52148022, 0.51763724, 0.51848757, 0.52458316, 0.50535602])

# %%
modeling.history
# Out:
#                 Name  Accuracy                         Notes
# 0        LR Baseline  0.318987              Log Reg, min/max
# 6          LR SMOTE   0.517509      Log Reg, mm, weapon flag
# 1          LR SMOTE   0.521393  Log Reg, mm, racial affinity
# 2          LR SMOTE   0.521712      Log Reg, mm, Weapon Bins
# 3  LR Baseline SMOTE  0.522025               Log Reg min/max
# 4          LR SMOTE   0.522159  Log Reg, mm, gender affinity
# 5           LR SMOTE  0.523875       Log Reg mm, officer age

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
#    Train F1   Test F1
# 0  0.533859  0.515598

# %% [markdown]
# ## Binarizing Initial Call Type
# 0 = no call information provided.

# %%
df['Initial Call Bin'] = df['Initial Call Type'].copy()

# %%
df['Initial Call Bin'] = df['Initial Call Bin'].replace('NA', 0)
df['Initial Call Bin'] = df['Initial Call Bin'].map(lambda x: 1 if x!=0 else 0)

# %%
df['Initial Call Bin'].value_counts()
# Out:
# 1    31268
# 0    12392
# Name: Initial Call Bin, dtype: int64

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins', 'Initial Call Type']

# %%
ICB_df = f.framer(df, [], excluded)

# %%
ICB_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None           Male        Black
# 2       0                NA        None           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Call Type  \
# 0                  Asian                     Male        NA
# 2                  White                     Male        NA
#
#               Officer Squad Precinct  Initial Call Bin
# 0  SOUTH PCT 1ST W - ROBERT    South                 0
# 2                        NA       NA                 0

# %%
X, y = f.Xy(ICB_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5099810803505928

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE ', 'Log Reg, mm, Initial Call Binary')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE  has an average F1 of 0.5039133895106931
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# array([0.50731707, 0.50972763, 0.51009033, 0.50311526, 0.48931665])

# %%
modeling.history
# Out:
#                 Name  Accuracy                             Notes
# 0        LR Baseline  0.318987                  Log Reg, min/max
# 7          LR SMOTE   0.503913  Log Reg, mm, Initial Call Binary
# 1          LR SMOTE   0.517509          Log Reg, mm, weapon flag
# 2          LR SMOTE   0.521393      Log Reg, mm, racial affinity
# 3          LR SMOTE   0.521712          Log Reg, mm, Weapon Bins
# 4  LR Baseline SMOTE  0.522025                   Log Reg min/max
# 5          LR SMOTE   0.522159      Log Reg, mm, gender affinity
# 6           LR SMOTE  0.523875           Log Reg mm, officer age

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
#    Train F1   Test F1
# 0   0.50993  0.497539

# %% [markdown]
# ## Binning Call Types

# %%
types = df['Call Type'].unique()

# %%
replace_list = [x for x in types if (x!='911') and (x!='ONVIEW')]

# %%
df['Call Type Bins'] = df['Call Type'].copy()

# %%
df['Call Type Bins'] = df['Call Type Bins'].replace(replace_list, 'OTHER')

# %%
df['Call Type Bins'].value_counts(normalize=True)
# Out:
# 911       0.452268
# OTHER     0.361361
# ONVIEW    0.186372
# Name: Call Type Bins, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43660 entries, 0 to 46959
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    43660 non-null  int64
#  1   Subject Age Group         43660 non-null  object
#  2   Weapon Type               43660 non-null  object
#  3   Officer ID                43660 non-null  object
#  4   Officer Gender            43660 non-null  object
#  5   Officer Race              43660 non-null  object
#  6   Subject Perceived Race    43660 non-null  object
#  7   Subject Perceived Gender  43660 non-null  object
#  8   Initial Call Type         43660 non-null  object
#  9   Final Call Type           43660 non-null  object
#  10  Call Type                 43660 non-null  object
#  11  Officer Squad             43660 non-null  object
#  12  Frisk Flag                43660 non-null  int64
#  13  Precinct                  43660 non-null  object
#  14  Weapon Flag               43660 non-null  int64
#  15  Reported Year             43660 non-null  int64
#  16  Reported Month            43660 non-null  int64
#  17  Day of Month              43660 non-null  int64
#  18  Day of Week               43660 non-null  int64
#  19  Reported Hour             43660 non-null  int64
#  20  Beat Flag                 43660 non-null  int64
#  21  Officer Age               43660 non-null  float64
#  22  Racial Affinity           43660 non-null  int64
#  23  Gender Affinity           43660 non-null  int64
#  24  Weapon Bins               43660 non-null  object
#  25  Initial Call Bin          43660 non-null  int64
#  26  Call Type Bins            43660 non-null  object
# dtypes: float64(1), int64(12), object(14)
# memory usage: 10.3+ MB

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins', 
            'Initial Call Bin','Call Type']

# %%
BCT_df = f.framer(df, [], excluded)

# %%
BCT_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None           Male        Black
# 2       0                NA        None           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type  \
# 0                  Asian                     Male                NA
# 2                  White                     Male                NA
#
#               Officer Squad Precinct Call Type Bins
# 0  SOUTH PCT 1ST W - ROBERT    South          OTHER
# 2                        NA       NA          OTHER

# %%
X, y = f.Xy(BCT_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5365332877823803

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE ', 'Log Reg, mm, call type bins')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE  has an average F1 of 0.5211482076394486
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.52222945, 0.52127885, 0.52327786, 0.52697185, 0.51198303])

# %%
modeling.history
# Out:
#                 Name  Accuracy                             Notes
# 0        LR Baseline  0.318987                  Log Reg, min/max
# 1          LR SMOTE   0.503913  Log Reg, mm, Initial Call Binary
# 2          LR SMOTE   0.517509          Log Reg, mm, weapon flag
# 8          LR SMOTE   0.521148       Log Reg, mm, call type bins
# 3          LR SMOTE   0.521393      Log Reg, mm, racial affinity
# 4          LR SMOTE   0.521712          Log Reg, mm, Weapon Bins
# 5  LR Baseline SMOTE  0.522025                   Log Reg min/max
# 6          LR SMOTE   0.522159      Log Reg, mm, gender affinity
# 7           LR SMOTE  0.523875           Log Reg mm, officer age

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s finished
#    Train F1   Test F1
# 0  0.536292  0.520567

# %% [markdown]
# ## Binning the Squad Data
# The squads look like they can be binned into precinct goups and a training group.

# %%
df['Officer Squad Bins'] = df['Officer Squad'].copy()

# %%
df['Officer Squad Bins'] = df['Officer Squad Bins'].map(lambda x: x[0])

# %%
df['Officer Squad Bins'].value_counts(normalize=True)
# Out:
# W    0.277119
# N    0.253275
# S    0.210009
# E    0.136395
# T    0.110330
# C    0.009345
# G    0.001306
# H    0.000710
# M    0.000412
# B    0.000206
# J    0.000206
# A    0.000183
# D    0.000183
# R    0.000160
# P    0.000115
# V    0.000023
# Z    0.000023
# Name: Officer Squad Bins, dtype: float64

# %%
proportions = df['Officer Squad Bins'].value_counts(normalize=True)
cutoff_idx = proportions.loc[proportions < .02].index
for i in cutoff_idx:
    df['Officer Squad Bins'].replace(i, 'OTHER', inplace=True)

# %%
df['Officer Squad Bins'].value_counts()
# Out:
# W        12099
# N        11058
# S         9169
# E         5955
# T         4817
# OTHER      562
# Name: Officer Squad Bins, dtype: int64

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins', 
            'Initial Call Bin','Call Type Bins', 'Officer Squad']

# %%
BSQ_df = f.framer(df, [], excluded)

# %%
BSQ_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None           Male        Black
# 2       0                NA        None           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#   Precinct Officer Squad Bins
# 0    South                  S
# 2       NA                  N

# %%
X, y = f.Xy(BSQ_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.52002822630858

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE', 'Log Reg, mm, Squad Bins')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE has an average F1 of 0.5131967423116138
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.51906467, 0.51236603, 0.51989281, 0.51051426, 0.50414594])

# %%
modeling.history
# Out:
#                 Name  Accuracy                             Notes
# 0        LR Baseline  0.318987                  Log Reg, min/max
# 1          LR SMOTE   0.503913  Log Reg, mm, Initial Call Binary
# 9           LR SMOTE  0.513197           Log Reg, mm, Squad Bins
# 2          LR SMOTE   0.517509          Log Reg, mm, weapon flag
# 3          LR SMOTE   0.521148       Log Reg, mm, call type bins
# 4          LR SMOTE   0.521393      Log Reg, mm, racial affinity
# 5          LR SMOTE   0.521712          Log Reg, mm, Weapon Bins
# 6  LR Baseline SMOTE  0.522025                   Log Reg min/max
# 7          LR SMOTE   0.522159      Log Reg, mm, gender affinity
# 8           LR SMOTE  0.523875           Log Reg mm, officer age

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s finished
#    Train F1   Test F1
# 0   0.52182  0.511318

# %% [markdown]
# ## Binning Officer Race

# %%
df['Officer Race Bins'] = df['Officer Race'].copy()

# %%
df['Officer Race Bins'].replace('White', 1, inplace=True)

# %%
df['Officer Race Bins'] = df['Officer Race Bins'].apply(lambda x: 0 if x!=1 else 1)

# %%
df['Officer Race Bins'].value_counts()
# Out:
# 1    34103
# 0     9557
# Name: Officer Race Bins, dtype: int64

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins', 
            'Initial Call Bin','Call Type Bins', 'Officer Squad Bins',
            'Officer Race']

# %%
ORB_df = f.framer(df, [], excluded)

# %%
ORB_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Subject Perceived Race  \
# 0       1                NA        None           Male                  Asian
# 2       0                NA        None           Male                  White
#
#   Subject Perceived Gender Initial Call Type Call Type  \
# 0                     Male                NA        NA
# 2                     Male                NA        NA
#
#               Officer Squad Precinct  Officer Race Bins
# 0  SOUTH PCT 1ST W - ROBERT    South                  0
# 2                        NA       NA                  1

# %%
X, y = f.Xy(ORB_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.0s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5361114661894415

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE', 'Log Reg, mm, Officer Race Bins')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE has an average F1 of 0.5225111785772603
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
# array([0.52597403, 0.52469396, 0.52419016, 0.5257754 , 0.51192235])

# %%
modeling.history
# Out:
#                  Name  Accuracy                             Notes
# 0         LR Baseline  0.318987                  Log Reg, min/max
# 1           LR SMOTE   0.503913  Log Reg, mm, Initial Call Binary
# 2            LR SMOTE  0.513197           Log Reg, mm, Squad Bins
# 3           LR SMOTE   0.517509          Log Reg, mm, weapon flag
# 4           LR SMOTE   0.521148       Log Reg, mm, call type bins
# 5           LR SMOTE   0.521393      Log Reg, mm, racial affinity
# 6           LR SMOTE   0.521712          Log Reg, mm, Weapon Bins
# 7   LR Baseline SMOTE  0.522025                   Log Reg min/max
# 8           LR SMOTE   0.522159      Log Reg, mm, gender affinity
# 10           LR SMOTE  0.522511    Log Reg, mm, Officer Race Bins
# 9            LR SMOTE  0.523875           Log Reg mm, officer age

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s finished
#    Train F1   Test F1
# 0  0.538222  0.522712

# %% [markdown]
# ## Testing on Top Features w/o Time

# %%
# Dropping Subject Age Nulls
df = df[(df['Subject Perceived Race']!='NA') &\
            (df['Officer Race']!='NA') &\
           (df['Subject Age Group']!='NA')]

# %%
# features engineered during eda
feature_list = ['Weapon Flag', 'Reported Year', 'Reported Month',
                'Day of Month', 'Day of Week', 'Reported Hour']

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag',
            'Racial Affinity', 'Weapon Bins', 'Officer Race',
            'Initial Call Bin','Call Type Bins', 'Officer Squad Bins']

# %%
df_6 = f.framer(df, [], excluded)

# %%
df_6.head(2)
# Out:
#      Target Subject Age Group Weapon Type Officer Gender  \
# 214       0            1 - 17        None           Male
# 328       0           36 - 45        None           Male
#
#     Subject Perceived Race Subject Perceived Gender Initial Call Type  \
# 214                  White                     Male                NA
# 328                  Asian                     Male                NA
#
#     Call Type Officer Squad Precinct  Officer Age  Gender Affinity  \
# 214        NA            NA       NA         27.0                1
# 328        NA            NA       NA         37.0                1
#
#      Officer Race Bins
# 214                  1
# 328                  1

# %%
df_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42589 entries, 214 to 46959
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    42589 non-null  int64
#  1   Subject Age Group         42589 non-null  object
#  2   Weapon Type               42589 non-null  object
#  3   Officer Gender            42589 non-null  object
#  4   Subject Perceived Race    42589 non-null  object
#  5   Subject Perceived Gender  42589 non-null  object
#  6   Initial Call Type         42589 non-null  object
#  7   Call Type                 42589 non-null  object
#  8   Officer Squad             42589 non-null  object
#  9   Precinct                  42589 non-null  object
#  10  Officer Age               42589 non-null  float64
#  11  Gender Affinity           42589 non-null  int64
#  12  Officer Race Bins         42589 non-null  int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 4.5+ MB

# %%
X, y = f.Xy(df_6)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.544110654851956

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train,\
                'LR SMOTE Dpd Nulls S,O Race, S Age', 'Top Features w/o Time')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE Dpd Nulls S,O Race, S Age has an average F1 of 0.5307750809943184
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s finished
# array([0.53033226, 0.53682842, 0.52004287, 0.5371179 , 0.52955394])

# %%
modeling.history
# Out:
#                                   Name  Accuracy  \
# 0                          LR Baseline  0.318987
# 1                            LR SMOTE   0.503913
# 2                             LR SMOTE  0.513197
# 3                            LR SMOTE   0.517509
# 4                            LR SMOTE   0.521148
# 5                            LR SMOTE   0.521393
# 6                            LR SMOTE   0.521712
# 7                    LR Baseline SMOTE  0.522025
# 8                            LR SMOTE   0.522159
# 9                             LR SMOTE  0.522511
# 10                            LR SMOTE  0.523875
# 11  LR SMOTE Dpd Nulls S,O Race, S Age  0.530775
#
#                                Notes
# 0                   Log Reg, min/max
# 1   Log Reg, mm, Initial Call Binary
# 2            Log Reg, mm, Squad Bins
# 3           Log Reg, mm, weapon flag
# 4        Log Reg, mm, call type bins
# 5       Log Reg, mm, racial affinity
# 6           Log Reg, mm, Weapon Bins
# 7                    Log Reg min/max
# 8       Log Reg, mm, gender affinity
# 9     Log Reg, mm, Officer Race Bins
# 10           Log Reg mm, officer age
# 11             Top Features w/o Time

# %% [markdown]
# ## Testing on Sub-Splits

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s finished
#    Train F1   Test F1
# 0  0.541705  0.536274

# %% [markdown]
# ## Testing on All Features w/o Time

# %%
# Dropping Subject Age Nulls
df = df[(df['Subject Perceived Race']!='NA') &\
            (df['Officer Race']!='NA') &\
           (df['Subject Age Group']!='NA')]

# %%
# features engineered during eda
feature_list = ['Weapon Flag', 'Reported Year', 'Reported Month',
                'Day of Month', 'Day of Week', 'Reported Hour']

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag',
           'Reported Year', 'Reported Month', 'Day of Month', 'Day of Week', 'Reported Hour']

# %%
# excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
#              'Reported Year', 'Reported Month','Day of Month',
#              'Day of Week', 'Reported Hour', 'Beat Flag',
#             'Racial Affinity', 'Weapon Bins', 
#             'Initial Call Bin','Call Type Bins', 'Officer Squad Bins']

# %%
df_7 = f.framer(df, [], excluded)

# %%
df_7.head(2)
# Out:
#      Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 214       0            1 - 17        None           Male        White
# 328       0           36 - 45        None           Male        White
#
#     Subject Perceived Race Subject Perceived Gender Initial Call Type  \
# 214                  White                     Male                NA
# 328                  Asian                     Male                NA
#
#     Call Type Officer Squad Precinct  Beat Flag  Officer Age  Racial Affinity  \
# 214        NA            NA       NA          0         27.0                1
# 328        NA            NA       NA          0         37.0                0
#
#      Gender Affinity Weapon Bins  Initial Call Bin Call Type Bins  \
# 214                1        NONE                 0          OTHER
# 328                1        NONE                 0          OTHER
#
#     Officer Squad Bins  Officer Race Bins
# 214                  N                  1
# 328                  N                  1

# %%
df_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42589 entries, 214 to 46959
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    42589 non-null  int64
#  1   Subject Age Group         42589 non-null  object
#  2   Weapon Type               42589 non-null  object
#  3   Officer Gender            42589 non-null  object
#  4   Officer Race              42589 non-null  object
#  5   Subject Perceived Race    42589 non-null  object
#  6   Subject Perceived Gender  42589 non-null  object
#  7   Initial Call Type         42589 non-null  object
#  8   Call Type                 42589 non-null  object
#  9   Officer Squad             42589 non-null  object
#  10  Precinct                  42589 non-null  object
#  11  Beat Flag                 42589 non-null  int64
#  12  Officer Age               42589 non-null  float64
#  13  Racial Affinity           42589 non-null  int64
#  14  Gender Affinity           42589 non-null  int64
#  15  Weapon Bins               42589 non-null  object
#  16  Initial Call Bin          42589 non-null  int64
#  17  Call Type Bins            42589 non-null  object
#  18  Officer Squad Bins        42589 non-null  object
#  19  Officer Race Bins         42589 non-null  int64
# dtypes: float64(1), int64(6), object(13)
# memory usage: 6.8+ MB

# %%
X, y = f.Xy(df_7)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.7s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f30a0>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ffe575f3040>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(baseline_smote.predict(X_train), y_train)
# Out:
# 0.5433360765798934

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train,\
                'LR SMOTE Dpd Nulls S,O Race, S Age', 'All Features w/o Time')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# LR SMOTE Dpd Nulls S,O Race, S Age has an average F1 of 0.5320124383913682
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s finished
# array([0.53319012, 0.5380117 , 0.52402499, 0.53377193, 0.53106345])

# %%
modeling.history
# Out:
#                                   Name  Accuracy  \
# 0                          LR Baseline  0.318987
# 1                            LR SMOTE   0.503913
# 2                             LR SMOTE  0.513197
# 3                            LR SMOTE   0.517509
# 4                            LR SMOTE   0.521148
# 5                            LR SMOTE   0.521393
# 6                            LR SMOTE   0.521712
# 7                    LR Baseline SMOTE  0.522025
# 8                            LR SMOTE   0.522159
# 9                             LR SMOTE  0.522511
# 10                            LR SMOTE  0.523875
# 11  LR SMOTE Dpd Nulls S,O Race, S Age  0.530775
# 12  LR SMOTE Dpd Nulls S,O Race, S Age  0.532012
#
#                                Notes
# 0                   Log Reg, min/max
# 1   Log Reg, mm, Initial Call Binary
# 2            Log Reg, mm, Squad Bins
# 3           Log Reg, mm, weapon flag
# 4        Log Reg, mm, call type bins
# 5       Log Reg, mm, racial affinity
# 6           Log Reg, mm, Weapon Bins
# 7                    Log Reg min/max
# 8       Log Reg, mm, gender affinity
# 9     Log Reg, mm, Officer Race Bins
# 10           Log Reg mm, officer age
# 11             Top Features w/o Time
# 12             All Features w/o Time

# %% [markdown]
# ## Testing on Sub-Splits

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s finished
#    Train F1   Test F1
# 0  0.543766  0.538435

# %% [markdown]
# ## Grid Searching Parameters

# %%
# C = np.logspace(-4, 2, 10)
# penalty = ['l1', 'l2']
# solver = ['liblinear', 'saga', 'lbfgs']

# grid_values = {'logisticregression__C':C, 
#                'logisticregression__penalty':penalty,
#                'logisticregression__solver':solver }

# grid_clf_f1 = GridSearchCV(baseline_smote, param_grid = grid_values,
#                            n_jobs=-1, scoring = 'f1', verbose=4)
# grid_clf_f1.fit(X_train, y_train)

# %%
# print('Best C:', grid_clf_f1.best_estimator_.get_params()['logisticregression__C'])
# print('Best penalty:', grid_clf_f1.best_estimator_.get_params()['logisticregression__penalty'])
# print('Best solver:', grid_clf_f1.best_estimator_.get_params()['logisticregression__solver'])

# %%
LR_tuned = LogisticRegression(C=.359381,
                            solver='saga', penalty='l2',
                            max_iter=1000, random_state=2021)

pipeline  = make_sm_pipeline(preprocessing_mm, sm, LR_tuned)
pipeline.fit(X_train, y_train)
f1_score(pipeline.predict(X_train), y_train)
modeling.report(pipeline, X_train, y_train, 'LR_tuned', 'C=4.641589, solver=lbfgs, penalty=l2')
# Out:
# LR_tuned has an average F1 of 0.5327214779510717
# array([0.53416149, 0.53902544, 0.52441385, 0.53458433, 0.53142227])

# %%
modeling.history
# Out:
#                                   Name  Accuracy  \
# 0                          LR Baseline  0.318987
# 1                            LR SMOTE   0.503913
# 2                             LR SMOTE  0.513197
# 3                            LR SMOTE   0.517509
# 4                            LR SMOTE   0.521148
# 5                            LR SMOTE   0.521393
# 6                            LR SMOTE   0.521712
# 7                    LR Baseline SMOTE  0.522025
# 8                            LR SMOTE   0.522159
# 9                             LR SMOTE  0.522511
# 10                            LR SMOTE  0.523875
# 11  LR SMOTE Dpd Nulls S,O Race, S Age  0.530775
# 12  LR SMOTE Dpd Nulls S,O Race, S Age  0.532012
# 13                            LR_tuned  0.532721
#
#                                    Notes
# 0                       Log Reg, min/max
# 1       Log Reg, mm, Initial Call Binary
# 2                Log Reg, mm, Squad Bins
# 3               Log Reg, mm, weapon flag
# 4            Log Reg, mm, call type bins
# 5           Log Reg, mm, racial affinity
# 6               Log Reg, mm, Weapon Bins
# 7                        Log Reg min/max
# 8           Log Reg, mm, gender affinity
# 9         Log Reg, mm, Officer Race Bins
# 10               Log Reg mm, officer age
# 11                 Top Features w/o Time
# 12                 All Features w/o Time
# 13  C=4.641589, solver=lbfgs, penalty=l2

# %% [markdown]
# ## Testing Tuned Model on Sub-Splits

# %%
f.subsplit_test(X_train, y_train, pipeline)
# Out:
#    Train F1   Test F1
# 0  0.543031  0.536862

# %% [markdown]
# ## Random Forest

# %%
RF = RandomForestClassifier(random_state=2021)

# %%
rf_pipeline = make_pipeline(preprocessing_mm, RF)

# %%
modeling.report(rf_pipeline, X_train, y_train, 'RandomForest', 'Forest w/o SMOTE')
# Out:
# RandomForest has an average F1 of 0.38125959589404107
# array([0.38234135, 0.37515127, 0.39467502, 0.38141414, 0.3727162 ])

# %%
# rf_pipeline.get_params().keys()

# %%
# criterion = ['gini', 'entropy']
# max_depth = [2, 3, None]
# min_samples_split = [2, 5, 10]
# class_weight = ['balanced', 'balanced_subsample']

# grid_values = {'randomforestclassifier__criterion':criterion, 
#                'randomforestclassifier__max_depth':max_depth,
#                'randomforestclassifier__min_samples_split':min_samples_split,
#               'randomforestclassifier__class_weight':class_weight}

# grid_rf_f1 = GridSearchCV(rf_pipeline, param_grid = grid_values, scoring = 'f1', verbose=2)
# grid_rf_f1.fit(X_train, y_train)

# %%
# print('Best criterion:', grid_rf_f1.best_estimator_.get_params()['randomforestclassifier__criterion'])
# print('Best max_depth:', grid_rf_f1.best_estimator_.get_params()['randomforestclassifier__max_depth'])
# print('Best min_samples_split:', grid_rf_f1.best_estimator_.get_params()['randomforestclassifier__min_samples_split'])
# print('Best class weight:', grid_rf_f1.best_estimator_.get_params()['randomforestclassifier__class_weight'])

# %%
RF = RandomForestClassifier(criterion='gini',
                            max_depth=None, min_samples_split=10,
                            class_weight='balanced_subsample',
                            random_state=2021)

# %%
rf_pipeline = make_pipeline(preprocessing_mm, RF)

# %%
modeling.report(rf_pipeline, X_train, y_train, 'RandomForest', 'criterion=gini,\
                            max_depth=None, min_samples_split=10,\
                            class_weight=balanced_subsample')
# Out:
# RandomForest has an average F1 of 0.5229196286569292
# array([0.52205472, 0.51794872, 0.53597323, 0.52622478, 0.51239669])

# %%
modeling.history
# Out:
#                                   Name  Accuracy  \
# 0                          LR Baseline  0.318987
# 1                         RandomForest  0.381260
# 2                            LR SMOTE   0.503913
# 3                             LR SMOTE  0.513197
# 4                            LR SMOTE   0.517509
# 5                            LR SMOTE   0.521148
# 6                            LR SMOTE   0.521393
# 7                            LR SMOTE   0.521712
# 8                    LR Baseline SMOTE  0.522025
# 9                            LR SMOTE   0.522159
# 10                            LR SMOTE  0.522511
# 15                        RandomForest  0.522920
# 11                            LR SMOTE  0.523875
# 12  LR SMOTE Dpd Nulls S,O Race, S Age  0.530775
# 13  LR SMOTE Dpd Nulls S,O Race, S Age  0.532012
# 14                            LR_tuned  0.532721
#
#                                                 Notes
# 0                                    Log Reg, min/max
# 1                                    Forest w/o SMOTE
# 2                    Log Reg, mm, Initial Call Binary
# 3                             Log Reg, mm, Squad Bins
# 4                            Log Reg, mm, weapon flag
# 5                         Log Reg, mm, call type bins
# 6                        Log Reg, mm, racial affinity
# 7                            Log Reg, mm, Weapon Bins
# 8                                     Log Reg min/max
# 9                        Log Reg, mm, gender affinity
# 10                     Log Reg, mm, Officer Race Bins
# 15  criterion=gini,                            max...
# 11                            Log Reg mm, officer age
# 12                              Top Features w/o Time
# 13                              All Features w/o Time
# 14               C=4.641589, solver=lbfgs, penalty=l2

# %%
f.subsplit_test( X_train, y_train, rf_pipeline)
# Out:
#    Train F1   Test F1
# 0  0.875515  0.514756

# %% [markdown]
# ## Decision Tree

# %%
DT = DecisionTreeClassifier()

# %%
dt_pipeline = make_sm_pipeline(preprocessing_mm, DT)

# %%
modeling.report(dt_pipeline, X_train, y_train, 'Tree CLF', 'Tree w/o SMOTE')

# %% [markdown]
# ## Boruta

# %%
X, y = f.Xy(df_7)

# %%
X.head()

# %%
num_cols = X.columns[X.dtypes.apply(lambda c: np.issubdtype(c, np.number))]

# %%
mm = MinMaxScaler()

X[num_cols] = mm.fit_transform(X[num_cols])

# %%
X.head(2)

# %%
X = pd.get_dummies(X)

# %%
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)

# define Boruta 
feat_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=2021)

# fit selector
feat_selector.fit(X.values, y.values)

# %%
#  get list of features
keep = X.columns[feat_selector.support_].to_list()
toss = X.columns[feat_selector.support_weak_].to_list()
print('features to keep:', keep)
print('features to toss:', toss)

# %%
#  get rankings
X.columns[feat_selector.ranking_].sort_values(ascending=False).to_list()

# %%
# call transform() on X to filter it down to selected features
X_filtered = feat_selector.transform(X.values)

# %%
boruta = pd.DataFrame(X_filtered)

# %%
X_train, X_test, y_train, y_test = f.splitter(boruta, y)

# %% [raw]
# boruta_selected = make_pipeline(preprocessing_mm, RF)

# %%
boruta_selected.fit(X_train, y_train)

# %%
#scoring the model
f1_score(boruta_selected.predict(X_train), y_train)

# %%
# checking cross val scores
modeling.report(boruta_selected, X_train, y_train, 'RF ', 'Boruta Selected')

# %%
modeling.history
