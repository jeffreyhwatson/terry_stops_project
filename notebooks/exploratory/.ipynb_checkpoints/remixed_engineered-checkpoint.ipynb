# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Package Imports & Setup

# %%
# setting project path
import os
import sys

gparent = os.path.join(os.pardir, os.pardir)
sys.path.append(gparent)

# imports
import pandas as pd
import numpy as np

from sklearn.base import clone
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import make_column_selector
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import make_scorer, plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.tree import plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline as make_sm_pipeline

import xgboost as xgb

from boruta import BorutaPy

from src import classes as c
from src import functions as f

import matplotlib.pyplot as plt
import seaborn as sns
import graphviz
import plotly
# setting style
sns.set_theme('talk')
plt.style.use('fivethirtyeight')
sns.set_palette(palette='Blues_r')

# %% [markdown]
# ## Importing the Data

# %%
path = os.path.join(gparent, 'data/processed', 'modeling_remixed.csv')
df = pd.read_csv(path, keep_default_na=False)

# %% [markdown]
# ## Preprocessing and Harness Objects

# %%
string_selector = make_column_selector(dtype_include='object')
number_selector = make_column_selector(dtype_include='number', dtype_exclude='object')

preprocessing_ss = make_column_transformer((OneHotEncoder
                                         (handle_unknown='ignore'),string_selector),
                                          (StandardScaler(), number_selector))
preprocessing_mm = make_column_transformer((OneHotEncoder
                                         (handle_unknown='ignore'),string_selector),
                                          (MinMaxScaler(), number_selector))
sm = SMOTE(random_state=2021)

# %%
# creating f1 scorer
f1 = f.f1

# %%
modeling = c.Harness(f1)

# %% [markdown]
# ## Creating the Baseline Dataframe

# %% [markdown]
# Dropping engineered features to establish the baseline score.

# %%
df.head(2)
# Out:
#    Target Remixed Subject Age Group Weapon Type Officer ID  Officer YOB  \
# 0               1                NA        None       7500         1984
# 1               0                NA        None       5670         1965
#
#   Officer Gender Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0              M        Black                  Asian                     Male
# 1              M        White                     NA                       NA
#
#   Initial Call Type  ...             Officer Squad Frisk Flag Precinct  \
# 0                NA  ...  SOUTH PCT 1ST W - ROBERT          0    South
# 1                NA  ...                        NA          0       NA
#
#    Weapon Flag Reported Year  Reported Month  Day of Month  Day of Week  \
# 0            0          2015              10            16            4
# 1            0          2015               3            19            3
#
#    Reported Hour  Beat Flag
# 0             11          1
# 1              7          0
#
# [2 rows x 22 columns]

# %% [markdown]
# ## Renaming the Target

# %%
df.rename(columns={'Target Remixed': 'Target'}, inplace=True)

# %%
df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer ID  Officer YOB  \
# 0       1                NA        None       7500         1984
# 1       0                NA        None       5670         1965
#
#   Officer Gender Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0              M        Black                  Asian                     Male
# 1              M        White                     NA                       NA
#
#   Initial Call Type  ...             Officer Squad Frisk Flag Precinct  \
# 0                NA  ...  SOUTH PCT 1ST W - ROBERT          0    South
# 1                NA  ...                        NA          0       NA
#
#    Weapon Flag Reported Year  Reported Month  Day of Month  Day of Week  \
# 0            0          2015              10            16            4
# 1            0          2015               3            19            3
#
#    Reported Hour  Beat Flag
# 0             11          1
# 1              7          0
#
# [2 rows x 22 columns]

# %% [markdown]
# ## Excluding Extraneous Features

# %%
# features engineered during eda
feature_list = ['Weapon Flag', 'Reported Year', 'Reported Month',
                'Day of Month', 'Day of Week', 'Reported Hour', 'Beat Flag']

# %%
# excluding Officer ID, 'Final Call Type', Frisk Flag & time features
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag']

# %% [markdown]
# ## Baseline Data Frame

# %%
baseline_df = f.framer(df, [], excluded)

# %%
baseline_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type  Officer YOB Officer Gender  \
# 0       1                NA        None         1984              M
# 1       0                NA        None         1965              M
#
#   Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0        Black                  Asian                     Male
# 1        White                     NA                       NA
#
#   Initial Call Type Call Type             Officer Squad Precinct
# 0                NA        NA  SOUTH PCT 1ST W - ROBERT    South
# 1                NA        NA                        NA       NA

# %%
baseline_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46960 entries, 0 to 46959
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    46960 non-null  int64
#  1   Subject Age Group         46960 non-null  object
#  2   Weapon Type               46960 non-null  object
#  3   Officer YOB               46960 non-null  int64
#  4   Officer Gender            46960 non-null  object
#  5   Officer Race              46960 non-null  object
#  6   Subject Perceived Race    46960 non-null  object
#  7   Subject Perceived Gender  46960 non-null  object
#  8   Initial Call Type         46960 non-null  object
#  9   Call Type                 46960 non-null  object
#  10  Officer Squad             46960 non-null  object
#  11  Precinct                  46960 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.3+ MB

# %%
path2 = os.path.join(gparent, 'data/processed', 'baseline_data.csv')
baseline_df.to_csv(path2, index=False, na_rep='NA')

# %% [markdown]
# ## Creating X, y & Train Test Split

# %%
X, y = f.Xy(baseline_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Baseline Logistic Regression

# %% [markdown]
# ## Creating Pipeline

# %%
# adding a random state for a future solver gridsearch 
LR = LogisticRegression(max_iter=1000, n_jobs=-1, random_state = 2021, verbose=2)

# %%
baseline = make_pipeline(preprocessing_mm, LR)

# %% [markdown]
# ## Fitting & Scoring Model

# %%
baseline.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    2.5s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %%
#scoring the model
f1_score(y_train, baseline.predict(X_train))
# Out:
# 0.884196120994762

# %% [markdown]
# ## Cross Val Scores

# %%
# checking cross val scores
modeling.report(baseline, X_train, y_train, 'LR Baseline', 'Log Reg, min/max')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR Baseline has an average F1 of 0.8810525054191466
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# array([0.88269208, 0.88256816, 0.88164422, 0.88122696, 0.8771311 ])

# %% [markdown]
# ## Sub-Splitting the Training Data

# %%
f.subsplit_test(X_train, y_train, baseline)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
#    Train F1  Test F1
# 0  0.885469  0.87456

# %% [markdown]
# ## Baseline Score: F1 = 0.87456

# %% [markdown]
# ## Baseline Coefficients & Odds

# %%
coeff = baseline[1].coef_.flatten()

# %%
features = list(baseline[0].transformers_[0][1].get_feature_names()) +\
                list(X_train.select_dtypes('number').columns)

# %%
coefficients = pd.DataFrame(coeff, features, columns=['coef'])\
                            .sort_values(by='coef', ascending=False)

# %%
top20_pos_coef = coefficients.head(20)

# %%
top20_pos_coef.plot(kind='bar', figsize=(15,7), color=['skyblue'])
plt.title('Top 20 Positive Coefficients')                                                 
plt.xlabel('Feature Name')
plt.xticks(rotation=90)
plt.legend(title='Coefficient', labels=['Value'])
plt.show()

# %%
top20_neg_coef = coefficients.tail(20)

# %%
top20_neg_coef.plot(kind='bar', figsize=(15,7), color=['skyblue'])
plt.title('Top 20 Negative Coefficients')                                                 
plt.xlabel('Feature Name')
plt.xticks(rotation=90)
plt.legend(title='Coefficient', labels=['Value'])
plt.show()

# %%
odds = np.exp(coeff)
odds_df = pd.DataFrame(odds, 
             features, 
             columns=['odds'])\
            .sort_values(by='odds', ascending=False)

# %%
top20_pos_odds = odds_df.head(20).reset_index()

# %%
fig, ax = plt.subplots(figsize =(20, 8))
sns.barplot(x='index',y='odds', data=top20_pos_odds, palette='Blues_r', edgecolor='deepskyblue')
plt.title('Relative Odds For The Top 20 Positive Features')                                                 
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=90)
plt.legend(title='Odds That A Major Outcome Is More Likely', labels=['Multiple'])
# plt.savefig('Baseline_Positive',  bbox_inches ="tight",\
#             pad_inches = .25, transparent = False)
plt.show()

# %%
top20_neg_odds = odds_df.tail(20).reset_index()

# %%
top20_neg_odds['odds'] = 1/top20_neg_odds['odds']

# %%
fig, ax = plt.subplots(figsize =(20, 8))
sns.barplot(x='index',y='odds', data=top20_neg_odds, palette='Blues', edgecolor='deepskyblue')
plt.title('Relative Odds For Top 20 Negative Features')                                                 
plt.xlabel('')
plt.xticks(rotation=90)
plt.legend(title='Odds That A Minor Outcome Is More Likely', labels=['Multiple'])
# plt.savefig('Baseline_Negative',  bbox_inches ="tight",\
#             pad_inches = .25, transparent = False)
plt.show()

# %%
baseline_df.columns
# Out:
# Index(['Target', 'Subject Age Group', 'Weapon Type', 'Officer YOB',
#        'Officer Gender', 'Officer Race', 'Subject Perceived Race',
#        'Subject Perceived Gender', 'Initial Call Type', 'Call Type',
#        'Officer Squad', 'Precinct'],
#       dtype='object')

# %%
features
# Out:
# ['x0_1 - 17',
#  'x0_18 - 25',
#  'x0_26 - 35',
#  'x0_36 - 45',
#  'x0_46 - 55',
#  'x0_56 and Above',
#  'x0_NA',
#  'x1_Automatic Handgun',
#  'x1_Blackjack',
#  'x1_Blunt Object/Striking Implement',
#  'x1_Brass Knuckles',
#  'x1_Club',
#  'x1_Club, Blackjack, Brass Knuckles',
#  'x1_Fire/Incendiary Device',
#  'x1_Firearm',
#  'x1_Firearm (unk type)',
#  'x1_Firearm Other',
#  'x1_Handgun',
#  'x1_Knife/Cutting/Stabbing Instrument',
#  'x1_Lethal Cutting Instrument',
#  'x1_Mace/Pepper Spray',
#  'x1_NA',
#  'x1_None',
#  'x1_None/Not Applicable',
#  'x1_Other Firearm',
#  'x1_Personal Weapons (hands, feet, etc.)',
#  'x1_Rifle',
#  'x1_Shotgun',
#  'x1_Taser/Stun Gun',
#  'x2_F',
#  'x2_M',
#  'x2_N',
#  'x3_Asian',
#  'x3_Black',
#  'x3_Hispanic',
#  'x3_Multi-Racial',
#  'x3_NA',
#  'x3_N_American',
#  'x3_P_Islander',
#  'x3_Unknown',
#  'x3_White',
#  'x4_Asian',
#  'x4_Black',
#  'x4_Hispanic',
#  'x4_Multi-Racial',
#  'x4_NA',
#  'x4_N_American',
#  'x4_Other',
#  'x4_P_Islander',
#  'x4_Unknown',
#  'x4_White',
#  'x5_Female',
#  'x5_Gender Diverse',
#  'x5_Male',
#  'x5_NA',
#  'x5_Undetermined',
#  'x5_Unknown',
#  'x6_-ASSIGNED DUTY - FOOT BEAT (FROM ASSIGNED CAR)',
#  'x6_-ASSIGNED DUTY - STAKEOUT',
#  'x6_ALARM - AUDIBLE AUTOMOBILE (UNOCC/ANTI-THEFT)',
#  'x6_ALARM - BANK (HOLD-UP)',
#  'x6_ALARM - COMM, HOLD-UP/PANIC (EXCEPT BANKS)',
#  'x6_ALARM - COMM, SILENT/AUD BURG (INCL BANKS)',
#  'x6_ALARM - RESIDENTIAL - BURGLARY, SILENT/AUDIBLE',
#  'x6_ALARM - RESIDENTIAL - SILENT/AUD PANIC/DURESS',
#  'x6_ANIMAL - INJURED, DEAD HAZARD, OTHER',
#  'x6_ANIMAL - IP/JO - BITE',
#  'x6_ANIMAL, REPORT - BITE',
#  'x6_ARSON - IP/JO',
#  'x6_ARSON - REPORT',
#  'x6_ASLT - DV',
#  'x6_ASLT - IP/JO - DV',
#  'x6_ASLT - IP/JO - PERSON SHOT OR SHOT AT',
#  'x6_ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)',
#  'x6_ASLT - MOLESTED ADULT (GROPED, FONDLED, ETC.)',
#  'x6_ASLT - PERSON SHOT OR SHOT AT',
#  'x6_ASLT - WITH OR W/O WEAPONS (NO SHOOTINGS)',
#  'x6_ASSIST OTHER AGENCY - EMERGENCY SERVICE',
#  'x6_ASSIST OTHER AGENCY - ROUTINE SERVICE',
#  'x6_ASSIST PUBLIC - NO WELFARE CHK OR DV ORDER SERVICE',
#  'x6_ASSIST SPD - ROUTINE SERVICE',
#  'x6_ASSIST SPD - URGENT SERVICE',
#  'x6_AUTO - THEFT/LOSS, PLATES AND/OR TAB',
#  'x6_AUTO RECOVERY',
#  'x6_AUTO THEFT - VEH THEFT OR THEFT & RECOVERY',
#  'x6_AUTO THEFT-IP/JO - VEHICLE, PLATES, TABS',
#  'x6_BIAS -RACIAL, POLITICAL, SEXUAL MOTIVATION',
#  'x6_BOMB THREATS - IP/JO',
#  'x6_BURG - COMM BURGLARY (INCLUDES SCHOOLS)',
#  'x6_BURG - IP/JO - COMM BURG (INCLUDES SCHOOLS)',
#  'x6_BURG - IP/JO - RES (INCL UNOCC STRUCTURES)',
#  'x6_BURG - RES (INCL UNOCC STRUCTURES ON PROP)',
#  'x6_BURN - RECKLESS BURNING',
#  'x6_CARJACKING - IP/JO - ROBBERY',
#  'x6_CARJACKING - ROBBERY',
#  'x6_CHILD -  LURING',
#  'x6_CHILD - ABAND, ABUSED, MOLESTED, NEGLECTED',
#  'x6_CHILD - IP/JO - ABAND, ABUSE, MOLEST, NEGLECT',
#  'x6_CHILD - IP/JO - LURING',
#  'x6_DEMONSTRATIONS',
#  'x6_DIRECTED PATROL ACTIVITY',
#  'x6_DIST - DV - NO ASLT',
#  'x6_DIST - IP/JO - DV DIST - NO ASLT',
#  'x6_DISTURBANCE, MISCELLANEOUS/OTHER',
#  'x6_DOA - CASUALTY, DEAD BODY',
#  'x6_DOWN - CHECK FOR DOWN PERSON',
#  'x6_DOWN - CHECK FOR PERSON DOWN',
#  'x6_DUI - DRIVING UNDER INFLUENCE',
#  'x6_ESCAPE - PRISONER',
#  'x6_EXPLOSION - IP/JO',
#  'x6_FIGHT - IP - PHYSICAL (NO WEAPONS)',
#  'x6_FIGHT - IP/JO - WITH WEAPONS',
#  'x6_FIGHT - JO - PHYSICAL (NO WEAPONS)',
#  'x6_FIGHT - VERBAL/ORAL (NO WEAPONS)',
#  'x6_FIGHT - WITH WEAPONS',
#  'x6_FIREWORKS - NUISANCE (NO HAZARD)',
#  'x6_FOLLOW UP',
#  'x6_FOOT - ELUDING POLICE',
#  'x6_FOUND - PERSON',
#  'x6_FRAUD - FORGERY,BUNCO, SCAMS, ID THEFT, ETC',
#  'x6_GAMBLING',
#  'x6_HARAS - NO BIAS, THREATS OR MALICIOUSNESS',
#  'x6_HARBOR - WATER EMERGENCIES',
#  'x6_HAZ - IMMINENT THRT TO PHYS SAFETY (NO HAZ MAT)',
#  'x6_HAZ - POTENTIAL THRT TO PHYS SAFETY (NO HAZMAT)',
#  'x6_HELP THE OFFICER',
#  'x6_ILLEGAL DUMPING',
#  'x6_INJURED -  PERSON/INDUSTRIAL ACCIDENT',
#  'x6_INJURED - IP/JO - PERSON/INDUSTRIAL ACCIDENT',
#  'x6_JUVENILE - RUNAWAY',
#  'x6_JUVENILE - RUNAWAY PICKUP',
#  'x6_LEWD -  (EXPOSING, FLASHING)',
#  'x6_LIQUOR VIOLATIONS - ADULT',
#  'x6_LIQUOR VIOLATIONS - MINOR',
#  'x6_LITTERING',
#  'x6_MISSING - (ALZHEIMER, ENDANGERED, ELDERLY)',
#  'x6_MISSING - ADULT',
#  'x6_MISSING - CHILD',
#  'x6_MVC - HIT AND RUN (NON INJURY), INCLUDES IP/JO',
#  'x6_MVC - NON INJURY, BLOCKING',
#  'x6_MVC - REPORT, NON INJ/NON BLKG OR AFTER FACT INJ',
#  'x6_MVC - UNK INJURIES',
#  'x6_MVC - WITH INJURIES (INCLUDES HIT AND RUN)',
#  'x6_NA',
#  'x6_NARCOTICS - FOUND',
#  'x6_NARCOTICS - VIOLATIONS (LOITER, USE, SELL, NARS)',
#  'x6_NARCOTICS WARRANT SERVICE',
#  'x6_NARCOTICS WARRANT SERVICE - EXECUTED, SECURED',
#  'x6_NOISE - DIST, GENERAL (CONST, RESID, BALL PLAY)',
#  'x6_NOISE - DISTURBANCE (PARTY, ETC)',
#  'x6_NUISANCE - MISCHIEF',
#  'x6_OFF DUTY EMPLOYMENT',
#  'x6_OPEN - BUILDING, DOOR, ETC.',
#  'x6_ORDER  - SERVICE OF DV COURT ORDER',
#  'x6_ORDER - ASSIST DV VIC W/SRVC OF COURT ORDER',
#  'x6_ORDER - IP - VIOLATION OF DV COURT ORDER',
#  'x6_ORDER - VIOLATING DV COURT ORDER',
#  'x6_ORDER - VIOLATION OF COURT ORDER (NON DV)',
#  'x6_OVERDOSE - DRUG RELATED CASUALTY',
#  'x6_PANHANDLING, AGGRESSIVE',
#  'x6_PARKING VIOLATION (EXCEPT ABANDONED CAR)',
#  'x6_PARKS VIOLATIONS/CITES (INCLUDES EXCLUSIONS)',
#  'x6_PEACE-STANDBY TO ASSURE (NO COURT ORDR SVC)',
#  'x6_PEDESTRIAN VIOLATIONS',
#  'x6_PERSON IN BEHAVIORAL/EMOTIONAL CRISIS',
#  'x6_PHONE - OBSCENE OR NUISANCE PHONE CALLS',
#  'x6_PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY',
#  'x6_PROPERTY - DAMAGE',
#  'x6_PROPERTY - DAMAGE (GUN RELATED)',
#  'x6_PROPERTY - FOUND',
#  'x6_PROWLER',
#  'x6_PROWLER - IP/JO',
#  'x6_PURSE SNATCH - IP/JO - ROBBERY',
#  'x6_PURSE SNATCH - ROBBERY',
#  'x6_RAPE',
#  'x6_RAPE - IP/JO',
#  'x6_REQUEST TO WATCH',
#  'x6_ROBBERY (INCLUDES STRONG ARM)',
#  'x6_ROBBERY - IP/JO (INCLUDES STRONG ARM)',
#  'x6_SERVICE - WELFARE CHECK',
#  'x6_SEX IN PUBLIC PLACE/VIEW (INCL MASTURBATION)',
#  'x6_SFD - ASSIST ON FIRE OR MEDIC RESPONSE',
#  'x6_SHOPLIFT - THEFT',
#  'x6_SHOTS - IP/JO - INCLUDES HEARD/NO ASSAULT',
#  'x6_SHOTS -DELAY/INCLUDES HEARD/NO ASSAULT',
#  'x6_SICK PERSON',
#  'x6_SLEEPER ABOARD BUS/COMMUTER TRAIN',
#  'x6_SUICIDE - IP/JO SUICIDAL PERSON AND ATTEMPTS',
#  'x6_SUICIDE, SUICIDAL PERSON AND ATTEMPTS',
#  'x6_SUSPICIOUS PACKAGE',
#  'x6_SUSPICIOUS PERSON, VEHICLE OR INCIDENT',
#  'x6_SUSPICIOUS STOP - OFFICER INITIATED ONVIEW',
#  'x6_THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)',
#  'x6_THEFT OF SERVICES',
#  'x6_THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)',
#  'x6_THREATS - DV - NO ASSAULT',
#  'x6_TRACKING ALARM',
#  'x6_TRAF - ELUDING POLICE',
#  'x6_TRAFFIC - ASSIST MOTORIST',
#  'x6_TRAFFIC - BLOCKING ROADWAY',
#  'x6_TRAFFIC - MOVING VIOLATION',
#  'x6_TRAFFIC - ROAD RAGE',
#  'x6_TRAFFIC STOP - OFFICER INITIATED ONVIEW',
#  'x6_TRESPASS',
#  'x6_TRU - THEFT',
#  'x6_UNDERCOVER OPS, CAUTION (INCLUDES STAKEOUTS)',
#  'x6_UNKNOWN - ANI/ALI - LANDLINE (INCLUDES OPEN LINE)',
#  'x6_UNKNOWN - ANI/ALI - WRLS PHNS (INCL OPEN LINE)',
#  'x6_UNKNOWN - COMPLAINT OF UNKNOWN NATURE',
#  'x6_VICE - PORNOGRAPHY',
#  'x6_VICE - PROSTITUTION',
#  'x6_WARRANT - FELONY PICKUP',
#  'x6_WARRANT - MISD WARRANT PICKUP',
#  'x6_WARRANT - SEARCH. CAUTION (EXCL NARCOTICS)',
#  'x6_WARRANT - SEARCH. EXECUTED, SECURED',
#  'x6_WARRANT PICKUP - FROM OTHER AGENCY',
#  'x6_WEAPN - GUN,DEADLY WPN (NO THRTS/ASLT/DIST)',
#  'x6_WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/DIST)',
#  'x7_911',
#  'x7_ALARM CALL (NOT POLICE ALARM)',
#  'x7_NA',
#  'x7_ONVIEW',
#  'x7_TELEPHONE OTHER, NOT 911',
#  'x7_TEXT MESSAGE',
#  'x8_AUTO THEFT',
#  'x8_BURG/THEFT/JUV - EAST',
#  'x8_BURG/THEFT/JUV - NORTH',
#  'x8_BURG/THEFT/JUV - SOUTH',
#  'x8_BURG/THEFT/JUV - WEST',
#  'x8_CANINE - NIGHT SQUAD',
#  'x8_CANINE - SQUAD A',
#  'x8_CANINE - SQUAD C',
#  'x8_CCI - MAJOR CRIMES TASK FORCE',
#  'x8_COMMUNITY OUTREACH - YOUTH VIOLENCE -SCHOOLS DETAIL',
#  'x8_COMMUNITY OUTREACH - YOUTH VIOLENCE-SCHOOLS DETAIL',
#  'x8_COMMUNITY OUTREACH UNIT',
#  'x8_CRG - SQUAD 81A',
#  'x8_CRG - SQUAD 81B',
#  'x8_CRG - SQUAD 81C',
#  'x8_CRG - SQUAD 81D',
#  'x8_CRG - SQUAD 81E',
#  'x8_CRG - SQUAD 82A',
#  'x8_CRG - SQUAD 82B',
#  'x8_CRG - SQUAD 82C',
#  'x8_CRG - SQUAD 82D',
#  'x8_CRG - SQUAD 82E',
#  'x8_CRISIS INTERVENTION COORDINATION SQUAD',
#  'x8_CRISIS RESPONSE SQUAD',
#  'x8_DV SQUAD A - INVESTIGATIONS',
#  'x8_DV SQUAD C - ELDER ABUSE',
#  'x8_DV SQUAD D - ORDER SERVICE',
#  'x8_EAST PCT 1ST W - E/G RELIEF (CHARLIE)',
#  'x8_EAST PCT 1ST W - EDWARD (CHARLIE)',
#  'x8_EAST PCT 1ST W - GEORGE (CHARLIE)',
#  'x8_EAST PCT 2ND W - BEATS',
#  'x8_EAST PCT 2ND W - CHARLIE',
#  'x8_EAST PCT 2ND W - CHARLIE RELIEF',
#  'x8_EAST PCT 2ND W - E/G RELIEF',
#  'x8_EAST PCT 2ND W - EDWARD',
#  'x8_EAST PCT 2ND W - GEORGE',
#  'x8_EAST PCT 3RD W - CHARLIE',
#  'x8_EAST PCT 3RD W - E/G RELIEF',
#  'x8_EAST PCT 3RD W - EAST BEATS',
#  'x8_EAST PCT 3RD W - EDWARD',
#  'x8_EAST PCT 3RD W - GEORGE',
#  'x8_EAST PCT 3RD WATCH - CHARLIE RELIEF',
#  'x8_EAST PCT OPS - BURG/THEFT',
#  'x8_EAST PCT OPS - CPT',
#  'x8_EAST PCT OPS - NIGHT ACT',
#  'x8_GANG SQUAD A',
#  'x8_GANG SQUAD B',
#  'x8_GANG SQUAD C',
#  'x8_HARBOR - SQUAD A',
#  'x8_HARBOR - SQUAD D',
#  'x8_HR - DEPARTMENT UNAVAILABLE PERSONNEL',
#  'x8_HR - HUMAN RESOURCES  - DEPT UNAVAIL PERSONNEL',
#  'x8_JOINT ENFORCEMENT TEAM',
#  'x8_JOINT ENFORCEMENT TEAM (JET)',
#  'x8_MAJOR CRIMES TASK FORCE',
#  'x8_NA',
#  'x8_NARC - PROACTIVE SQUAD C',
#  'x8_NAVIGATION TEAM - SQUAD A',
#  'x8_NAVIGATION TEAM - SQUAD B',
#  'x8_NORTH PCT 1ST W - B/N RELIEF (JOHN)',
#  'x8_NORTH PCT 1ST W - BOY (JOHN)',
#  'x8_NORTH PCT 1ST W - L/U RELIEF',
#  'x8_NORTH PCT 1ST W - LINCOLN',
#  'x8_NORTH PCT 1ST W - NORA (JOHN)',
#  'x8_NORTH PCT 1ST W - UNION',
#  'x8_NORTH PCT 2ND W - BOY',
#  'x8_NORTH PCT 2ND W - JOHN',
#  'x8_NORTH PCT 2ND W - JOHN RELIEF',
#  'x8_NORTH PCT 2ND W - L/U RELIEF',
#  'x8_NORTH PCT 2ND W - LINCOLN',
#  'x8_NORTH PCT 2ND W - NORA',
#  'x8_NORTH PCT 2ND W - UNION',
#  'x8_NORTH PCT 2ND WATCH - B/N RELIEF',
#  'x8_NORTH PCT 2ND WATCH - NORTH BEATS',
#  'x8_NORTH PCT 3RD W - B/N RELIEF',
#  'x8_NORTH PCT 3RD W - BOY',
#  'x8_NORTH PCT 3RD W - JOHN',
#  'x8_NORTH PCT 3RD W - JOHN RELIEF',
#  'x8_NORTH PCT 3RD W - L/U RELIEF',
#  'x8_NORTH PCT 3RD W - LINCOLN',
#  'x8_NORTH PCT 3RD W - NORA',
#  'x8_NORTH PCT 3RD W - UNION',
#  'x8_NORTH PCT OPS - ACT DAY',
#  'x8_NORTH PCT OPS - CPT',
#  'x8_OPS BUREAU - SPECIAL ASSIGNMENTS',
#  'x8_PAWN DETAIL',
#  'x8_PUBLIC AFFAIRS SQUAD',
#  'x8_RECORDS - DAY SHIFT',
#  'x8_ROBBERY SQUAD A',
#  'x8_ROBBERY SQUAD B',
#  'x8_SAU SQUAD A',
#  'x8_SAU SQUAD B',
#  'x8_SOUTH PCT 1ST W - OCEAN',
#  'x8_SOUTH PCT 1ST W - R/S RELIEF',
#  'x8_SOUTH PCT 1ST W - ROBERT',
#  'x8_SOUTH PCT 1ST W - SAM',
#  'x8_SOUTH PCT 2ND W - OCEAN',
#  'x8_SOUTH PCT 2ND W - OCEAN RELIEF',
#  'x8_SOUTH PCT 2ND W - R/S RELIEF',
#  'x8_SOUTH PCT 2ND W - ROBERT',
#  'x8_SOUTH PCT 2ND W - SAM',
#  'x8_SOUTH PCT 2ND W - SAM BEATS',
#  'x8_SOUTH PCT 3RD W - OCEAN',
#  'x8_SOUTH PCT 3RD W - OCEAN RELIEF',
#  'x8_SOUTH PCT 3RD W - R/S RELIEF',
#  'x8_SOUTH PCT 3RD W - ROBERT',
#  'x8_SOUTH PCT 3RD W - SAM',
#  'x8_SOUTH PCT OPS - BURG/THEFT',
#  'x8_SOUTH PCT OPS - CPT',
#  'x8_SOUTH PCT OPS - DAY ACT',
#  'x8_SOUTH PCT OPS - NIGHT ACT',
#  'x8_SOUTHWEST PCT - 1ST WATCH - F/W RELIEF',
#  'x8_SOUTHWEST PCT - 3RD WATCH - F/W RELIEF',
#  'x8_SOUTHWEST PCT 1ST W - FRANK',
#  'x8_SOUTHWEST PCT 1ST W - WILLIAM',
#  'x8_SOUTHWEST PCT 2ND W - FRANK',
#  'x8_SOUTHWEST PCT 2ND W - SOUTHWEST BEATS',
#  'x8_SOUTHWEST PCT 2ND W - WILLIAM',
#  'x8_SOUTHWEST PCT 2ND WATCH - F/W RELIEF',
#  'x8_SOUTHWEST PCT 3RD W - FRANK',
#  'x8_SOUTHWEST PCT 3RD W - WILLIAM',
#  'x8_SOUTHWEST PCT OPS - CPT',
#  'x8_SOUTHWEST PCT OPS - DAY ACT',
#  'x8_SOUTHWEST PCT OPS - NIGHT ACT',
#  'x8_SWAT - DAY SQUAD 1',
#  'x8_SWAT - DAY SQUAD 2',
#  'x8_SWAT - NIGHT SQUAD 1',
#  'x8_SWAT - NIGHT SQUAD 2',
#  'x8_TRAF - AM ENFORCEMENT',
#  'x8_TRAF - COLLISION INVESTIGATION',
#  'x8_TRAF - DUI SQUAD',
#  'x8_TRAF - MOTORCYCLE UNIT - T2 SQUAD',
#  'x8_TRAF - MOTORCYCLE UNIT - T4 SQUAD',
#  'x8_TRAF - PM ENFORCEMENT',
#  'x8_TRAINING - ADVANCED - SQUAD C',
#  'x8_TRAINING - FIELD TRAINING SQUAD',
#  'x8_TRAINING - LEARNING MANAGEMENT SYSTEM',
#  'x8_WEST PCT 1ST W - DAVID/MARY',
#  'x8_WEST PCT 1ST W - KING/QUEEN',
#  'x8_WEST PCT 1ST W - KQ/DM RELIEF',
#  'x8_WEST PCT 2ND W - D/M RELIEF',
#  'x8_WEST PCT 2ND W - DAVID',
#  'x8_WEST PCT 2ND W - DAVID BEATS',
#  'x8_WEST PCT 2ND W - K/Q RELIEF',
#  'x8_WEST PCT 2ND W - KING',
#  'x8_WEST PCT 2ND W - KING BEATS',
#  'x8_WEST PCT 2ND W - MARY',
#  'x8_WEST PCT 2ND W - MARY BEATS',
#  'x8_WEST PCT 2ND W - QUEEN',
#  'x8_WEST PCT 2ND W - SPECIAL BEATS',
#  'x8_WEST PCT 3RD W - D/M RELIEF',
#  'x8_WEST PCT 3RD W - DAVID',
#  'x8_WEST PCT 3RD W - DAVID BEATS',
#  'x8_WEST PCT 3RD W - K/Q RELIEF',
#  'x8_WEST PCT 3RD W - KING',
#  'x8_WEST PCT 3RD W - MARY',
#  'x8_WEST PCT 3RD W - QUEEN',
#  'x8_WEST PCT OPS - ACT NIGHT',
#  'x8_WEST PCT OPS - BURG/THEFT',
#  'x8_WEST PCT OPS - COMMERCIAL SEC',
#  'x8_WEST PCT OPS - CPT',
#  'x8_WEST PCT OPS - MOUNTED PATROL',
#  'x8_WEST PCT OPS - SEA CTR',
#  'x9_East',
#  'x9_NA',
#  'x9_North',
#  'x9_South',
#  'x9_Southwest',
#  'x9_West',
#  'Officer YOB']

# %% [markdown]
# ## Baseline Logistic Regression w/smote

# %% [markdown]
# ## Pipeline

# %%
baseline_smote = make_sm_pipeline(preprocessing_mm, sm, LR)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.5s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, baseline_smote.predict(X_train))
# Out:
# 0.8780940291949422

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR Baseline SMOTE', 'Log Reg min/max')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR Baseline SMOTE has an average F1 of 0.874411465797958
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.87512148, 0.87985393, 0.87170732, 0.87409231, 0.8712823 ])

# %%
modeling.history
# Out:
#                 Name  Accuracy (F1)             Notes
# 1  LR Baseline SMOTE       0.874411   Log Reg min/max
# 0        LR Baseline       0.881053  Log Reg, min/max

# %% [markdown]
# ## Sub-Splitting the Training Data

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.4s finished
#    Train F1   Test F1
# 0  0.878957  0.868125

# %% [markdown]
# ## Baseline LR w/SMOTE Score: F1 = 0.868125

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## Dropping Subject and Officer Race Nulls

# %%
df = df[(df['Subject Perceived Race']!='NA') &\
            (df['Officer Race']!='NA')]

# %%
# features engineered during eda
feature_list = ['Weapon Flag', 'Reported Year', 'Reported Month',
                'Day of Month', 'Day of Week', 'Reported Hour', 'Beat Flag']

# %%
# excluding Officer ID, 'Final Call Type', Frisk Flag & time features
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag']

# %% [markdown]
# ## Creating New Data Frame w/Dropped Nulls

# %%
dropped_df = f.framer(df, [], excluded)

# %%
dropped_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type  Officer YOB Officer Gender  \
# 0       1                NA        None         1984              M
# 2       0                NA        None         1961              M
#
#   Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0        Black                  Asian                     Male
# 2        White                  White                     Male
#
#   Initial Call Type Call Type             Officer Squad Precinct
# 0                NA        NA  SOUTH PCT 1ST W - ROBERT    South
# 2                NA        NA                        NA       NA

# %% [markdown]
# ## New Test Train Split

# %%
X, y = f.Xy(dropped_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Baseline Logistic Regression w/o SMOTE on Dropped Nulls Data

# %% [markdown]
# ## Pipeline

# %%
baseline_nosmote = make_pipeline(preprocessing_mm, LR)

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train,baseline_nosmote.predict(X_train))
# Out:
# 0.8906098741529526

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train, 'LR w/o SMOTE', 'LR, Dropped Nulls')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE has an average F1 of 0.8872296084439542
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# array([0.88241826, 0.88584247, 0.88847445, 0.89044173, 0.88897113])

# %%
modeling.history
# Out:
#                 Name  Accuracy (F1)              Notes
# 0  LR Baseline SMOTE       0.874411    Log Reg min/max
# 1        LR Baseline       0.881053   Log Reg, min/max
# 2       LR w/o SMOTE       0.887230  LR, Dropped Nulls

# %% [markdown]
# ## Subsplit Test

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
#    Train F1   Test F1
# 0  0.890398  0.890325

# %% [markdown]
# ## LR No SMOTE on Dropped Nulls Score: 0.890325

# %% [markdown]
# ## Baseline Logistic Regression w/SMOTE on Dropped Nulls Data

# %% [markdown]
# ## Pipeline

# %%
baseline_smote = make_sm_pipeline(preprocessing_mm, sm, LR)

# %%
baseline_smote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.5s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train,baseline_smote.predict(X_train))
# Out:
# 0.8834931436230541

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR SMOTE', 'LR, Dropped Nulls')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR SMOTE has an average F1 of 0.8784407446482632
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.87348088, 0.8761165 , 0.88023797, 0.8808384 , 0.88152997])

# %%
modeling.history
# Out:
#                 Name  Accuracy (F1)              Notes
# 0  LR Baseline SMOTE       0.874411    Log Reg min/max
# 3           LR SMOTE       0.878441  LR, Dropped Nulls
# 1        LR Baseline       0.881053   Log Reg, min/max
# 2       LR w/o SMOTE       0.887230  LR, Dropped Nulls

# %% [markdown]
# ## Sub-Splitting the Training Data

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
#    Train F1   Test F1
# 0  0.883259  0.879422

# %% [markdown]
# ## LR w/SMOTE on Dropped Nulls Data Score: F1=0.879422

# %% [markdown]
# ## Investigating the Data More Closely
# Looking for some score improvement through feature engineering

# %%
cols = baseline_df.columns
for col in cols:
    print(f'{df[col].value_counts()}\n')
# Out:
# 1    26357
# 0    17328
# Name: Target, dtype: int64
#
# 26 - 35         14651
# 36 - 45          9360
# 18 - 25          8828
# 46 - 55          5693
# 56 and Above     2228
# 1 - 17           1853
# NA               1072
# Name: Subject Age Group, dtype: int64
#
# None                                    30763
# NA                                      10307
# Lethal Cutting Instrument                1417
# Knife/Cutting/Stabbing Instrument         575
# Handgun                                   269
# Firearm Other                              94
# Blunt Object/Striking Implement            78
# Club, Blackjack, Brass Knuckles            46
# Firearm                                    33
# Mace/Pepper Spray                          24
# Other Firearm                              18
# Firearm (unk type)                         15
# Taser/Stun Gun                             10
# Club                                        8
# None/Not Applicable                         7
# Fire/Incendiary Device                      6
# Rifle                                       6
# Shotgun                                     3
# Automatic Handgun                           2
# Personal Weapons (hands, feet, etc.)        2
# Brass Knuckles                              1
# Blackjack                                   1
# Name: Weapon Type, dtype: int64
#
# 1986    3165
# 1987    2831
# 1984    2590
# 1991    2395
# 1992    2320
# 1985    2243
# 1990    2160
# 1989    1887
# 1988    1868
# 1983    1647
# 1982    1641
# 1993    1389
# 1981    1340
# 1979    1281
# 1978    1100
# 1995    1058
# 1971    1033
# 1977     965
# 1976     964
# 1973     855
# 1994     823
# 1980     796
# 1967     694
# 1996     581
# 1968     574
# 1970     551
# 1974     522
# 1969     506
# 1975     481
# 1962     446
# 1964     420
# 1965     401
# 1972     399
# 1997     379
# 1963     253
# 1961     211
# 1958     210
# 1966     209
# 1959     171
# 1960     106
# 1954      44
# 1957      42
# 1953      32
# 1900      25
# 1955      21
# 1956      17
# 1948      11
# 1998      11
# 1952       9
# 1949       5
# 1946       2
# 1951       1
# Name: Officer YOB, dtype: int64
#
# M    38661
# F     5003
# N       21
# Name: Officer Gender, dtype: int64
#
# White           34103
# Hispanic         2603
# Multi-Racial     2533
# Asian            1915
# Black            1771
# P_Islander        432
# N_American        303
# Unknown            25
# Name: Officer Race, dtype: int64
#
# White           22389
# Black           13536
# Unknown          2470
# Hispanic         1627
# Asian            1481
# N_American       1312
# Multi-Racial      672
# Other             143
# P_Islander         55
# Name: Subject Perceived Race, dtype: int64
#
# Male              34558
# Female             8871
# Undetermined        215
# Unknown              21
# NA                   14
# Gender Diverse        6
# Name: Subject Perceived Gender, dtype: int64
#
# NA                                                12416
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW         2857
# SUSPICIOUS PERSON, VEHICLE OR INCIDENT             2737
# DISTURBANCE, MISCELLANEOUS/OTHER                   2268
# ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)     1875
#                                                   ...
# ALARM - RESIDENTIAL - SILENT/AUD PANIC/DURESS         1
# PROPERTY - FOUND GUN, SHELLCASINGS                    1
# WARRANT PICKUP - FROM OTHER AGENCY                    1
# KNOWN KIDNAPPNG                                       1
# -ASSIGNED DUTY - STAKEOUT                             1
# Name: Initial Call Type, Length: 166, dtype: int64
#
# 911                              19746
# NA                               12416
# ONVIEW                            8137
# TELEPHONE OTHER, NOT 911          3062
# ALARM CALL (NOT POLICE ALARM)      317
# TEXT MESSAGE                         7
# Name: Call Type, dtype: int64
#
# TRAINING - FIELD TRAINING SQUAD        4731
# WEST PCT 1ST W - DAVID/MARY            1511
# WEST PCT 2ND W - D/M RELIEF             988
# SOUTHWEST PCT 2ND W - FRANK             936
# NORTH PCT 2ND WATCH - NORTH BEATS       865
#                                        ...
# ZOLD CRIME ANALYSIS UNIT - ANALYSTS       1
# RECORDS - DAY SHIFT                       1
# ROBBERY SQUAD B                           1
# BURG/THEFT/JUV - NORTH                    1
# TRAF - MOTORCYCLE UNIT - T2 SQUAD         1
# Name: Officer Squad, Length: 168, dtype: int64
#
# West         10695
# North         9777
# NA            9273
# East          5685
# South         5107
# Southwest     3148
# Name: Precinct, dtype: int64

# %%
baseline_df['Officer YOB'].describe()
# Out:
# count    46960.000000
# mean      1982.972764
# std          9.079240
# min       1900.000000
# 25%       1978.000000
# 50%       1985.000000
# 75%       1990.000000
# max       1998.000000
# Name: Officer YOB, dtype: float64

# %% [markdown]
# ## Creating & Testing Officer Age Feature
# Creating `Officer Age` feature, dropping invalid ages and `Officer YOB` feature.

# %%
df['Officer Age'] = df['Reported Year'] - df['Officer YOB']
df['Officer Age'] = df['Officer Age'].apply(lambda x: np.nan if x > 100 else x)
df.dropna(subset = ['Officer Age'], inplace=True)

# %%
df.drop('Officer YOB', axis=1, inplace=True)

# %% [markdown]
# ## New Data Frame

# %%
age_df = f.framer(df, [], excluded)

# %%
age_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None              M        Black
# 2       0                NA        None              M        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct  Officer Age
# 0  SOUTH PCT 1ST W - ROBERT    South         31.0
# 2                        NA       NA         54.0

# %%
age_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43660 entries, 0 to 46959
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    43660 non-null  int64
#  1   Subject Age Group         43660 non-null  object
#  2   Weapon Type               43660 non-null  object
#  3   Officer Gender            43660 non-null  object
#  4   Officer Race              43660 non-null  object
#  5   Subject Perceived Race    43660 non-null  object
#  6   Subject Perceived Gender  43660 non-null  object
#  7   Initial Call Type         43660 non-null  object
#  8   Call Type                 43660 non-null  object
#  9   Officer Squad             43660 non-null  object
#  10  Precinct                  43660 non-null  object
#  11  Officer Age               43660 non-null  float64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 4.3+ MB

# %% [markdown]
# ## New Test Train Split

# %%
X, y = f.Xy(age_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Baseline LR on New Data

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, baseline_nosmote.predict(X_train))
# Out:
# 0.8891812720321731

# %%
# checking cross val scores
modeling.report(baseline_smote, X_train, y_train, 'LR w/o SMOTE', 'Dropped Nulls, officer age')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE has an average F1 of 0.8787473513717463
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.87301382, 0.88128149, 0.88231528, 0.87708494, 0.88004123])

# %%
modeling.history
# Out:
#                 Name  Accuracy (F1)                       Notes
# 0  LR Baseline SMOTE       0.874411             Log Reg min/max
# 1           LR SMOTE       0.878441           LR, Dropped Nulls
# 4       LR w/o SMOTE       0.878747  Dropped Nulls, officer age
# 2        LR Baseline       0.881053            Log Reg, min/max
# 3       LR w/o SMOTE       0.887230           LR, Dropped Nulls

# %% [markdown]
# ## Subsplit Test

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
#    Train F1   Test F1
# 0  0.884127  0.878195

# %% [markdown]
# ## LR w/Officer Age Score: F1=0.878195

# %% [markdown]
# ## Creating Racial Affinity Feature
# 0 if subject and officer are different races; 1 if subject and officer are different races.

# %%
df['Racial Affinity'] = [1 if df['Subject Perceived Race'][row]\
                         == df['Officer Race'][row] else 0 for row in df.index]

# %%
df.head(3)
# Out:
#    Target Subject Age Group Weapon Type Officer ID Officer Gender  \
# 0       1                NA        None       7500              M
# 2       0                NA        None       4844              M
# 4       0                NA        None       6973              M
#
#   Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0        Black                  Asian                     Male
# 2        White                  White                     Male
# 4        White                  Black                     Male
#
#   Initial Call Type Final Call Type  ... Precinct Weapon Flag  Reported Year  \
# 0                NA              NA  ...    South           0           2015
# 2                NA              NA  ...       NA           0           2015
# 4                NA              NA  ...       NA           0           2015
#
#   Reported Month  Day of Month  Day of Week  Reported Hour  Beat Flag  \
# 0             10            16            4             11          1
# 2              3            21            5             19          0
# 4              4             3            4              0          0
#
#    Officer Age  Racial Affinity
# 0         31.0                0
# 2         54.0                1
# 4         38.0                0
#
# [3 rows x 23 columns]

# %% [markdown]
# ## New Data Frame

# %%
# excluding Officer ID, 'Final Call Type', and Frisk Flag
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age']

# %%
RA_df = f.framer(df, [], excluded)

# %%
RA_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None              M        Black
# 2       0                NA        None              M        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct  Racial Affinity
# 0  SOUTH PCT 1ST W - ROBERT    South                0
# 2                        NA       NA                1

# %%
X, y = f.Xy(RA_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Racial Affinity Feature

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train,baseline_nosmote.predict(X_train))
# Out:
# 0.889241920270069

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train, 'LR w/o SMOTE ', 'Dropped Nulls, racial affinity')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE  has an average F1 of 0.8856132891331248
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# array([0.88053591, 0.88836341, 0.88949253, 0.88436725, 0.88530735])

# %%
modeling.history
# Out:
#                 Name  Accuracy (F1)                           Notes
# 0  LR Baseline SMOTE       0.874411                 Log Reg min/max
# 1           LR SMOTE       0.878441               LR, Dropped Nulls
# 2       LR w/o SMOTE       0.878747      Dropped Nulls, officer age
# 3        LR Baseline       0.881053                Log Reg, min/max
# 5      LR w/o SMOTE        0.885613  Dropped Nulls, racial affinity
# 4       LR w/o SMOTE       0.887230               LR, Dropped Nulls

# %% [markdown]
# ## Subsplit Test

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
#    Train F1   Test F1
# 0  0.890482  0.884281

# %% [markdown]
# ## LR w/Racial Affinity Score: F1=0.884281

# %% [markdown]
# ## Gender Affinity Feature
# 0 if subject and officer are different genders; 1 if the same.

# %%
df['Officer Gender'].value_counts()
# Out:
# M    38657
# F     5003
# Name: Officer Gender, dtype: int64

# %%
df['Officer Gender'] = df['Officer Gender'].apply(lambda x: 'Male' if x=='M' else 'Female')

# %%
df['Gender Affinity'] = [1 if df['Subject Perceived Gender'][row]\
                         == df['Officer Gender'][row] else 0 for row in df.index]

# %%
df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer ID Officer Gender  \
# 0       1                NA        None       7500           Male
# 2       0                NA        None       4844           Male
#
#   Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0        Black                  Asian                     Male
# 2        White                  White                     Male
#
#   Initial Call Type Final Call Type  ... Weapon Flag Reported Year  \
# 0                NA              NA  ...           0          2015
# 2                NA              NA  ...           0          2015
#
#    Reported Month Day of Month  Day of Week  Reported Hour  Beat Flag  \
# 0              10           16            4             11          1
# 2               3           21            5             19          0
#
#    Officer Age  Racial Affinity  Gender Affinity
# 0         31.0                0                1
# 2         54.0                1                1
#
# [2 rows x 24 columns]

# %% [markdown]
# ## New Data Frame

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity']

# %%
GA_df = f.framer(df, [], excluded)

# %%
GA_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None           Male        Black
# 2       0                NA        None           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct  Gender Affinity
# 0  SOUTH PCT 1ST W - ROBERT    South                1
# 2                        NA       NA                1

# %%
X, y = f.Xy(GA_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Gender Affinity

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train,baseline_nosmote.predict(X_train))
# Out:
# 0.8890709568498933

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train, 'LR w/o SMOTE ', 'Dropped Nulls, gender affinity')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE  has an average F1 of 0.885576773725723
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# array([0.88065436, 0.88803185, 0.88930072, 0.88428625, 0.8856107 ])

# %%
modeling.history
# Out:
#                 Name  Accuracy (F1)                           Notes
# 0  LR Baseline SMOTE       0.874411                 Log Reg min/max
# 1           LR SMOTE       0.878441               LR, Dropped Nulls
# 2       LR w/o SMOTE       0.878747      Dropped Nulls, officer age
# 3        LR Baseline       0.881053                Log Reg, min/max
# 6      LR w/o SMOTE        0.885577  Dropped Nulls, gender affinity
# 4      LR w/o SMOTE        0.885613  Dropped Nulls, racial affinity
# 5       LR w/o SMOTE       0.887230               LR, Dropped Nulls

# %% [markdown]
# ## Subsplit Test

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
#    Train F1   Test F1
# 0  0.890519  0.884676

# %% [markdown]
# ## LR w/Gender Affinity Score: F1=0.884676

# %% [markdown]
# ## Binning Weapon Type
# Binning into NONE, GUN, KNIFE, OTHER

# %%
# checking weapon types
df['Weapon Type'].unique()
# Out:
# array(['None', 'Firearm Other', 'Handgun', 'Lethal Cutting Instrument',
#        'NA', 'Club, Blackjack, Brass Knuckles',
#        'Knife/Cutting/Stabbing Instrument', 'Other Firearm',
#        'Fire/Incendiary Device', 'Blunt Object/Striking Implement',
#        'Firearm (unk type)', 'Mace/Pepper Spray', 'None/Not Applicable',
#        'Club', 'Rifle', 'Firearm', 'Taser/Stun Gun', 'Shotgun',
#        'Brass Knuckles', 'Automatic Handgun', 'Blackjack',
#        'Personal Weapons (hands, feet, etc.)'], dtype=object)

# %%
NONE= ['None', 'NA','None/Not Applicable']

GUN = ['Firearm Other', 'Handgun', 'Other Firearm',
        'Rifle', 'Firearm (unk type)', 'Firearm',
        'Shotgun', 'Automatic Handgun']

KNIFE = ['Lethal Cutting Instrument', 'Knife/Cutting/Stabbing Instrument']

OTHER = ['Club, Blackjack, Brass Knuckles',
         'Fire/Incendiary Device', 'Blunt Object/Striking Implement',
         'Mace/Pepper Spray', 'Club', 'Taser/Stun Gun',
         'Brass Knuckles','Blackjack',
         'Personal Weapons (hands, feet, etc.)']

# %%
df['Weapon Bins'] = df['Weapon Type'].copy()

# %%
df['Weapon Bins']
# Out:
# 0                                     None
# 2                                     None
# 4                                     None
# 5                                     None
# 6                                     None
#                        ...
# 46955    Knife/Cutting/Stabbing Instrument
# 46956                                   NA
# 46957                        Other Firearm
# 46958                                   NA
# 46959                                   NA
# Name: Weapon Bins, Length: 43660, dtype: object

# %%
for type in NONE:
    df['Weapon Bins'].replace(type, 'NONE', inplace=True)
for type in GUN:
    df['Weapon Bins'].replace(type, 'GUN', inplace=True)
for type in KNIFE:
    df['Weapon Bins'].replace(type, 'KNIFE', inplace=True)
for type in OTHER:
    df['Weapon Bins'].replace(type, 'OTHER', inplace=True)

# %%
df['Weapon Bins'].value_counts(normalize=True)
# Out:
# NONE     0.940289
# KNIFE    0.045602
# GUN      0.010078
# OTHER    0.004031
# Name: Weapon Bins, dtype: float64

# %% [markdown]
# ## 94% of Subjects Are Unarmed and Only 1% Have a Gun.

# %%
df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer ID Officer Gender  \
# 0       1                NA        None       7500           Male
# 2       0                NA        None       4844           Male
#
#   Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0        Black                  Asian                     Male
# 2        White                  White                     Male
#
#   Initial Call Type Final Call Type  ... Reported Year Reported Month  \
# 0                NA              NA  ...          2015             10
# 2                NA              NA  ...          2015              3
#
#    Day of Month Day of Week  Reported Hour  Beat Flag  Officer Age  \
# 0            16           4             11          1         31.0
# 2            21           5             19          0         54.0
#
#    Racial Affinity  Gender Affinity  Weapon Bins
# 0                0                1         NONE
# 2                1                1         NONE
#
# [2 rows x 25 columns]

# %% [markdown]
# ## New Data Frame w/Weapons Bins

# %%
excluded = ['Weapon Type', 'Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity']

# %%
WB_df = f.framer(df, [], excluded)

# %%
WB_df.head(2)
# Out:
#    Target Subject Age Group Officer Gender Officer Race  \
# 0       1                NA           Male        Black
# 2       0                NA           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct Weapon Bins
# 0  SOUTH PCT 1ST W - ROBERT    South        NONE
# 2                        NA       NA        NONE

# %%
X, y = f.Xy(WB_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Weapon Bins

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train,baseline_nosmote.predict(X_train))
# Out:
# 0.8753161234909577

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train, 'LR w/o SMOTE ', 'Dropped Nulls, weapon bins')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE  has an average F1 of 0.8732731002854633
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# array([0.87071429, 0.87295718, 0.87626533, 0.87315212, 0.87327659])

# %%
modeling.history
# Out:
#                 Name  Accuracy (F1)                           Notes
# 7      LR w/o SMOTE        0.873273      Dropped Nulls, weapon bins
# 0  LR Baseline SMOTE       0.874411                 Log Reg min/max
# 1           LR SMOTE       0.878441               LR, Dropped Nulls
# 2       LR w/o SMOTE       0.878747      Dropped Nulls, officer age
# 3        LR Baseline       0.881053                Log Reg, min/max
# 4      LR w/o SMOTE        0.885577  Dropped Nulls, gender affinity
# 5      LR w/o SMOTE        0.885613  Dropped Nulls, racial affinity
# 6       LR w/o SMOTE       0.887230               LR, Dropped Nulls

# %% [markdown]
# ## Subsplit Test

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
#    Train F1   Test F1
# 0  0.874478  0.875523

# %% [markdown]
# ## LR w/Weapon Bins Score: F1=0.875523

# %% [markdown]
# ## Testing Weapon Flag
# The weapon flag binary (0 = no weapon) has been excluded from tests up to this point.

# %% [markdown]
# ## New Data Frame

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Type', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins']

# %%
WF_df = f.framer(df, [], excluded)

# %%
WF_df.head(2)
# Out:
#    Target Subject Age Group Officer Gender Officer Race  \
# 0       1                NA           Male        Black
# 2       0                NA           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#               Officer Squad Precinct  Weapon Flag
# 0  SOUTH PCT 1ST W - ROBERT    South            0
# 2                        NA       NA            0

# %%
X, y = f.Xy(WF_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Weapon Flag

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, baseline_nosmote.predict(X_train))
# Out:
# 0.8753370076110037

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train, 'LR w/o SMOTE ', 'Dropped Nulls, weapon flag')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE  has an average F1 of 0.8732586135599082
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# array([0.87061064, 0.87295718, 0.87602715, 0.87328645, 0.87341165])

# %%
modeling.history
# Out:
#                 Name  Accuracy (F1)                           Notes
# 8      LR w/o SMOTE        0.873259      Dropped Nulls, weapon flag
# 0      LR w/o SMOTE        0.873273      Dropped Nulls, weapon bins
# 1  LR Baseline SMOTE       0.874411                 Log Reg min/max
# 2           LR SMOTE       0.878441               LR, Dropped Nulls
# 3       LR w/o SMOTE       0.878747      Dropped Nulls, officer age
# 4        LR Baseline       0.881053                Log Reg, min/max
# 5      LR w/o SMOTE        0.885577  Dropped Nulls, gender affinity
# 6      LR w/o SMOTE        0.885613  Dropped Nulls, racial affinity
# 7       LR w/o SMOTE       0.887230               LR, Dropped Nulls

# %% [markdown]
# ## Subsplit Test

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
#    Train F1   Test F1
# 0  0.874761  0.875167

# %% [markdown]
# ## LR w/Weapon Flag Score: F1=0.875167

# %% [markdown]
# ## Binarizing Initial Call Type
# 0 = no call information provided.

# %%
df['Initial Call Bin'] = df['Initial Call Type'].copy()

# %%
df['Initial Call Bin'] = df['Initial Call Bin'].replace('NA', 0)
df['Initial Call Bin'] = df['Initial Call Bin'].map(lambda x: 1 if x!=0 else 0)

# %%
df['Initial Call Bin'].value_counts()
# Out:
# 1    31268
# 0    12392
# Name: Initial Call Bin, dtype: int64

# %% [markdown]
# ## New Data Frame

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins', 'Initial Call Type']

# %%
ICB_df = f.framer(df, [], excluded)

# %%
ICB_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None           Male        Black
# 2       0                NA        None           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Call Type  \
# 0                  Asian                     Male        NA
# 2                  White                     Male        NA
#
#               Officer Squad Precinct  Initial Call Bin
# 0  SOUTH PCT 1ST W - ROBERT    South                 0
# 2                        NA       NA                 0

# %%
X, y = f.Xy(ICB_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Initial Call Type Binary

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.2s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, baseline_nosmote.predict(X_train))
# Out:
# 0.8825751030584286

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train, 'LR w/o SMOTE ', 'Dropped Nulls, Initial Call Binary')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE  has an average F1 of 0.8805836214650842
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.7s finished
# array([0.87609204, 0.88340531, 0.88412757, 0.87868691, 0.88060629])

# %%
modeling.history
# Out:
#                 Name  Accuracy (F1)                               Notes
# 0      LR w/o SMOTE        0.873259          Dropped Nulls, weapon flag
# 1      LR w/o SMOTE        0.873273          Dropped Nulls, weapon bins
# 2  LR Baseline SMOTE       0.874411                     Log Reg min/max
# 3           LR SMOTE       0.878441                   LR, Dropped Nulls
# 4       LR w/o SMOTE       0.878747          Dropped Nulls, officer age
# 9      LR w/o SMOTE        0.880584  Dropped Nulls, Initial Call Binary
# 5        LR Baseline       0.881053                    Log Reg, min/max
# 6      LR w/o SMOTE        0.885577      Dropped Nulls, gender affinity
# 7      LR w/o SMOTE        0.885613      Dropped Nulls, racial affinity
# 8       LR w/o SMOTE       0.887230                   LR, Dropped Nulls

# %% [markdown]
# ## Subsplit Test

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
#    Train F1  Test F1
# 0  0.882708   0.8793

# %% [markdown]
# ## LR w/Initial Call Types Binary Score: F1=0.8793

# %% [markdown]
# ## Binning Call Types
# Binning into 911, OTHER, ONVIEW.

# %%
types = df['Call Type'].unique()

# %%
replace_list = [x for x in types if (x!='911') and (x!='ONVIEW')]

# %%
df['Call Type Bins'] = df['Call Type'].copy()

# %%
df['Call Type Bins'] = df['Call Type Bins'].replace(replace_list, 'OTHER')

# %%
df['Call Type Bins'].value_counts(normalize=True)
# Out:
# 911       0.452268
# OTHER     0.361361
# ONVIEW    0.186372
# Name: Call Type Bins, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43660 entries, 0 to 46959
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    43660 non-null  int64
#  1   Subject Age Group         43660 non-null  object
#  2   Weapon Type               43660 non-null  object
#  3   Officer ID                43660 non-null  object
#  4   Officer Gender            43660 non-null  object
#  5   Officer Race              43660 non-null  object
#  6   Subject Perceived Race    43660 non-null  object
#  7   Subject Perceived Gender  43660 non-null  object
#  8   Initial Call Type         43660 non-null  object
#  9   Final Call Type           43660 non-null  object
#  10  Call Type                 43660 non-null  object
#  11  Officer Squad             43660 non-null  object
#  12  Frisk Flag                43660 non-null  int64
#  13  Precinct                  43660 non-null  object
#  14  Weapon Flag               43660 non-null  int64
#  15  Reported Year             43660 non-null  int64
#  16  Reported Month            43660 non-null  int64
#  17  Day of Month              43660 non-null  int64
#  18  Day of Week               43660 non-null  int64
#  19  Reported Hour             43660 non-null  int64
#  20  Beat Flag                 43660 non-null  int64
#  21  Officer Age               43660 non-null  float64
#  22  Racial Affinity           43660 non-null  int64
#  23  Gender Affinity           43660 non-null  int64
#  24  Weapon Bins               43660 non-null  object
#  25  Initial Call Bin          43660 non-null  int64
#  26  Call Type Bins            43660 non-null  object
# dtypes: float64(1), int64(12), object(14)
# memory usage: 10.3+ MB

# %% [markdown]
# ## New Data Frame

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins', 
            'Initial Call Bin','Call Type']

# %%
BCT_df = f.framer(df, [], excluded)

# %%
BCT_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None           Male        Black
# 2       0                NA        None           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type  \
# 0                  Asian                     Male                NA
# 2                  White                     Male                NA
#
#               Officer Squad Precinct Call Type Bins
# 0  SOUTH PCT 1ST W - ROBERT    South          OTHER
# 2                        NA       NA          OTHER

# %%
X, y = f.Xy(BCT_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Call Type Bins

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train,baseline_nosmote.predict(X_train))
# Out:
# 0.8891371264025419

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train, 'LR w/o SMOTE ', 'Dropped Nulls, call type bins')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE  has an average F1 of 0.885498244229375
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.88042669, 0.8881145 , 0.8893554 , 0.88420531, 0.88538933])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)                               Notes
# 0       LR w/o SMOTE        0.873259          Dropped Nulls, weapon flag
# 1       LR w/o SMOTE        0.873273          Dropped Nulls, weapon bins
# 2   LR Baseline SMOTE       0.874411                     Log Reg min/max
# 3            LR SMOTE       0.878441                   LR, Dropped Nulls
# 4        LR w/o SMOTE       0.878747          Dropped Nulls, officer age
# 5       LR w/o SMOTE        0.880584  Dropped Nulls, Initial Call Binary
# 6         LR Baseline       0.881053                    Log Reg, min/max
# 10      LR w/o SMOTE        0.885498       Dropped Nulls, call type bins
# 7       LR w/o SMOTE        0.885577      Dropped Nulls, gender affinity
# 8       LR w/o SMOTE        0.885613      Dropped Nulls, racial affinity
# 9        LR w/o SMOTE       0.887230                   LR, Dropped Nulls

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
#    Train F1   Test F1
# 0   0.89049  0.884391

# %% [markdown]
# ## LR w/Call Type Bins Score: F1=0.884391

# %% [markdown]
# ## Binning the Squad Data
# The squads look like they can be binned into precinct goups, a training group and an group of smaller precincts.

# %%
df['Officer Squad Bins'] = df['Officer Squad'].copy()

# %%
df['Officer Squad Bins'] = df['Officer Squad Bins'].map(lambda x: x[0])

# %%
df['Officer Squad Bins'].value_counts(normalize=True)
# Out:
# W    0.277119
# N    0.253275
# S    0.210009
# E    0.136395
# T    0.110330
# C    0.009345
# G    0.001306
# H    0.000710
# M    0.000412
# J    0.000206
# B    0.000206
# D    0.000183
# A    0.000183
# R    0.000160
# P    0.000115
# V    0.000023
# Z    0.000023
# Name: Officer Squad Bins, dtype: float64

# %%
proportions = df['Officer Squad Bins'].value_counts(normalize=True)
cutoff_idx = proportions.loc[proportions < .02].index
for i in cutoff_idx:
    df['Officer Squad Bins'].replace(i, 'OTHER', inplace=True)

# %%
df['Officer Squad Bins'].value_counts()
# Out:
# W        12099
# N        11058
# S         9169
# E         5955
# T         4817
# OTHER      562
# Name: Officer Squad Bins, dtype: int64

# %% [markdown]
# ## New Data Frame

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins', 
            'Initial Call Bin','Call Type Bins', 'Officer Squad']

# %%
BSQ_df = f.framer(df, [], excluded)

# %%
BSQ_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 0       1                NA        None           Male        Black
# 2       0                NA        None           Male        White
#
#   Subject Perceived Race Subject Perceived Gender Initial Call Type Call Type  \
# 0                  Asian                     Male                NA        NA
# 2                  White                     Male                NA        NA
#
#   Precinct Officer Squad Bins
# 0    South                  S
# 2       NA                  N

# %%
X, y = f.Xy(BSQ_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Precinct Bins

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, baseline_nosmote.predict(X_train))
# Out:
# 0.8864583333333332

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train, 'LR w/o SMOTE', 'Dropped Nulls, Squad Bins')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE has an average F1 of 0.8847169493409648
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# array([0.88042669, 0.88551518, 0.88735519, 0.8851728 , 0.88511489])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)                               Notes
# 0       LR w/o SMOTE        0.873259          Dropped Nulls, weapon flag
# 1       LR w/o SMOTE        0.873273          Dropped Nulls, weapon bins
# 2   LR Baseline SMOTE       0.874411                     Log Reg min/max
# 3            LR SMOTE       0.878441                   LR, Dropped Nulls
# 4        LR w/o SMOTE       0.878747          Dropped Nulls, officer age
# 5       LR w/o SMOTE        0.880584  Dropped Nulls, Initial Call Binary
# 6         LR Baseline       0.881053                    Log Reg, min/max
# 11       LR w/o SMOTE       0.884717           Dropped Nulls, Squad Bins
# 7       LR w/o SMOTE        0.885498       Dropped Nulls, call type bins
# 8       LR w/o SMOTE        0.885577      Dropped Nulls, gender affinity
# 9       LR w/o SMOTE        0.885613      Dropped Nulls, racial affinity
# 10       LR w/o SMOTE       0.887230                   LR, Dropped Nulls

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
#    Train F1   Test F1
# 0  0.887071  0.883155

# %% [markdown]
# ## LR w/Precinct Bins Score: F1=0.883155

# %% [markdown]
# ## Binarizing Officer Race
# Binarizing into White and Non-White.

# %%
df['Officer Race Bins'] = df['Officer Race'].copy()

# %%
df['Officer Race Bins'].replace('White', 1, inplace=True)

# %%
df['Officer Race Bins'] = df['Officer Race Bins'].apply(lambda x: 0 if x!=1 else 1)

# %%
df['Officer Race Bins'].value_counts()
# Out:
# 1    34103
# 0     9557
# Name: Officer Race Bins, dtype: int64

# %%
df['Officer Race Bins'].value_counts(normalize=True)
# Out:
# 1    0.781104
# 0    0.218896
# Name: Officer Race Bins, dtype: float64

# %% [markdown]
# ## New Data Frame

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Racial Affinity', 'Gender Affinity', 'Weapon Bins', 
            'Initial Call Bin','Call Type Bins', 'Officer Squad Bins',
            'Officer Race']

# %%
ORB_df = f.framer(df, [], excluded)

# %%
ORB_df.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Subject Perceived Race  \
# 0       1                NA        None           Male                  Asian
# 2       0                NA        None           Male                  White
#
#   Subject Perceived Gender Initial Call Type Call Type  \
# 0                     Male                NA        NA
# 2                     Male                NA        NA
#
#               Officer Squad Precinct  Officer Race Bins
# 0  SOUTH PCT 1ST W - ROBERT    South                  0
# 2                        NA       NA                  1

# %%
X, y = f.Xy(ORB_df)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Officer Race Binary

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.2s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, baseline_nosmote.predict(X_train))
# Out:
# 0.8893909675497182

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train, 'LR w/o SMOTE', 'Dropped Nulls, Officer Race Bins')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE has an average F1 of 0.8855252933136862
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
# array([0.88095238, 0.88797712, 0.88946523, 0.88444831, 0.88478342])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)                               Notes
# 0       LR w/o SMOTE        0.873259          Dropped Nulls, weapon flag
# 1       LR w/o SMOTE        0.873273          Dropped Nulls, weapon bins
# 2   LR Baseline SMOTE       0.874411                     Log Reg min/max
# 3            LR SMOTE       0.878441                   LR, Dropped Nulls
# 4        LR w/o SMOTE       0.878747          Dropped Nulls, officer age
# 5       LR w/o SMOTE        0.880584  Dropped Nulls, Initial Call Binary
# 6         LR Baseline       0.881053                    Log Reg, min/max
# 7        LR w/o SMOTE       0.884717           Dropped Nulls, Squad Bins
# 8       LR w/o SMOTE        0.885498       Dropped Nulls, call type bins
# 12       LR w/o SMOTE       0.885525    Dropped Nulls, Officer Race Bins
# 9       LR w/o SMOTE        0.885577      Dropped Nulls, gender affinity
# 10      LR w/o SMOTE        0.885613      Dropped Nulls, racial affinity
# 11       LR w/o SMOTE       0.887230                   LR, Dropped Nulls

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s finished
#    Train F1   Test F1
# 0   0.89046  0.885071

# %% [markdown]
# ## LR w/Officer Race Binary Score: F1=0.885071

# %% [markdown]
# ## Testing on Top Features w/o Time
# Test LR with features that perfomed better than the baseline features.

# %% [markdown]
# ## New Data Frame

# %%
# features engineered during eda
feature_list = ['Weapon Flag', 'Reported Year', 'Reported Month',
                'Day of Month', 'Day of Week', 'Reported Hour']

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Weapon Bins', 'Officer Race',
            'Initial Call Bin']

# %%
df_6 = f.framer(df, [], excluded)

# %%
df_6.head(2)
# Out:
#    Target Subject Age Group Weapon Type Officer Gender Subject Perceived Race  \
# 0       1                NA        None           Male                  Asian
# 2       0                NA        None           Male                  White
#
#   Subject Perceived Gender Initial Call Type Call Type  \
# 0                     Male                NA        NA
# 2                     Male                NA        NA
#
#               Officer Squad Precinct  Racial Affinity  Gender Affinity  \
# 0  SOUTH PCT 1ST W - ROBERT    South                0                1
# 2                        NA       NA                1                1
#
#   Call Type Bins Officer Squad Bins  Officer Race Bins
# 0          OTHER                  S                  0
# 2          OTHER                  N                  1

# %%
df_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43660 entries, 0 to 46959
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    43660 non-null  int64
#  1   Subject Age Group         43660 non-null  object
#  2   Weapon Type               43660 non-null  object
#  3   Officer Gender            43660 non-null  object
#  4   Subject Perceived Race    43660 non-null  object
#  5   Subject Perceived Gender  43660 non-null  object
#  6   Initial Call Type         43660 non-null  object
#  7   Call Type                 43660 non-null  object
#  8   Officer Squad             43660 non-null  object
#  9   Precinct                  43660 non-null  object
#  10  Racial Affinity           43660 non-null  int64
#  11  Gender Affinity           43660 non-null  int64
#  12  Call Type Bins            43660 non-null  object
#  13  Officer Squad Bins        43660 non-null  object
#  14  Officer Race Bins         43660 non-null  int64
# dtypes: int64(4), object(11)
# memory usage: 6.3+ MB

# %%
X, y = f.Xy(df_6)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.5s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, baseline_nosmote.predict(X_train))
# Out:
# 0.8893247269116186

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train,\
                'LR w/o SMOTE', 'Top Features w/o Time, Dropped Nulls')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE has an average F1 of 0.8854208674880357
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.1s finished
# array([0.88087269, 0.88808754, 0.88921823, 0.88422881, 0.88469706])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)                                 Notes
# 0       LR w/o SMOTE        0.873259            Dropped Nulls, weapon flag
# 1       LR w/o SMOTE        0.873273            Dropped Nulls, weapon bins
# 2   LR Baseline SMOTE       0.874411                       Log Reg min/max
# 3            LR SMOTE       0.878441                     LR, Dropped Nulls
# 4        LR w/o SMOTE       0.878747            Dropped Nulls, officer age
# 5       LR w/o SMOTE        0.880584    Dropped Nulls, Initial Call Binary
# 6         LR Baseline       0.881053                      Log Reg, min/max
# 7        LR w/o SMOTE       0.884717             Dropped Nulls, Squad Bins
# 13       LR w/o SMOTE       0.885421  Top Features w/o Time, Dropped Nulls
# 8       LR w/o SMOTE        0.885498         Dropped Nulls, call type bins
# 9        LR w/o SMOTE       0.885525      Dropped Nulls, Officer Race Bins
# 10      LR w/o SMOTE        0.885577        Dropped Nulls, gender affinity
# 11      LR w/o SMOTE        0.885613        Dropped Nulls, racial affinity
# 12       LR w/o SMOTE       0.887230                     LR, Dropped Nulls

# %% [markdown]
# ## Testing on Sub-Splits

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
#    Train F1   Test F1
# 0  0.890556  0.884919

# %% [markdown]
# ## LR Top Features w/o Time Score: F1=0.884919

# %% [markdown]
# ## Testing on All Features w/o Time

# %% [markdown]
# ## New Data Frame

# %%
# Dropping Subject Age Nulls
df = df[(df['Subject Perceived Race']!='NA') &\
            (df['Officer Race']!='NA') &\
           (df['Subject Age Group']!='NA')]

# %%
# features engineered during eda
feature_list = ['Weapon Flag', 'Reported Year', 'Reported Month',
                'Day of Month', 'Day of Week', 'Reported Hour']

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag',
           'Reported Year', 'Reported Month', 'Day of Month', 'Day of Week', 'Reported Hour']

# %%
df_7 = f.framer(df, [], excluded)

# %%
df_7.head(2)
# Out:
#      Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 214       0            1 - 17        None           Male        White
# 328       0           36 - 45        None           Male        White
#
#     Subject Perceived Race Subject Perceived Gender Initial Call Type  \
# 214                  White                     Male                NA
# 328                  Asian                     Male                NA
#
#     Call Type Officer Squad Precinct  Beat Flag  Officer Age  Racial Affinity  \
# 214        NA            NA       NA          0         27.0                1
# 328        NA            NA       NA          0         37.0                0
#
#      Gender Affinity Weapon Bins  Initial Call Bin Call Type Bins  \
# 214                1        NONE                 0          OTHER
# 328                1        NONE                 0          OTHER
#
#     Officer Squad Bins  Officer Race Bins
# 214                  N                  1
# 328                  N                  1

# %%
df_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42589 entries, 214 to 46959
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    42589 non-null  int64
#  1   Subject Age Group         42589 non-null  object
#  2   Weapon Type               42589 non-null  object
#  3   Officer Gender            42589 non-null  object
#  4   Officer Race              42589 non-null  object
#  5   Subject Perceived Race    42589 non-null  object
#  6   Subject Perceived Gender  42589 non-null  object
#  7   Initial Call Type         42589 non-null  object
#  8   Call Type                 42589 non-null  object
#  9   Officer Squad             42589 non-null  object
#  10  Precinct                  42589 non-null  object
#  11  Beat Flag                 42589 non-null  int64
#  12  Officer Age               42589 non-null  float64
#  13  Racial Affinity           42589 non-null  int64
#  14  Gender Affinity           42589 non-null  int64
#  15  Weapon Bins               42589 non-null  object
#  16  Initial Call Bin          42589 non-null  int64
#  17  Call Type Bins            42589 non-null  object
#  18  Officer Squad Bins        42589 non-null  object
#  19  Officer Race Bins         42589 non-null  int64
# dtypes: float64(1), int64(6), object(13)
# memory usage: 6.8+ MB

# %%
X, y = f.Xy(df_7)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing LR All Features w/o Time

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.6s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train,baseline_nosmote.predict(X_train))
# Out:
# 0.8908076447272084

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train,'LR w/o SMOTE', 'All Features w/o Time, Dropped Nulls')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE has an average F1 of 0.887738641013511
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.2s finished
# array([0.89257862, 0.88841039, 0.88726171, 0.88380282, 0.88663968])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)                                 Notes
# 0       LR w/o SMOTE        0.873259            Dropped Nulls, weapon flag
# 1       LR w/o SMOTE        0.873273            Dropped Nulls, weapon bins
# 2   LR Baseline SMOTE       0.874411                       Log Reg min/max
# 3            LR SMOTE       0.878441                     LR, Dropped Nulls
# 4        LR w/o SMOTE       0.878747            Dropped Nulls, officer age
# 5       LR w/o SMOTE        0.880584    Dropped Nulls, Initial Call Binary
# 6         LR Baseline       0.881053                      Log Reg, min/max
# 7        LR w/o SMOTE       0.884717             Dropped Nulls, Squad Bins
# 8        LR w/o SMOTE       0.885421  Top Features w/o Time, Dropped Nulls
# 9       LR w/o SMOTE        0.885498         Dropped Nulls, call type bins
# 10       LR w/o SMOTE       0.885525      Dropped Nulls, Officer Race Bins
# 11      LR w/o SMOTE        0.885577        Dropped Nulls, gender affinity
# 12      LR w/o SMOTE        0.885613        Dropped Nulls, racial affinity
# 13       LR w/o SMOTE       0.887230                     LR, Dropped Nulls
# 14       LR w/o SMOTE       0.887739  All Features w/o Time, Dropped Nulls

# %% [markdown]
# ## Testing on Sub-Splits

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.4s finished
#    Train F1  Test F1
# 0  0.891402   0.8881

# %% [markdown]
# ## LR All Features w/o Time Score: F1=0.8881

# %% [markdown]
# ## Testing Top Features w/o Time Dropped Subject Age

# %% [markdown]
# ## New Data Frame

# %%
# Dropping Subject Age Nulls
df = df[(df['Subject Perceived Race']!='NA') &\
            (df['Officer Race']!='NA') &\
           (df['Subject Age Group']!='NA')]

# %%
# features engineered during eda
feature_list = ['Weapon Flag', 'Reported Year', 'Reported Month',
                'Day of Month', 'Day of Week', 'Reported Hour']

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag', 
             'Reported Year', 'Reported Month','Day of Month',
             'Day of Week', 'Reported Hour', 'Beat Flag', 'Officer Age',
            'Weapon Bins', 'Officer Race',
            'Initial Call Bin']

# %%
df_8 = f.framer(df, [], excluded)

# %%
df_8.head(2)
# Out:
#      Target Subject Age Group Weapon Type Officer Gender  \
# 214       0            1 - 17        None           Male
# 328       0           36 - 45        None           Male
#
#     Subject Perceived Race Subject Perceived Gender Initial Call Type  \
# 214                  White                     Male                NA
# 328                  Asian                     Male                NA
#
#     Call Type Officer Squad Precinct  Racial Affinity  Gender Affinity  \
# 214        NA            NA       NA                1                1
# 328        NA            NA       NA                0                1
#
#     Call Type Bins Officer Squad Bins  Officer Race Bins
# 214          OTHER                  N                  1
# 328          OTHER                  N                  1

# %%
df_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42589 entries, 214 to 46959
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    42589 non-null  int64
#  1   Subject Age Group         42589 non-null  object
#  2   Weapon Type               42589 non-null  object
#  3   Officer Gender            42589 non-null  object
#  4   Subject Perceived Race    42589 non-null  object
#  5   Subject Perceived Gender  42589 non-null  object
#  6   Initial Call Type         42589 non-null  object
#  7   Call Type                 42589 non-null  object
#  8   Officer Squad             42589 non-null  object
#  9   Precinct                  42589 non-null  object
#  10  Racial Affinity           42589 non-null  int64
#  11  Gender Affinity           42589 non-null  int64
#  12  Call Type Bins            42589 non-null  object
#  13  Officer Squad Bins        42589 non-null  object
#  14  Officer Race Bins         42589 non-null  int64
# dtypes: int64(4), object(11)
# memory usage: 5.2+ MB

# %%
X, y = f.Xy(df_8)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.4s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, baseline_nosmote.predict(X_train))
# Out:
# 0.890375343918015

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train,\
                'LR w/o SMOTE', 'Top Features w/o Time, Dpd Nulls Race, Age')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE has an average F1 of 0.8874350703172629
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# array([0.89280322, 0.88793213, 0.8875142 , 0.88355131, 0.88537449])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)  \
# 0       LR w/o SMOTE        0.873259
# 1       LR w/o SMOTE        0.873273
# 2   LR Baseline SMOTE       0.874411
# 3            LR SMOTE       0.878441
# 4        LR w/o SMOTE       0.878747
# 5       LR w/o SMOTE        0.880584
# 6         LR Baseline       0.881053
# 7        LR w/o SMOTE       0.884717
# 8        LR w/o SMOTE       0.885421
# 9       LR w/o SMOTE        0.885498
# 10       LR w/o SMOTE       0.885525
# 11      LR w/o SMOTE        0.885577
# 12      LR w/o SMOTE        0.885613
# 13       LR w/o SMOTE       0.887230
# 15       LR w/o SMOTE       0.887435
# 14       LR w/o SMOTE       0.887739
#
#                                          Notes
# 0                   Dropped Nulls, weapon flag
# 1                   Dropped Nulls, weapon bins
# 2                              Log Reg min/max
# 3                            LR, Dropped Nulls
# 4                   Dropped Nulls, officer age
# 5           Dropped Nulls, Initial Call Binary
# 6                             Log Reg, min/max
# 7                    Dropped Nulls, Squad Bins
# 8         Top Features w/o Time, Dropped Nulls
# 9                Dropped Nulls, call type bins
# 10            Dropped Nulls, Officer Race Bins
# 11              Dropped Nulls, gender affinity
# 12              Dropped Nulls, racial affinity
# 13                           LR, Dropped Nulls
# 15  Top Features w/o Time, Dpd Nulls Race, Age
# 14        All Features w/o Time, Dropped Nulls

# %% [markdown]
# ## Testing on Sub-Splits

# %%
f.subsplit_test(X_train, y_train, baseline_nosmote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.1s finished
#    Train F1   Test F1
# 0  0.890959  0.888438

# %% [markdown]
# ## LR Top Features Dropped Subject Age Score: F1=0.888438

# %% [markdown]
# ## Testing on All Features w/o Time Dropped Subject Age

# %% [markdown]
# ## Data Frame

# %%
# Dropping Subject Age Nulls
df = df[(df['Subject Perceived Race']!='NA') &\
            (df['Officer Race']!='NA') &\
           (df['Subject Age Group']!='NA')]

# %%
# features engineered during eda
feature_list = ['Weapon Flag', 'Reported Year', 'Reported Month',
                'Day of Month', 'Day of Week', 'Reported Hour']

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag',
           'Reported Year', 'Reported Month', 'Day of Month', 'Day of Week', 'Reported Hour']

# %%
df_9 = f.framer(df, [], excluded)

# %%
df_9.head(2)
# Out:
#      Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 214       0            1 - 17        None           Male        White
# 328       0           36 - 45        None           Male        White
#
#     Subject Perceived Race Subject Perceived Gender Initial Call Type  \
# 214                  White                     Male                NA
# 328                  Asian                     Male                NA
#
#     Call Type Officer Squad Precinct  Beat Flag  Officer Age  Racial Affinity  \
# 214        NA            NA       NA          0         27.0                1
# 328        NA            NA       NA          0         37.0                0
#
#      Gender Affinity Weapon Bins  Initial Call Bin Call Type Bins  \
# 214                1        NONE                 0          OTHER
# 328                1        NONE                 0          OTHER
#
#     Officer Squad Bins  Officer Race Bins
# 214                  N                  1
# 328                  N                  1

# %%
df_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42589 entries, 214 to 46959
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    42589 non-null  int64
#  1   Subject Age Group         42589 non-null  object
#  2   Weapon Type               42589 non-null  object
#  3   Officer Gender            42589 non-null  object
#  4   Officer Race              42589 non-null  object
#  5   Subject Perceived Race    42589 non-null  object
#  6   Subject Perceived Gender  42589 non-null  object
#  7   Initial Call Type         42589 non-null  object
#  8   Call Type                 42589 non-null  object
#  9   Officer Squad             42589 non-null  object
#  10  Precinct                  42589 non-null  object
#  11  Beat Flag                 42589 non-null  int64
#  12  Officer Age               42589 non-null  float64
#  13  Racial Affinity           42589 non-null  int64
#  14  Gender Affinity           42589 non-null  int64
#  15  Weapon Bins               42589 non-null  object
#  16  Initial Call Bin          42589 non-null  int64
#  17  Call Type Bins            42589 non-null  object
#  18  Officer Squad Bins        42589 non-null  object
#  19  Officer Race Bins         42589 non-null  int64
# dtypes: float64(1), int64(6), object(13)
# memory usage: 6.8+ MB

# %%
X, y = f.Xy(df_9)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing

# %%
baseline_nosmote.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.8s finished
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, n_jobs=-1, random_state=2021,
#                                     verbose=2))])

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, baseline_nosmote.predict(X_train))
# Out:
# 0.8908076447272084

# %%
# checking cross val scores
modeling.report(baseline_nosmote, X_train, y_train,\
                'LR w/o SMOTE', 'All Features w/o Time, Dpd Nulls Race, Age')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LR w/o SMOTE has an average F1 of 0.887738641013511
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.2s finished
# array([0.89257862, 0.88841039, 0.88726171, 0.88380282, 0.88663968])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)  \
# 0       LR w/o SMOTE        0.873259
# 1       LR w/o SMOTE        0.873273
# 2   LR Baseline SMOTE       0.874411
# 3            LR SMOTE       0.878441
# 4        LR w/o SMOTE       0.878747
# 5       LR w/o SMOTE        0.880584
# 6         LR Baseline       0.881053
# 7        LR w/o SMOTE       0.884717
# 8        LR w/o SMOTE       0.885421
# 9       LR w/o SMOTE        0.885498
# 10       LR w/o SMOTE       0.885525
# 11      LR w/o SMOTE        0.885577
# 12      LR w/o SMOTE        0.885613
# 13       LR w/o SMOTE       0.887230
# 14       LR w/o SMOTE       0.887435
# 15       LR w/o SMOTE       0.887739
# 16       LR w/o SMOTE       0.887739
#
#                                          Notes
# 0                   Dropped Nulls, weapon flag
# 1                   Dropped Nulls, weapon bins
# 2                              Log Reg min/max
# 3                            LR, Dropped Nulls
# 4                   Dropped Nulls, officer age
# 5           Dropped Nulls, Initial Call Binary
# 6                             Log Reg, min/max
# 7                    Dropped Nulls, Squad Bins
# 8         Top Features w/o Time, Dropped Nulls
# 9                Dropped Nulls, call type bins
# 10            Dropped Nulls, Officer Race Bins
# 11              Dropped Nulls, gender affinity
# 12              Dropped Nulls, racial affinity
# 13                           LR, Dropped Nulls
# 14  Top Features w/o Time, Dpd Nulls Race, Age
# 15        All Features w/o Time, Dropped Nulls
# 16  All Features w/o Time, Dpd Nulls Race, Age

# %% [markdown]
# ## Testing on Sub-Splits

# %%
f.subsplit_test(X_train, y_train, baseline_smote)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.6s finished
#    Train F1   Test F1
# 0  0.884459  0.876283

# %% [markdown]
# ## LR All Features Dropped Subject Age Nulls Score: F1=0.876283

# %% [markdown]
# ## Grid Searching Parameters

# %%
# C = np.logspace(-4, 2, 20)
# penalty = ['l1', 'l2']
# solver = ['liblinear', 'saga', 'lbfgs']


# grid_values = {'logisticregression__C':C, 
#                'logisticregression__penalty':penalty,
#                'logisticregression__solver':solver}

# grid_clf_f1 = GridSearchCV(baseline_nosmote, param_grid = grid_values,
#                            n_jobs=-1, scoring = 'f1', cv=3, verbose=4)
# grid_clf_f1.fit(X_train, y_train)

# %%
# print('Best C:', grid_clf_f1.best_estimator_.get_params()['logisticregression__C'])
# print('Best penalty:', grid_clf_f1.best_estimator_.get_params()['logisticregression__penalty'])
# print('Best solver:', grid_clf_f1.best_estimator_.get_params()['logisticregression__solver'])

# %% [markdown]
# ## Tuning LR Model

# %%
LR_tuned = LogisticRegression(C=1.2742749857031321,
                            solver='lbfgs', penalty='l2',
                            max_iter=1000, class_weight=None,
                              n_jobs=-1)

# %% [markdown]
# ## Scoring

# %%
pipeline  = make_pipeline(preprocessing_mm, LR_tuned)
pipeline.fit(X_train, y_train)
f1_score(pipeline.predict(X_train), y_train)
modeling.report(pipeline, X_train, y_train, 'LR Tuned', 'C=1.2742749857031321,\
solver=lbfgs, penalty=l2class_weight=None')
# Out:
# LR Tuned has an average F1 of 0.8878052434391641
# array([0.89285714, 0.88838211, 0.88762626, 0.88380282, 0.88635788])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)  \
# 0       LR w/o SMOTE        0.873259
# 1       LR w/o SMOTE        0.873273
# 2   LR Baseline SMOTE       0.874411
# 3            LR SMOTE       0.878441
# 4        LR w/o SMOTE       0.878747
# 5       LR w/o SMOTE        0.880584
# 6         LR Baseline       0.881053
# 7        LR w/o SMOTE       0.884717
# 8        LR w/o SMOTE       0.885421
# 9       LR w/o SMOTE        0.885498
# 10       LR w/o SMOTE       0.885525
# 11      LR w/o SMOTE        0.885577
# 12      LR w/o SMOTE        0.885613
# 13       LR w/o SMOTE       0.887230
# 14       LR w/o SMOTE       0.887435
# 15       LR w/o SMOTE       0.887739
# 16       LR w/o SMOTE       0.887739
# 17           LR Tuned       0.887805
#
#                                                 Notes
# 0                          Dropped Nulls, weapon flag
# 1                          Dropped Nulls, weapon bins
# 2                                     Log Reg min/max
# 3                                   LR, Dropped Nulls
# 4                          Dropped Nulls, officer age
# 5                  Dropped Nulls, Initial Call Binary
# 6                                    Log Reg, min/max
# 7                           Dropped Nulls, Squad Bins
# 8                Top Features w/o Time, Dropped Nulls
# 9                       Dropped Nulls, call type bins
# 10                   Dropped Nulls, Officer Race Bins
# 11                     Dropped Nulls, gender affinity
# 12                     Dropped Nulls, racial affinity
# 13                                  LR, Dropped Nulls
# 14         Top Features w/o Time, Dpd Nulls Race, Age
# 15               All Features w/o Time, Dropped Nulls
# 16         All Features w/o Time, Dpd Nulls Race, Age
# 17  C=1.2742749857031321,solver=lbfgs, penalty=l2c...

# %% [markdown]
# ## Testing Tuned Model on Sub-Splits

# %%
f.subsplit_test(X_train, y_train, pipeline)
# Out:
#    Train F1   Test F1
# 0   0.89132  0.888167

# %% [markdown]
# ## Tuned LR Model Score: F1=0.888167 (All Features, Dropped Nulls)

# %% [markdown]
# ## Random Forest Baseline

# %% [markdown]
# ## Pipeline

# %%
RF = RandomForestClassifier(n_jobs=-1, random_state=2021)

# %%
rf_pipeline = make_pipeline(preprocessing_mm, RF)

# %% [markdown]
# ## Scoring

# %%
modeling.report(rf_pipeline, X_train, y_train, 'RF Baseline', 'Random Forest w/o SMOTE')
# Out:
# RF Baseline has an average F1 of 0.8933431327379935
# array([0.89841589, 0.89230769, 0.89436796, 0.89089315, 0.89073097])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)  \
# 0       LR w/o SMOTE        0.873259
# 1       LR w/o SMOTE        0.873273
# 2   LR Baseline SMOTE       0.874411
# 3            LR SMOTE       0.878441
# 4        LR w/o SMOTE       0.878747
# 5       LR w/o SMOTE        0.880584
# 6         LR Baseline       0.881053
# 7        LR w/o SMOTE       0.884717
# 8        LR w/o SMOTE       0.885421
# 9       LR w/o SMOTE        0.885498
# 10       LR w/o SMOTE       0.885525
# 11      LR w/o SMOTE        0.885577
# 12      LR w/o SMOTE        0.885613
# 13       LR w/o SMOTE       0.887230
# 14       LR w/o SMOTE       0.887435
# 15       LR w/o SMOTE       0.887739
# 16       LR w/o SMOTE       0.887739
# 17           LR Tuned       0.887805
# 18        RF Baseline       0.893343
#
#                                                 Notes
# 0                          Dropped Nulls, weapon flag
# 1                          Dropped Nulls, weapon bins
# 2                                     Log Reg min/max
# 3                                   LR, Dropped Nulls
# 4                          Dropped Nulls, officer age
# 5                  Dropped Nulls, Initial Call Binary
# 6                                    Log Reg, min/max
# 7                           Dropped Nulls, Squad Bins
# 8                Top Features w/o Time, Dropped Nulls
# 9                       Dropped Nulls, call type bins
# 10                   Dropped Nulls, Officer Race Bins
# 11                     Dropped Nulls, gender affinity
# 12                     Dropped Nulls, racial affinity
# 13                                  LR, Dropped Nulls
# 14         Top Features w/o Time, Dpd Nulls Race, Age
# 15               All Features w/o Time, Dropped Nulls
# 16         All Features w/o Time, Dpd Nulls Race, Age
# 17  C=1.2742749857031321,solver=lbfgs, penalty=l2c...
# 18                            Random Forest w/o SMOTE

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train, rf_pipeline)
# Out:
#    Train F1   Test F1
# 0  0.997562  0.890634

# %% [markdown]
# ## RF Baseline Score: F1=0.890634

# %% [markdown]
# ## Random Forest w/ SMOTE

# %% [markdown]
# ## Pipeline

# %%
rf_sm_pipeline = make_sm_pipeline(preprocessing_mm, sm, RF)

# %% [markdown]
# ## Scoring

# %%
modeling.report(rf_sm_pipeline, X_train, y_train, 'RF SMOTE', 'Random Forest SMOTE')
# Out:
# RF SMOTE has an average F1 of 0.8916655086768314
# array([0.89781483, 0.8877331 , 0.89269953, 0.8897281 , 0.89035199])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)  \
# 0       LR w/o SMOTE        0.873259
# 1       LR w/o SMOTE        0.873273
# 2   LR Baseline SMOTE       0.874411
# 3            LR SMOTE       0.878441
# 4        LR w/o SMOTE       0.878747
# 5       LR w/o SMOTE        0.880584
# 6         LR Baseline       0.881053
# 7        LR w/o SMOTE       0.884717
# 8        LR w/o SMOTE       0.885421
# 9       LR w/o SMOTE        0.885498
# 10       LR w/o SMOTE       0.885525
# 11      LR w/o SMOTE        0.885577
# 12      LR w/o SMOTE        0.885613
# 13       LR w/o SMOTE       0.887230
# 14       LR w/o SMOTE       0.887435
# 15       LR w/o SMOTE       0.887739
# 16       LR w/o SMOTE       0.887739
# 17           LR Tuned       0.887805
# 19           RF SMOTE       0.891666
# 18        RF Baseline       0.893343
#
#                                                 Notes
# 0                          Dropped Nulls, weapon flag
# 1                          Dropped Nulls, weapon bins
# 2                                     Log Reg min/max
# 3                                   LR, Dropped Nulls
# 4                          Dropped Nulls, officer age
# 5                  Dropped Nulls, Initial Call Binary
# 6                                    Log Reg, min/max
# 7                           Dropped Nulls, Squad Bins
# 8                Top Features w/o Time, Dropped Nulls
# 9                       Dropped Nulls, call type bins
# 10                   Dropped Nulls, Officer Race Bins
# 11                     Dropped Nulls, gender affinity
# 12                     Dropped Nulls, racial affinity
# 13                                  LR, Dropped Nulls
# 14         Top Features w/o Time, Dpd Nulls Race, Age
# 15               All Features w/o Time, Dropped Nulls
# 16         All Features w/o Time, Dpd Nulls Race, Age
# 17  C=1.2742749857031321,solver=lbfgs, penalty=l2c...
# 19                                Random Forest SMOTE
# 18                            Random Forest w/o SMOTE

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train, rf_sm_pipeline)
# Out:
#    Train F1   Test F1
# 0  0.997596  0.889611

# %% [markdown]
# ## RF w/SMOTE Score: F1=0.889611

# %% [markdown]
# ## Tuning RF Baseline

# %% [markdown]
# ## GridSearch

# %%
# criterion =['gini', 'entropy']
# max_depth = [2, 10, None]
# min_samples_split = [2, 10]
# max_features = [None, 'auto']
# min_samples_leaf = [1, 3]

# grid_values = {
#                'randomforestclassifier__max_depth':max_depth,
#                'randomforestclassifier__criterion':criterion,
#                'randomforestclassifier__min_samples_split':min_samples_split,
#                'randomforestclassifier__max_features': max_features,
#                'randomforestclassifier__min_samples_leaf': min_samples_leaf}

# grid_rf_f1 = GridSearchCV(rf_pipeline, param_grid = grid_values, scoring = 'f1',
#                           n_jobs=-1, verbose=2, cv=3)
# grid_rf_f1.fit(X_train, y_train)

# %%
# f.feature_plot(preprocessing_mm, grid_rf_f1, X_train)

# %%
# grid_rf_f1.best_estimator_[0].transformers_[0][1].get_feature_names()

# %%
# print('Best criterion:', grid_rf_f1.best_estimator_.get_params()['randomforestclassifier__criterion'])
# print('Best max_depth:', grid_rf_f1.best_estimator_.get_params()['randomforestclassifier__max_depth'])
# print('Best min_samples_split:', grid_rf_f1.best_estimator_.get_params()['randomforestclassifier__min_samples_split'])
# print('Best min_samples_leaf:', grid_rf_f1.best_estimator_.get_params()['randomforestclassifier__min_samples_leaf'])
# print('Best max_features:', grid_rf_f1.best_estimator_.get_params()['randomforestclassifier__max_features'])

# %% [markdown]
# ## Tuned Random Forest

# %%
RF2 = RandomForestClassifier(criterion='entropy',
                            max_depth=None, min_samples_split=10,
                            class_weight=None,
                             min_samples_leaf=1, max_features='auto',
                             n_estimators=100,
                            n_jobs=-1, random_state=2021)

# %%
rf_pipeline = make_pipeline(preprocessing_mm, RF2)

# %%
rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6b20>),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc7d88c6bb0>)])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(criterion='entropy',
#                                         min_samples_split=10, n_jobs=-1,
#                                         random_state=2021))])

# %%
modeling.report(rf_pipeline, X_train, y_train, 'RF Tuned', 'criterion=entropy,\
                            max_depth=None, min_samples_split=10,\
                            class_weight=None,\
                            in_samples_leaf=1, max_features=auto,\
                            n_estimators=100,\
                            n_jobs=-1, random_state=2021')
# Out:
# RF Tuned has an average F1 of 0.896066695136874
# array([0.90325   , 0.89435383, 0.89344672, 0.89537773, 0.89390519])

# %%
modeling.history
# Out:
#                  Name  Accuracy (F1)  \
# 0       LR w/o SMOTE        0.873259
# 1       LR w/o SMOTE        0.873273
# 2   LR Baseline SMOTE       0.874411
# 3            LR SMOTE       0.878441
# 4        LR w/o SMOTE       0.878747
# 5       LR w/o SMOTE        0.880584
# 6         LR Baseline       0.881053
# 7        LR w/o SMOTE       0.884717
# 8        LR w/o SMOTE       0.885421
# 9       LR w/o SMOTE        0.885498
# 10       LR w/o SMOTE       0.885525
# 11      LR w/o SMOTE        0.885577
# 12      LR w/o SMOTE        0.885613
# 13       LR w/o SMOTE       0.887230
# 14       LR w/o SMOTE       0.887435
# 15       LR w/o SMOTE       0.887739
# 16       LR w/o SMOTE       0.887739
# 17           LR Tuned       0.887805
# 18           RF SMOTE       0.891666
# 19        RF Baseline       0.893343
# 20           RF Tuned       0.896067
#
#                                                 Notes
# 0                          Dropped Nulls, weapon flag
# 1                          Dropped Nulls, weapon bins
# 2                                     Log Reg min/max
# 3                                   LR, Dropped Nulls
# 4                          Dropped Nulls, officer age
# 5                  Dropped Nulls, Initial Call Binary
# 6                                    Log Reg, min/max
# 7                           Dropped Nulls, Squad Bins
# 8                Top Features w/o Time, Dropped Nulls
# 9                       Dropped Nulls, call type bins
# 10                   Dropped Nulls, Officer Race Bins
# 11                     Dropped Nulls, gender affinity
# 12                     Dropped Nulls, racial affinity
# 13                                  LR, Dropped Nulls
# 14         Top Features w/o Time, Dpd Nulls Race, Age
# 15               All Features w/o Time, Dropped Nulls
# 16         All Features w/o Time, Dpd Nulls Race, Age
# 17  C=1.2742749857031321,solver=lbfgs, penalty=l2c...
# 18                                Random Forest SMOTE
# 19                            Random Forest w/o SMOTE
# 20  criterion=entropy,                            ...

# %% [markdown]
# ## Testing on Subsplits

# %%
f.subsplit_test( X_train, y_train, rf_pipeline)
# Out:
#    Train F1   Test F1
# 0  0.950847  0.892731

# %% [markdown]
# ## RF Tuned Score: F1=0.892731

# %% [markdown]
# ## Re-Checking the Data

# %%
for col in df.columns:
    print(col, df[col].nunique())
# Out:
# Target 2
# Subject Age Group 6
# Weapon Type 22
# Officer ID 1153
# Officer Gender 2
# Officer Race 7
# Subject Perceived Race 9
# Subject Perceived Gender 6
# Initial Call Type 165
# Final Call Type 201
# Call Type 6
# Officer Squad 163
# Frisk Flag 2
# Precinct 6
# Weapon Flag 2
# Reported Year 7
# Reported Month 12
# Day of Month 31
# Day of Week 7
# Reported Hour 24
# Beat Flag 2
# Officer Age 50
# Racial Affinity 2
# Gender Affinity 2
# Weapon Bins 4
# Initial Call Bin 2
# Call Type Bins 3
# Officer Squad Bins 6
# Officer Race Bins 2

# %% [markdown]
# ## More Feature Engineering

# %% [markdown]
# ## New Data Frame

# %%
excluded = ['Officer ID','Final Call Type', 'Weapon Type', 'Officer Gender',
            'Officer Race', 'Frisk Flag', 'Weapon Flag', 'Officer Squad', 
            'Call Type', 'Officer Squad', 'Reported Year', 'Reported Month',
            'Day of Month', 'Day of Week', 'Reported Hour']

# %%
df_10 = f.framer(df, [], excluded)

# %%
df_10.head(2)
# Out:
#      Target Subject Age Group Subject Perceived Race Subject Perceived Gender  \
# 214       0            1 - 17                  White                     Male
# 328       0           36 - 45                  Asian                     Male
#
#     Initial Call Type Precinct  Beat Flag  Officer Age  Racial Affinity  \
# 214                NA       NA          0         27.0                1
# 328                NA       NA          0         37.0                0
#
#      Gender Affinity Weapon Bins  Initial Call Bin Call Type Bins  \
# 214                1        NONE                 0          OTHER
# 328                1        NONE                 0          OTHER
#
#     Officer Squad Bins  Officer Race Bins
# 214                  N                  1
# 328                  N                  1

# %%
X, y = f.Xy(df_10)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %%
# checking the small df
for col in df_10.columns:
    print(col, df_10[col].nunique())
# Out:
# Target 2
# Subject Age Group 6
# Subject Perceived Race 9
# Subject Perceived Gender 6
# Initial Call Type 165
# Precinct 6
# Beat Flag 2
# Officer Age 50
# Racial Affinity 2
# Gender Affinity 2
# Weapon Bins 4
# Initial Call Bin 2
# Call Type Bins 3
# Officer Squad Bins 6
# Officer Race Bins 2

# %% [markdown]
# ## Exploring Initial Call Type

# %%
df['Initial Call Re-Bin'] = df['Initial Call Type'].copy()

# %%
df['Initial Call Re-Bin'].value_counts(normalize=True)[0:50]
# Out:
# NA                                                  0.283407
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW          0.065815
# SUSPICIOUS PERSON, VEHICLE OR INCIDENT              0.063091
# DISTURBANCE, MISCELLANEOUS/OTHER                    0.051844
# ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)      0.042781
# TRESPASS                                            0.041090
# THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)           0.030313
# SHOPLIFT - THEFT                                    0.029256
# FIGHT - IP - PHYSICAL (NO WEAPONS)                  0.027049
# WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/DIST)      0.024396
# ROBBERY - IP/JO (INCLUDES STRONG ARM)               0.019207
# BURG - IP/JO - RES (INCL UNOCC STRUCTURES)          0.017047
# THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)       0.015544
# DIST - IP/JO - DV DIST - NO ASLT                    0.015098
# PROPERTY - DAMAGE                                   0.014675
# NARCOTICS - VIOLATIONS (LOITER, USE, SELL, NARS)    0.014276
# ASLT - IP/JO - DV                                   0.013712
# AUTO RECOVERY                                       0.013548
# TRAFFIC STOP - OFFICER INITIATED ONVIEW             0.013055
# ASLT - WITH OR W/O WEAPONS (NO SHOOTINGS)           0.011599
# BURG - IP/JO - COMM BURG (INCLUDES SCHOOLS)         0.010824
# WARRANT - FELONY PICKUP                             0.008829
# DIST - DV - NO ASLT                                 0.008007
# ASLT - IP/JO - PERSON SHOT OR SHOT AT               0.007373
# NUISANCE - MISCHIEF                                 0.007302
# UNKNOWN - COMPLAINT OF UNKNOWN NATURE               0.006128
# DOWN - CHECK FOR PERSON DOWN                        0.006034
# FIGHT - VERBAL/ORAL (NO WEAPONS)                    0.005987
# ALARM - COMM, SILENT/AUD BURG (INCL BANKS)          0.005447
# SHOTS - IP/JO - INCLUDES HEARD/NO ASSAULT           0.005353
# PROWLER - IP/JO                                     0.005166
# BURG - COMM BURGLARY (INCLUDES SCHOOLS)             0.004954
# BURG - RES (INCL UNOCC STRUCTURES ON PROP)          0.004673
# ROBBERY (INCLUDES STRONG ARM)                       0.004297
# WEAPN - GUN,DEADLY WPN (NO THRTS/ASLT/DIST)         0.004226
# FIGHT - IP/JO - WITH WEAPONS                        0.004086
# PERSON IN BEHAVIORAL/EMOTIONAL CRISIS               0.003921
# WARRANT - MISD WARRANT PICKUP                       0.003639
# LEWD -  (EXPOSING, FLASHING)                        0.003499
# PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY        0.003428
# SFD - ASSIST ON FIRE OR MEDIC RESPONSE              0.003311
# DUI - DRIVING UNDER INFLUENCE                       0.003311
# FIGHT - JO - PHYSICAL (NO WEAPONS)                  0.003264
# HAZ - POTENTIAL THRT TO PHYS SAFETY (NO HAZMAT)     0.003193
# MVC - HIT AND RUN (NON INJURY), INCLUDES IP/JO      0.003076
# ASLT - DV                                           0.002841
# MVC - WITH INJURIES (INCLUDES HIT AND RUN)          0.002606
# ARSON - IP/JO                                       0.002442
# FRAUD - FORGERY,BUNCO, SCAMS, ID THEFT, ETC         0.002418
# SUICIDE - IP/JO SUICIDAL PERSON AND ATTEMPTS        0.002325
# Name: Initial Call Re-Bin, dtype: float64

# %% [markdown]
# ## Re-Binning Initial Call Type
# Grouping similar call types into bins.

# %%
categories = df['Initial Call Re-Bin'].unique()

# %%
alarms = [x for x in categories if 'ALARM' in x]

# %%
assaults = [x for x in categories if 'ASLT -' in x ]

# %%
burglaries = [x for x in categories if 'BURG -' in x]

# %%
fights = [x for x in categories if 'FIGHT -' in x]

# %%
weapons = [x for x in categories if 'WEAPN' in x]

# %%
warrants = [x for x in categories if 'WARRANT -' in x]

# %%
narcos = [x for x in categories if 'NARCOTICS ' in x]

# %%
shots = [x for x in categories if 'SHOTS' in x]

# %%
autos = [x for x in categories if 'AUTO ' in x]

# %%
for type in alarms:
    df['Initial Call Re-Bin'].replace(type, 'ALARM BIN', inplace=True)
for type in assaults:
    df['Initial Call Re-Bin'].replace(type, 'ASLT BIN', inplace=True)
for type in burglaries:
    df['Initial Call Re-Bin'].replace(type, 'BURG BIN', inplace=True)
for type in fights:
    df['Initial Call Re-Bin'].replace(type, 'FIGHT BIN', inplace=True)
for type in weapons:
    df['Initial Call Re-Bin'].replace(type, 'WEAPN BIN', inplace=True)
for type in warrants:
    df['Initial Call Re-Bin'].replace(type, 'WARRANT BIN', inplace=True)
for type in narcos:
    df['Initial Call Re-Bin'].replace(type, 'NARCOTICS BIN', inplace=True)
for type in shots:
    df['Initial Call Re-Bin'].replace(type, 'SHOTS BIN', inplace=True)
for type in autos:
    df['Initial Call Re-Bin'].replace(type, 'AUTO BIN', inplace=True)

# %% [markdown]
# ## Checking Value Counts

# %%
df['Initial Call Re-Bin'].value_counts(normalize=True)[:50]
# Out:
# NA                                                  0.283407
# ASLT BIN                                            0.079410
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW          0.065815
# SUSPICIOUS PERSON, VEHICLE OR INCIDENT              0.063091
# DISTURBANCE, MISCELLANEOUS/OTHER                    0.051844
# TRESPASS                                            0.041090
# FIGHT BIN                                           0.040574
# BURG BIN                                            0.037498
# THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)           0.030313
# SHOPLIFT - THEFT                                    0.029256
# WEAPN BIN                                           0.028622
# ROBBERY - IP/JO (INCLUDES STRONG ARM)               0.019207
# AUTO BIN                                            0.016483
# THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)       0.015544
# DIST - IP/JO - DV DIST - NO ASLT                    0.015098
# NARCOTICS BIN                                       0.014699
# PROPERTY - DAMAGE                                   0.014675
# WARRANT BIN                                         0.013712
# TRAFFIC STOP - OFFICER INITIATED ONVIEW             0.013055
# DIST - DV - NO ASLT                                 0.008007
# NUISANCE - MISCHIEF                                 0.007302
# ALARM BIN                                           0.006481
# UNKNOWN - COMPLAINT OF UNKNOWN NATURE               0.006128
# DOWN - CHECK FOR PERSON DOWN                        0.006034
# SHOTS BIN                                           0.005706
# PROWLER - IP/JO                                     0.005166
# ROBBERY (INCLUDES STRONG ARM)                       0.004297
# PERSON IN BEHAVIORAL/EMOTIONAL CRISIS               0.003921
# LEWD -  (EXPOSING, FLASHING)                        0.003499
# PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY        0.003428
# DUI - DRIVING UNDER INFLUENCE                       0.003311
# SFD - ASSIST ON FIRE OR MEDIC RESPONSE              0.003311
# HAZ - POTENTIAL THRT TO PHYS SAFETY (NO HAZMAT)     0.003193
# MVC - HIT AND RUN (NON INJURY), INCLUDES IP/JO      0.003076
# MVC - WITH INJURIES (INCLUDES HIT AND RUN)          0.002606
# ARSON - IP/JO                                       0.002442
# FRAUD - FORGERY,BUNCO, SCAMS, ID THEFT, ETC         0.002418
# SUICIDE - IP/JO SUICIDAL PERSON AND ATTEMPTS        0.002325
# UNKNOWN - ANI/ALI - WRLS PHNS (INCL OPEN LINE)      0.002066
# FOLLOW UP                                           0.001972
# SEX IN PUBLIC PLACE/VIEW (INCL MASTURBATION)        0.001925
# ORDER - IP - VIOLATION OF DV COURT ORDER            0.001808
# ASSIST OTHER AGENCY - ROUTINE SERVICE               0.001808
# THEFT OF SERVICES                                   0.001714
# BURN - RECKLESS BURNING                             0.001620
# SERVICE - WELFARE CHECK                             0.001550
# UNDERCOVER OPS, CAUTION (INCLUDES STAKEOUTS)        0.001315
# LIQUOR VIOLATIONS - ADULT                           0.001221
# HARAS - NO BIAS, THREATS OR MALICIOUSNESS           0.001197
# MVC - REPORT, NON INJ/NON BLKG OR AFTER FACT INJ    0.001174
# Name: Initial Call Re-Bin, dtype: float64

# %% [markdown]
# ## Moving Smaller Categories into a Single `Other` Bin

# %%
proportions = df['Initial Call Re-Bin'].value_counts(normalize=True)
cutoff_idx = proportions.loc[proportions < .004].index
for i in cutoff_idx:
    df['Initial Call Re-Bin'].replace(i, 'OTHER', inplace=True)

# %% [markdown]
# ## Checking New Value Counts

# %%
df['Initial Call Re-Bin'].value_counts(normalize=True)
# Out:
# NA                                               0.283407
# ASLT BIN                                         0.079410
# OTHER                                            0.077485
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW       0.065815
# SUSPICIOUS PERSON, VEHICLE OR INCIDENT           0.063091
# DISTURBANCE, MISCELLANEOUS/OTHER                 0.051844
# TRESPASS                                         0.041090
# FIGHT BIN                                        0.040574
# BURG BIN                                         0.037498
# THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)        0.030313
# SHOPLIFT - THEFT                                 0.029256
# WEAPN BIN                                        0.028622
# ROBBERY - IP/JO (INCLUDES STRONG ARM)            0.019207
# AUTO BIN                                         0.016483
# THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)    0.015544
# DIST - IP/JO - DV DIST - NO ASLT                 0.015098
# NARCOTICS BIN                                    0.014699
# PROPERTY - DAMAGE                                0.014675
# WARRANT BIN                                      0.013712
# TRAFFIC STOP - OFFICER INITIATED ONVIEW          0.013055
# DIST - DV - NO ASLT                              0.008007
# NUISANCE - MISCHIEF                              0.007302
# ALARM BIN                                        0.006481
# UNKNOWN - COMPLAINT OF UNKNOWN NATURE            0.006128
# DOWN - CHECK FOR PERSON DOWN                     0.006034
# SHOTS BIN                                        0.005706
# PROWLER - IP/JO                                  0.005166
# ROBBERY (INCLUDES STRONG ARM)                    0.004297
# Name: Initial Call Re-Bin, dtype: float64

# %% [markdown]
# ## Binning Subject Race
# Binning into White, Black, and Other.

# %%
df['Subject Perceived Race'].unique()
# Out:
# array(['White', 'Asian', 'Unknown', 'Black', 'N_American', 'Multi-Racial',
#        'Hispanic', 'Other', 'P_Islander'], dtype=object)

# %%
df['Subject Perceived Race'].value_counts(normalize=True)
# Out:
# White           0.516237
# Black           0.309610
# Unknown         0.052290
# Hispanic        0.037592
# Asian           0.033952
# N_American      0.030149
# Multi-Racial    0.015614
# Other           0.003311
# P_Islander      0.001244
# Name: Subject Perceived Race, dtype: float64

# %%
df['Subject Perceived Race'].replace('White', 0, inplace=True)
df['Subject Perceived Race'].replace('Black', 1, inplace=True)

# %%
types = df['Subject Perceived Race'].unique()
replace_list = [x for x in types if (x!=0) and (x!=1)]
df['Subject Perceived Race'].replace(replace_list, 2, inplace=True)

# %%
df['Subject Perceived Race'].value_counts(normalize=True)
# Out:
# 0    0.516237
# 1    0.309610
# 2    0.174153
# Name: Subject Perceived Race, dtype: float64

# %% [markdown]
# ## Binning Subject Gender
# Binning into Male, Female, Other.

# %%
df['Subject Perceived Gender'].unique()
# Out:
# array(['Male', 'Female', 'Undetermined', 'NA', 'Unknown',
#        'Gender Diverse'], dtype=object)

# %%
df['Subject Perceived Gender'].value_counts(normalize=True)
# Out:
# Male              0.793820
# Female            0.203503
# Undetermined      0.002043
# Unknown           0.000258
# NA                0.000258
# Gender Diverse    0.000117
# Name: Subject Perceived Gender, dtype: float64

# %%
df['Subject Perceived Gender'].replace('Male', 0, inplace=True)
df['Subject Perceived Gender'].replace('Female', 1, inplace=True)

# %%
types = df['Subject Perceived Gender'].unique()
replace_list = [x for x in types if (x!=0) and (x!=1)]
df['Subject Perceived Gender'].replace(replace_list, 2, inplace=True)

# %%
df['Subject Perceived Gender'].value_counts(normalize=True)
# Out:
# 0    0.793820
# 1    0.203503
# 2    0.002677
# Name: Subject Perceived Gender, dtype: float64

# %% [markdown]
# ## DF With Re-engineered Data

# %%
excluded = ['Officer ID','Final Call Type', 'Frisk Flag','Weapon Flag',
           'Reported Year', 'Reported Month', 'Day of Month', 'Day of Week', 'Reported Hour']

# %%
df_11 = f.framer(df, [], excluded)

# %%
df_11.head(2)
# Out:
#      Target Subject Age Group Weapon Type Officer Gender Officer Race  \
# 214       0            1 - 17        None           Male        White
# 328       0           36 - 45        None           Male        White
#
#      Subject Perceived Race  Subject Perceived Gender Initial Call Type  \
# 214                       0                         0                NA
# 328                       2                         0                NA
#
#     Call Type Officer Squad  ... Beat Flag  Officer Age  Racial Affinity  \
# 214        NA            NA  ...         0         27.0                1
# 328        NA            NA  ...         0         37.0                0
#
#      Gender Affinity  Weapon Bins Initial Call Bin  Call Type Bins  \
# 214                1         NONE                0           OTHER
# 328                1         NONE                0           OTHER
#
#     Officer Squad Bins Officer Race Bins  Initial Call Re-Bin
# 214                  N                 1                   NA
# 328                  N                 1                   NA
#
# [2 rows x 21 columns]

# %%
df_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42589 entries, 214 to 46959
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    42589 non-null  int64
#  1   Subject Age Group         42589 non-null  object
#  2   Weapon Type               42589 non-null  object
#  3   Officer Gender            42589 non-null  object
#  4   Officer Race              42589 non-null  object
#  5   Subject Perceived Race    42589 non-null  int64
#  6   Subject Perceived Gender  42589 non-null  int64
#  7   Initial Call Type         42589 non-null  object
#  8   Call Type                 42589 non-null  object
#  9   Officer Squad             42589 non-null  object
#  10  Precinct                  42589 non-null  object
#  11  Beat Flag                 42589 non-null  int64
#  12  Officer Age               42589 non-null  float64
#  13  Racial Affinity           42589 non-null  int64
#  14  Gender Affinity           42589 non-null  int64
#  15  Weapon Bins               42589 non-null  object
#  16  Initial Call Bin          42589 non-null  int64
#  17  Call Type Bins            42589 non-null  object
#  18  Officer Squad Bins        42589 non-null  object
#  19  Officer Race Bins         42589 non-null  int64
#  20  Initial Call Re-Bin       42589 non-null  object
# dtypes: float64(1), int64(8), object(12)
# memory usage: 7.1+ MB

# %%
path2 = os.path.join(gparent, 'data/processed', 'final_modeling_data.csv')
df_11.to_csv(path2, index=False, na_rep='NA')

# %%
X, y = f.Xy(df_11)

# %%
X_train, X_test, y_train, y_test = f.splitter(X,y)

# %% [markdown]
# ## Testing Tuned RF on New Data

# %%
rf_pipeline.fit(X_train, y_train)

# %% [markdown]
# ## Scoring

# %%
modeling.report(rf_pipeline, X_train, y_train, 'RF Tuned New Data', 'criterion=entropy,\
                            max_depth=None, min_samples_split=10,\
                            class_weight=None,\
                            in_samples_leaf=1, max_features=auto,\
                            n_estimators=100,\
                            n_jobs=-1, random_state=2021')

# %%
modeling.history

# %% [markdown]
# ## Testing on Subsplits

# %%
f.subsplit_test( X_train, y_train, rf_pipeline)

# %% [markdown]
# ## Tuned RF on New Data Score: F1=0.893339

# %% [markdown]
# ## Re-Tuning Models on New Data

# %% [markdown]
# ## LR All Data

# %%
LR_ALL = LogisticRegression(random_state=2021, n_jobs=-1)

# %%
pipeline = make_pipeline(preprocessing_mm, LR_ALL)
pipeline.fit(X_train, y_train)

# %%
f1_score(y_train, pipeline.predict(X_train))

# %% [markdown]
# ## GridSearch

# %%
# C = np.logspace(-4, 2, 20)
# penalty = ['l1', 'l2']
# solver = ['liblinear', 'saga', 'lbfgs']


# grid_values = {'logisticregression__C':C, 
#                'logisticregression__penalty':penalty,
#                'logisticregression__solver':solver}

# grid_clf_f1_all = GridSearchCV(pipeline, param_grid = grid_values,
#                            n_jobs=-1, scoring = 'f1', cv=3, verbose=4)
# grid_clf_f1_all.fit(X_train, y_train)

# %%
# print('Best C:', grid_clf_f1_all.best_estimator_.get_params()['logisticregression__C'])
# print('Best penalty:', grid_clf_f1_all.best_estimator_.get_params()['logisticregression__penalty'])
# print('Best solver:', grid_clf_f1_all.best_estimator_.get_params()['logisticregression__solver'])

# %%
LR_ALL_tuned = LogisticRegression(C=2.6366508987303554,
                            solver='lbfgs', penalty='l2',
                              class_weight=None,
                            max_iter=1000, n_jobs=-1)

pipeline  = make_pipeline(preprocessing_mm, LR_ALL_tuned)
pipeline.fit(X_train, y_train)
f1_score(pipeline.predict(X_train), y_train)
modeling.report(pipeline, X_train, y_train, 'LR_ALL Tuned',\
                'C=2.6366508987303554, penalty=l2,\
                solver=lbfgs, class_weight=None')

# %%
modeling.history

# %% [markdown]
# ## LR Coefficients & Odds

# %%
features = list(grid_clf_f1_all.best_estimator_[0].\
                transformers_[0][1].\
                get_feature_names())+\
                list(X_train.select_dtypes('number').columns)

# %%
coeff = grid_clf_f1_all.best_estimator_[1].coef_.flatten()

# %%
coefficients = pd.DataFrame(coeff, features, columns=['coef'])\
                            .sort_values(by='coef', ascending=False)

# %%
top20_pos_coef = coefficients.head(20)

# %%
top20_pos_coef.plot(kind='bar', figsize=(15,7), color=['skyblue'])
plt.title('Top 20 Positive Coefficients')                                                 
plt.xlabel('Feature Name')
plt.xticks(rotation=90)
plt.legend(title='Coefficient', labels=['Value'])
plt.show()

# %%
top20_neg_coef = coefficients.tail(20)

# %%
top20_neg_coef.plot(kind='bar', figsize=(15,7), color=['skyblue'])
plt.title('Top 20 Negative Coefficients')                                                 
plt.xlabel('Feature Name')
plt.xticks(rotation=90)
plt.legend(title='Coefficient', labels=['Value'])
plt.show()

# %%
odds = np.exp(coeff)
odds_df = pd.DataFrame(odds, 
             features, 
             columns=['odds'])\
            .sort_values(by='odds', ascending=False)

# %%
top20_pos_odds = odds_df.head(20).reset_index()

# %%
fig, ax = plt.subplots(figsize =(20, 8))
sns.barplot(x='index',y='odds', data=top20_pos_odds, palette='Blues_r', edgecolor='deepskyblue')
plt.title('Relative Odds For The Top 20 Positive Features')                                                 
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=90)
plt.legend(title='Odds That A Major Outcome Is More Likely', labels=['Multiple'])
# plt.savefig('LR_Positive',  bbox_inches ="tight",\
#             pad_inches = .25, transparent = False)
plt.show()

# %%
top20_neg_odds = odds_df.tail(20).reset_index()

# %%
top20_neg_odds['odds'] = 1/top20_neg_odds['odds']

# %%
fig, ax = plt.subplots(figsize =(20, 8))
sns.barplot(x='index',y='odds', data=top20_neg_odds, palette='Blues', edgecolor='deepskyblue')
plt.title('Relative Odds For Top 20 Negative Features')                                                 
plt.xlabel('')
plt.xticks(rotation=90)
plt.legend(title='Odds That A Minor Outcome Is More Likely', labels=['Multiple'])
# plt.savefig('LR_Negative',  bbox_inches ="tight",\
#             pad_inches = .25, transparent = False)
plt.show()

# %% [markdown]
# ## Testing Tuned Model on Sub-Splits

# %%
f.subsplit_test(X_train, y_train, pipeline)

# %% [markdown]
# ## Tuned LR on All Data Score: F1=0.886699

# %% [markdown]
# ## RF Tuned on All Data

# %%
RF5 = RandomForestClassifier(n_jobs=-1,
                            random_state=2021)

# %%
rf2_pipeline = make_pipeline(preprocessing_mm, RF5)
rf2_pipeline.fit(X_train, y_train)

# %% [markdown]
# ## Gridsearch

# %%
criterion =['gini', 'entropy']
max_depth = [2, 10, None]
min_samples_split = [2, 10]
max_features = [None, 'auto']
min_samples_leaf = [1, 3]

grid_values = {
               'randomforestclassifier__max_depth':max_depth,
               'randomforestclassifier__criterion':criterion,
               'randomforestclassifier__min_samples_split':min_samples_split,
               'randomforestclassifier__max_features': max_features,
               'randomforestclassifier__min_samples_leaf': min_samples_leaf}

grid_rf2_f1 = GridSearchCV(rf2_pipeline, param_grid = grid_values, scoring = 'f1',
                          n_jobs=-1, verbose=2, cv=3)
grid_rf2_f1.fit(X_train, y_train)

# %%
print('Best criterion:', grid_rf2_f1.best_estimator_.get_params()['randomforestclassifier__criterion'])
print('Best max_depth:', grid_rf2_f1.best_estimator_.get_params()['randomforestclassifier__max_depth'])
print('Best min_samples_split:', grid_rf2_f1.best_estimator_.get_params()['randomforestclassifier__min_samples_split'])
print('Best min_samples_leaf:', grid_rf2_f1.best_estimator_.get_params()['randomforestclassifier__min_samples_leaf'])
print('Best max_features:', grid_rf2_f1.best_estimator_.get_params()['randomforestclassifier__max_features'])

# %% [markdown]
# ## Tuning

# %%
RF_ALL = RandomForestClassifier(criterion='gini',
                             max_depth=None,
                             min_samples_split=10,
                                max_features='auto',
                                min_samples_leaf=1,
                                n_jobs=-1,
                                n_estimators=100,
                            random_state=2021)

# %%
rfall_pipeline = make_pipeline(preprocessing_mm, RF_ALL)
rfall_pipeline.fit(X_train, y_train)

# %% [markdown]
# ## Scoring

# %%
modeling.report(rfall_pipeline, X_train, y_train, 'RF_ALL Tuned', 'criterion=gini,\
                                                            max_depth=None,\
                                                            min_samples_split=10,\
                                                            class_weight=None,\
                                                            min_samples_leaf=1,\
                                                            max_features=auto,\
                                                            n_estimators=100')

# %%
modeling.history

# %% [markdown]
# ## Feature Importance

# %%
# f.feature_plot(preprocessing_mm, grid_rf2_f1, X_train)

# %%
# grid_rf2_f1.best_estimator_[0].transformers_[0][1].get_feature_names()

# %% [markdown]
# ## Testing on Subsplits

# %%
f.subsplit_test( X_train, y_train, rfall_pipeline)

# %% [markdown]
# ## Tuned RF on All Data Score: F1=0.895318

# %% [markdown]
# ## AdaBoost

# %% [markdown]
# ## Pipeline

# %%
ada = AdaBoostClassifier(random_state=2021)

ada_pipeline = make_pipeline(preprocessing_mm, ada)

# %%
ada_pipeline.fit(X_train, y_train)

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, ada_pipeline.predict(X_train))

# %%
# checking cross val scores
modeling.report(ada_pipeline, X_train, y_train,\
                'AdaBoost Baseline', 'All Data')

# %%
modeling.history

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train, ada_pipeline)

# %% [markdown]
# ## AdaBoost Baseline Score: F1=0.887071

# %% [markdown]
# ## AdaBoost with LR

# %% [markdown]
# ## Pipeline

# %%
ada = AdaBoostClassifier(base_estimator=LR_ALL, random_state=2021)

adaLR_pipeline = make_pipeline(preprocessing_mm, ada)

# %%
adaLR_pipeline.fit(X_train, y_train)

# %% [markdown]
# ## Scoring

# %%
#scoring the model
f1_score(y_train, adaLR_pipeline.predict(X_train))

# %%
# checking cross val scores
modeling.report(adaLR_pipeline, X_train, y_train,\
                'AdaBoostLR', 'All Data')

# %%
modeling.history

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train, adaLR_pipeline)

# %% [markdown]
# ## AdaBoost w/LR Score: F1=0.887036

# %% [markdown]
# ## AdaBoost LR Tuned

# %%
# adaLR_pipeline.get_params().keys()

# %% [markdown]
# ## GridSearch

# %%
# parameters = {
#               'adaboostclassifier__n_estimators':[10,50,100,250],
#               'adaboostclassifier__learning_rate':[.01,.1,.5, 1]}

# adaGCV = GridSearchCV(adaLR_pipeline, parameters,verbose=2,
#                    scoring='f1',n_jobs=-1, cv=3)
# adaGCV.fit(X_train,y_train)

# %%
# print('Best learning_rate:', adaGCV.best_estimator_.get_params()['adaboostclassifier__learning_rate'])
# print('Best n_estimators:', adaGCV.best_estimator_.get_params()['adaboostclassifier__n_estimators'])

# %% [markdown]
# ## Tuning

# %%
ada = AdaBoostClassifier(base_estimator=LR_ALL, learning_rate=1,
                         n_estimators=250, random_state=2021)

adaLR_ALL = make_pipeline(preprocessing_mm, ada)

# %%
adaLR_ALL.fit(X_train, y_train)

# %% [markdown]
# ## Scoring

# %%
# #scoring the model
f1_score(y_train, adaLR_ALL.predict(X_train))

# %%
# checking cross val scores
modeling.report(adaLR_ALL, X_train, y_train,\
                'AdaBoostLR_ALL', 'All Data')

# %%
modeling.history

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train, adaLR_ALL)

# %% [markdown]
# ## AdaBoost LR Tuned Score: F1=0.887758

# %% [markdown]
# ## Plotting a DT

# %%
X, y = f.Xy(df_11)

# %%
X.head(2)

# %%
X_train, X_test, y_train, y_test = f.splitter(X, y)

# %%
DT = DecisionTreeClassifier(max_depth=5, random_state=2021)

# %% [markdown]
# ## Pipeline

# %%
pipeline = make_pipeline(preprocessing_mm, DT)

# %%
pipeline.fit(X_train,y_train)

# %% [markdown]
# ## Scoring

# %%
f1_score(y_train, pipeline.predict(X_train))

# %%
modeling.report(pipeline, X_train, y_train, 'Baseline DT', 'All Data')

# %%
modeling.history

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train,pipeline)

# %% [markdown]
# ## DT Baseline Score: F1=0.890196

# %%
# plt.figure(figsize=(20,20))
# plot_tree(pipeline[1])
# plt.show()

# %% [markdown]
# ## XGBoost

# %% [markdown]
# ## PipeLine

# %%
xboostclf = xgb.XGBClassifier(use_label_encoder=False)

# %%
X, y = f.Xy(df_11)

# %%
X_train, X_test, y_train, y_test = f.splitter(X, y)

# %%
xpipeline = make_pipeline(preprocessing_mm, xboostclf)

# %%
xpipeline.fit(X_train, y_train)

# %%
xpipeline.fit(X_train, y_train)

# %% [markdown]
# ## Scoring

# %%
f1_score(y_train, xpipeline.predict(X_train))

# %%
modeling.report(xpipeline, X_train, y_train, 'XGBoost Baseline', 'All Data' )

# %%
modeling.history

# %% [markdown]
# ## Subsplits

# %%
f.subsplit_test(X_train, y_train,xpipeline)

# %% [markdown]
# ## XGBoost Baseline Score: F1=0.891262
