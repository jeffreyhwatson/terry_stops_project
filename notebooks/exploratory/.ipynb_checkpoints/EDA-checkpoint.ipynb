# %%
# %load_ext autoreload
# %autoreload 2

# %%
# setting project path
import os
import sys

gparent = os.path.join(os.pardir, os.pardir)
sys.path.append(gparent)

# imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE




import matplotlib.pyplot as plt
import seaborn as sns

# setting style
sns.set_theme('talk')
plt.style.use('fivethirtyeight')
sns.set_palette(palette='Blues_r')

# %% [markdown]
# ## Initial EDA and Light Data Cleaning

# %%
# creating path to data
path = os.path.join(gparent, 'data/raw', 'Terry_Stops.csv')
df = pd.read_csv(path)

# %%
# checking first few rows
df.head()
# Out:
#   Subject Age Group  Subject ID     GO / SC Num  Terry Stop ID  \
# 0                 -          -1  20140000120677          92317
# 1                 -          -1  20150000001463          28806
# 2                 -          -1  20150000001516          29599
# 3                 -          -1  20150000001670          32260
# 4                 -          -1  20150000001739          33155
#
#   Stop Resolution Weapon Type Officer ID  Officer YOB Officer Gender  \
# 0          Arrest        None     7500           1984              M
# 1   Field Contact        None     5670           1965              M
# 2   Field Contact        None     4844           1961              M
# 3   Field Contact        None     7539           1963              M
# 4   Field Contact        None     6973           1977              M
#
#                 Officer Race  ... Reported Time Initial Call Type  \
# 0  Black or African American  ...      11:32:00                 -
# 1                      White  ...      07:59:00                 -
# 2                      White  ...      19:12:00                 -
# 3                      White  ...      04:55:00                 -
# 4                      White  ...      00:41:00                 -
#
#   Final Call Type Call Type             Officer Squad Arrest Flag Frisk Flag  \
# 0               -         -  SOUTH PCT 1ST W - ROBERT           N          N
# 1               -         -                       NaN           N          N
# 2               -         -                       NaN           N          -
# 3               -         -                       NaN           N          N
# 4               -         -                       NaN           N          N
#
#   Precinct  Sector    Beat
# 0    South  O       O2
# 1        -       -       -
# 2        -       -       -
# 3        -       -       -
# 4        -       -       -
#
# [5 rows x 23 columns]

# %%
#  checking info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47213 entries, 0 to 47212
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject Age Group         47213 non-null  object
#  1   Subject ID                47213 non-null  int64
#  2   GO / SC Num               47213 non-null  int64
#  3   Terry Stop ID             47213 non-null  int64
#  4   Stop Resolution           47213 non-null  object
#  5   Weapon Type               47213 non-null  object
#  6   Officer ID                47213 non-null  object
#  7   Officer YOB               47213 non-null  int64
#  8   Officer Gender            47213 non-null  object
#  9   Officer Race              47213 non-null  object
#  10  Subject Perceived Race    47213 non-null  object
#  11  Subject Perceived Gender  47213 non-null  object
#  12  Reported Date             47213 non-null  object
#  13  Reported Time             47213 non-null  object
#  14  Initial Call Type         47213 non-null  object
#  15  Final Call Type           47213 non-null  object
#  16  Call Type                 47213 non-null  object
#  17  Officer Squad             46609 non-null  object
#  18  Arrest Flag               47213 non-null  object
#  19  Frisk Flag                47213 non-null  object
#  20  Precinct                  47213 non-null  object
#  21  Sector                    47213 non-null  object
#  22  Beat                      47213 non-null  object
# dtypes: int64(4), object(19)
# memory usage: 8.3+ MB

# %%
# checking for nulls
df.isna().sum()
# Out:
# Subject Age Group             0
# Subject ID                    0
# GO / SC Num                   0
# Terry Stop ID                 0
# Stop Resolution               0
# Weapon Type                   0
# Officer ID                    0
# Officer YOB                   0
# Officer Gender                0
# Officer Race                  0
# Subject Perceived Race        0
# Subject Perceived Gender      0
# Reported Date                 0
# Reported Time                 0
# Initial Call Type             0
# Final Call Type               0
# Call Type                     0
# Officer Squad               604
# Arrest Flag                   0
# Frisk Flag                    0
# Precinct                      0
# Sector                        0
# Beat                          0
# dtype: int64

# %%
# filling nulls and replacing - values
df['Officer Squad'].fillna('NA', inplace=True)
df.replace('-', 'NA', inplace=True)

# %%
#  checking work
df.isna().sum()
# Out:
# Subject Age Group           0
# Subject ID                  0
# GO / SC Num                 0
# Terry Stop ID               0
# Stop Resolution             0
# Weapon Type                 0
# Officer ID                  0
# Officer YOB                 0
# Officer Gender              0
# Officer Race                0
# Subject Perceived Race      0
# Subject Perceived Gender    0
# Reported Date               0
# Reported Time               0
# Initial Call Type           0
# Final Call Type             0
# Call Type                   0
# Officer Squad               0
# Arrest Flag                 0
# Frisk Flag                  0
# Precinct                    0
# Sector                      0
# Beat                        0
# dtype: int64

# %%
#  checking uniques
df['Officer Race'].unique()
# Out:
# array(['Black or African American', 'White', 'Hispanic or Latino',
#        'Asian', 'American Indian/Alaska Native', 'Two or More Races',
#        'Not Specified', 'Nat Hawaiian/Oth Pac Islander', 'Unknown'],
#       dtype=object)

# %%
# renaming categories for brevity
officer_race_list = ['Black or African American', 'White', 'Hispanic or Latino',
       'Asian', 'American Indian/Alaska Native', 'Two or More Races',
       'Not Specified', 'Nat Hawaiian/Oth Pac Islander', 'Unknown']

officer_replace_list = race_list = ['Black', 'White', 'Hispanic',
       'Asian', 'N_American', 'Multi-Racial',
       'NA', 'P_Islander', 'Unknown']

df['Officer Race'] = df['Officer Race'].replace(officer_race_list, officer_replace_list)

# %%
# checking uniques
df['Subject Perceived Race'].unique()
# Out:
# array(['Asian', 'NA', 'White', 'Black or African American', 'Other',
#        'Unknown', 'American Indian or Alaska Native', 'Hispanic',
#        'Multi-Racial', 'Native Hawaiian or Other Pacific Islander'],
#       dtype=object)

# %%
# renaming categories for brevity
race_list = ['Asian', 'NA', 'White', 'Black or African American', 'Other',
       'Unknown', 'American Indian or Alaska Native', 'Hispanic',
       'Multi-Racial', 'Native Hawaiian or Other Pacific Islander']

replace_list =['Asian', 'NA', 'White', 'Black', 'Other',
       'Unknown', 'N_American', 'Hispanic',
       'Multi-Racial', 'P_Islander']

df['Subject Perceived Race'] = df['Subject Perceived Race'].replace(race_list, replace_list)

# %%
# checking uniques
df['Subject Perceived Gender'].unique()
# Out:
# array(['Male', 'NA', 'Female', 'Unable to Determine', 'Unknown',
#        'Gender Diverse (gender non-conforming and/or transgender)'],
#       dtype=object)

# %%
# renaming categories for brevity
gender_list = ['Male', 'NA', 'Female', 'Unable to Determine', 'Unknown',
       'Gender Diverse (gender non-conforming and/or transgender)']

gender_replace = ['Male', 'NA', 'Female', 'Undetermined', 'Unknown',
       'Gender Diverse']

df['Subject Perceived Gender'] = df['Subject Perceived Gender'].replace(gender_list, gender_replace)

# %%
# checking uniques
df['Officer Gender'].unique()
# Out:
# array(['M', 'F', 'N'], dtype=object)

# %%
# checking uniques
df['Officer ID'].unique()
# Out:
# array(['7500  ', '5670  ', '4844  ', ..., '6237  ', '6983  ', '5917  '],
#       dtype=object)

# %%
# stripping white spaces
df['Officer ID']= df['Officer ID'].apply(lambda x: x.strip())

# %% [markdown]
# ## Visualizing Stop Outcomes

# %%
# checking proportion of arrests by race
df[df['Stop Resolution'] == 'Arrest']['Subject Perceived Race'].value_counts(normalize=True)
# Out:
# White           0.472444
# Black           0.335305
# Unknown         0.050913
# Asian           0.037285
# Hispanic        0.034628
# N_American      0.033942
# NA              0.016885
# Multi-Racial    0.013885
# Other           0.003428
# P_Islander      0.001286
# Name: Subject Perceived Race, dtype: float64

# %%
# making a list of the racial categories for visualization
races = df['Subject Perceived Race'].unique()

# %%
# visualizing outcomes by race
AA_Stops = df.groupby('Subject Perceived Race')['Stop Resolution']\
           .value_counts(normalize=True)['Asian']
AI_Stops = df.groupby('Subject Perceived Race')['Stop Resolution']\
           .value_counts(normalize=True)['N_American']
BAA_Stops = df.groupby('Subject Perceived Race')['Stop Resolution']\
           .value_counts(normalize=True)['Black']
H_Stops = df.groupby('Subject Perceived Race')['Stop Resolution']\
           .value_counts(normalize=True)['Hispanic']
W_Stops = df.groupby('Subject Perceived Race')['Stop Resolution']\
           .value_counts(normalize=True)['White']

fig, axes=plt.subplots(figsize=(15,7))

AA_Stops.plot(label='Asian')
AI_Stops.plot(label='Native American')
BAA_Stops.plot(label='Black')
H_Stops.plot(label='Hispanic')
W_Stops.plot(label='White')
plt.title('Stop Outcome by Subject Race')
plt.xticks(rotation=80)
plt.legend()
plt.show()

# %%
#  getting age list
ages = df['Subject Age Group'].unique()

# %%
# checking outcomes by age category
fig, axes=plt.subplots(figsize=(15,7))

for age in ages:
    age_df = df.groupby('Subject Age Group')['Stop Resolution'].value_counts(normalize=True)[age]
    age_df.plot(label=f'{age}')
plt.title('Stop Outcome by Age Cohort')    
plt.xticks(rotation=80)
plt.legend()
plt.show()

# %%
# getting gender list
genders = df['Subject Perceived Gender'].unique()

# %%
# checking outcome by gender
fig, axes=plt.subplots(figsize=(15,7))

for g in genders:
    age_df = df.groupby('Subject Perceived Gender')['Stop Resolution'].value_counts(normalize=True)[g]
    age_df.plot(label=f'{g}')
plt.title('Stop Outcome by Gender')    
plt.xticks(rotation=80)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Some Data Cleaning

# %%
# creating and binarizing the target feature
df['Target'] = df['Stop Resolution']

df['Target'] = df['Target'].replace('Arrest', 1)
df['Target'] = df['Target'].map(lambda x: 0 if (x!=1) else 1)

# %%
# moving target to the front of the data frame
column_name = 'Target'
first_column = df.pop(column_name)
df.insert(0, column_name, first_column)

# %%
# checking columns
df.columns
# Out:
# Index(['Target', 'Subject Age Group', 'Subject ID', 'GO / SC Num',
#        'Terry Stop ID', 'Stop Resolution', 'Weapon Type', 'Officer ID',
#        'Officer YOB', 'Officer Gender', 'Officer Race',
#        'Subject Perceived Race', 'Subject Perceived Gender', 'Reported Date',
#        'Reported Time', 'Initial Call Type', 'Final Call Type', 'Call Type',
#        'Officer Squad', 'Arrest Flag', 'Frisk Flag', 'Precinct', 'Sector',
#        'Beat'],
#       dtype='object')

# %%
# dropping columns
df.drop(['Subject ID', 'Stop Resolution', 'GO / SC Num',
         'Terry Stop ID'], axis=1, inplace=True)

# %%
# getting new column list
column_list = df.columns
column_list
# Out:
# Index(['Target', 'Subject Age Group', 'Weapon Type', 'Officer ID',
#        'Officer YOB', 'Officer Gender', 'Officer Race',
#        'Subject Perceived Race', 'Subject Perceived Gender', 'Reported Date',
#        'Reported Time', 'Initial Call Type', 'Final Call Type', 'Call Type',
#        'Officer Squad', 'Arrest Flag', 'Frisk Flag', 'Precinct', 'Sector',
#        'Beat'],
#       dtype='object')

# %%
# creating list to check value counts
excluded = ['Officer YOB', 'Initial Call Type',
            'Final Call Type','Call Type', 'Officer Squad']
cols = [x for x in column_list if x not in excluded]

# %%
# printing value counts
for col in cols:
    print(f'{df[col].value_counts()}\n')
# Out:
# 0    35546
# 1    11667
# Name: Target, dtype: int64
#
# 26 - 35         15707
# 36 - 45         10017
# 18 - 25          9452
# 46 - 55          6111
# 56 and Above     2399
# 1 - 17           1978
# NA               1549
# Name: Subject Age Group, dtype: int64
#
# None                                    32565
# NA                                      11855
# Lethal Cutting Instrument                1482
# Knife/Cutting/Stabbing Instrument         633
# Handgun                                   291
# Firearm Other                             100
# Blunt Object/Striking Implement            86
# Club, Blackjack, Brass Knuckles            49
# Firearm                                    38
# Mace/Pepper Spray                          28
# Other Firearm                              23
# Firearm (unk type)                         15
# Taser/Stun Gun                             10
# Club                                        9
# None/Not Applicable                         7
# Rifle                                       7
# Fire/Incendiary Device                      6
# Shotgun                                     3
# Automatic Handgun                           2
# Personal Weapons (hands, feet, etc.)        2
# Blackjack                                   1
# Brass Knuckles                              1
# Name: Weapon Type, dtype: int64
#
# 7456    420
# 7634    344
# 7773    327
# 7765    315
# 7758    309
#        ...
# 8732      1
# 8543      1
# 8799      1
# 5699      1
# 5664      1
# Name: Officer ID, Length: 1214, dtype: int64
#
# M    41786
# F     5398
# N       29
# Name: Officer Gender, dtype: int64
#
# White           35651
# Hispanic         2742
# Multi-Racial     2652
# Asian            2029
# Black            1880
# NA               1453
# P_Islander        454
# N_American        317
# Unknown            35
# Name: Officer Race, dtype: int64
#
# White           23052
# Black           14046
# Unknown          2626
# NA               1893
# Hispanic         1684
# Asian            1536
# N_American       1359
# Multi-Racial      809
# Other             152
# P_Islander         56
# Name: Subject Perceived Race, dtype: int64
#
# Male              36993
# Female             9583
# Undetermined        326
# NA                  280
# Unknown              25
# Gender Diverse        6
# Name: Subject Perceived Gender, dtype: int64
#
# 2015-10-01T00:00:00    101
# 2015-09-29T00:00:00     66
# 2015-05-28T00:00:00     57
# 2015-07-18T00:00:00     55
# 2019-04-26T00:00:00     54
#                       ...
# 2015-05-13T00:00:00      1
# 2015-03-24T00:00:00      1
# 2015-05-10T00:00:00      1
# 2015-04-28T00:00:00      1
# 2015-03-31T00:00:00      1
# Name: Reported Date, Length: 2230, dtype: int64
#
# 17:00:00    51
# 19:18:00    51
# 02:56:00    51
# 03:13:00    50
# 03:09:00    50
#             ..
# 14:00:02     1
# 18:13:22     1
# 15:10:58     1
# 09:46:58     1
# 11:27:34     1
# Name: Reported Time, Length: 12955, dtype: int64
#
# N    43754
# Y     3459
# Name: Arrest Flag, dtype: int64
#
# N     36147
# Y     10588
# NA      478
# Name: Frisk Flag, dtype: int64
#
# West         11432
# North        10385
# NA            9859
# East          6213
# South         5653
# Southwest     2320
# SouthWest     1098
# Unknown        200
# OOJ             33
# FK ERROR        20
# Name: Precinct, dtype: int64
#
# NA        10065
# E          2337
# M          2270
# N          2191
# K          1762
# K          1725
# B          1658
# L          1639
# D          1512
# R          1455
# F          1378
# S          1348
# U          1302
# M          1254
# O          1161
# D          1144
# J          1119
# G          1087
# C          1037
# Q           967
# W           941
# E           925
# Q           794
# N           694
# F           669
# R           616
# O           598
# B           518
# S           476
# U           453
# G           442
# W           428
# L           416
# J           395
# C           384
# 99           53
# Name: Sector, dtype: int64
#
# NA        10004
# N3         1175
# E2         1092
# K3          964
# M2          852
#           ...
# N1           73
# 99           53
# 99           32
# OOJ          23
# S             2
# Name: Beat, Length: 107, dtype: int64

# %%
# creating weapons flag
df['Weapon Flag'] = df['Weapon Type']

df['Weapon Flag'] = df['Weapon Flag'].replace(['None', 'NA', 'None/Not Applicable'], [0,0,0])
df['Weapon Flag'] = df['Weapon Flag'].map(lambda x: 1 if x!=0 else 0)

# %%
# creating beat flag
df['Beat Flag'] = df['Beat']

df['Beat Flag'] = df['Beat Flag'].replace('NA', 1)
df['Beat Flag'] = df['Beat Flag'].map(lambda x: 0 if x!=1 else 1)

# %%
df['Frisk Flag'].value_counts()
# Out:
# N     36147
# Y     10588
# NA      478
# Name: Frisk Flag, dtype: int64

# %%
#  binarizing frisk flag
df['Frisk Flag'] = df['Frisk Flag'].replace('Y', 1)
df['Frisk Flag'] =df['Frisk Flag'].map(lambda x: 0 if x!=1 else 1)

# %%
df['Frisk Flag'].value_counts()
# Out:
# 0    36625
# 1    10588
# Name: Frisk Flag, dtype: int64

# %%
df['Arrest Flag'].value_counts()
# Out:
# N    43754
# Y     3459
# Name: Arrest Flag, dtype: int64

# %%
#  binarizing arrest flag
df['Arrest Flag'] = df['Arrest Flag'].replace('Y', 1)
df['Arrest Flag'] =df['Arrest Flag'].map(lambda x: 0 if x!=1 else 1)

# %%
# checking date and time columns
print(df['Reported Date'][:5])
df['Reported Time'][:5]
# Out:
# 0    2015-10-16T00:00:00
# 1    2015-03-19T00:00:00
# 2    2015-03-21T00:00:00
# 3    2015-04-01T00:00:00
# 4    2015-04-03T00:00:00
# Name: Reported Date, dtype: object
# 0    11:32:00
# 1    07:59:00
# 2    19:12:00
# 3    04:55:00
# 4    00:41:00
# Name: Reported Time, dtype: object

# %%
# converting date & time columns to datetime types
df = df.astype({'Reported Time':'datetime64', 'Reported Date':'datetime64'})

# %%
#  getting year, month, day of month, day of week, and hour features
df['Reported Year'] = df['Reported Date'].dt.year
df['Reported Month'] = df['Reported Date'].dt.month
df['Day of Month'] = df['Reported Date'].dt.day

# Monday = 0, Sunday = 6
df['Day of Week'] = df['Reported Date'].dt.weekday
df['Reported Hour'] = df['Reported Time'].dt.hour

# %%
# checking work
df.sort_values(by='Reported Year').head(2)
# Out:
#        Target Subject Age Group Weapon Type Officer ID  Officer YOB  \
# 0           1                NA        None       7500         1984
# 39233       0           46 - 55        None       7459         1973
#
#       Officer Gender Officer Race Subject Perceived Race  \
# 0                  M        Black                  Asian
# 39233              M        White                  White
#
#       Subject Perceived Gender Reported Date  ... Precinct  Sector    Beat  \
# 0                         Male    2015-10-16  ...    South  O       O2
# 39233                     Male    2015-06-28  ...    North  B       B1
#
#       Weapon Flag Beat Flag  Reported Year  Reported Month Day of Month  \
# 0               0         0           2015              10           16
# 39233           0         0           2015               6           28
#
#       Day of Week Reported Hour
# 0               4            11
# 39233           6             5
#
# [2 rows x 27 columns]

# %%
# dropping date and time columns
df.drop(['Reported Date', 'Reported Time'], axis=1, inplace=True)

# %%
# re-checking types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47213 entries, 0 to 47212
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Target                    47213 non-null  int64
#  1   Subject Age Group         47213 non-null  object
#  2   Weapon Type               47213 non-null  object
#  3   Officer ID                47213 non-null  object
#  4   Officer YOB               47213 non-null  int64
#  5   Officer Gender            47213 non-null  object
#  6   Officer Race              47213 non-null  object
#  7   Subject Perceived Race    47213 non-null  object
#  8   Subject Perceived Gender  47213 non-null  object
#  9   Initial Call Type         47213 non-null  object
#  10  Final Call Type           47213 non-null  object
#  11  Call Type                 47213 non-null  object
#  12  Officer Squad             47213 non-null  object
#  13  Arrest Flag               47213 non-null  int64
#  14  Frisk Flag                47213 non-null  int64
#  15  Precinct                  47213 non-null  object
#  16  Sector                    47213 non-null  object
#  17  Beat                      47213 non-null  object
#  18  Weapon Flag               47213 non-null  int64
#  19  Beat Flag                 47213 non-null  int64
#  20  Reported Year             47213 non-null  int64
#  21  Reported Month            47213 non-null  int64
#  22  Day of Month              47213 non-null  int64
#  23  Day of Week               47213 non-null  int64
#  24  Reported Hour             47213 non-null  int64
# dtypes: int64(11), object(14)
# memory usage: 9.0+ MB

# %%
# fixing Southwest precinct
df['Precinct'] = df['Precinct'].replace('SouthWest', 'Southwest')

# %%
# checking proprtion of indeterminate race category
unknown = df['Subject Perceived Race'].value_counts()[2]
na = df['Subject Perceived Race'].value_counts()[3]

(unknown + na)/df['Subject Perceived Race'].value_counts().sum()
# Out:
# 0.09571516319657722

# %%
# checking proportion of arrests to stops by race
arate = df.groupby('Subject Perceived Race')['Target']\
           .value_counts(normalize=True)
arrest_rate = pd.DataFrame(arate)
arrest_rate.columns = ['Rate']
arrest_rate
# Out:
#                                    Rate
# Subject Perceived Race Target
# Asian                  0       0.716797
#                        1       0.283203
# Black                  0       0.721487
#                        1       0.278513
# Hispanic               0       0.760095
#                        1       0.239905
# Multi-Racial           0       0.799753
#                        1       0.200247
# NA                     0       0.895932
#                        1       0.104068
# N_American             0       0.708609
#                        1       0.291391
# Other                  0       0.736842
#                        1       0.263158
# P_Islander             0       0.732143
#                        1       0.267857
# Unknown                0       0.773800
#                        1       0.226200
# White                  0       0.760888
#                        1       0.239112

# %% [markdown]
# ## Visualizing the Target

# %%
# getting normalized target value counts by race for visualization
target_race = df.groupby('Subject Perceived Race')['Target'].value_counts()

# visualizing target values by race
target_race.plot(kind='bar', figsize=(15,7), color=['skyblue', 'darkblue'])
plt.title('Outcomes by Subject Race')
plt.xlabel('Perceived Race')
plt.xticks(rotation=75)
plt.show()

# %%
# getting target value counts by race for visualization
target_race = df.groupby('Subject Perceived Race')\
                        ['Target'].value_counts(normalize=True)

# visualizing target values by race
target_race.plot(kind='bar', figsize=(15,7), color=['skyblue', 'darkblue'])
plt.title('Outcomes by Subject Race Normalized ')
plt.xlabel('Perceived Race')
plt.xticks(rotation=75)
plt.show()

# %%
#  getting target value counts by gender
target_gender = df.groupby('Subject Perceived Gender')['Target'].value_counts()

# visualizing target values by gender
target_gender.plot(kind='bar', figsize=(15,7), color=['skyblue', 'darkblue'])
plt.title('Outcomes by Subject Gender')                                                 
plt.xlabel('Perceived Gender')
plt.xticks(rotation=80)
plt.show()

# %%
# getting target value counts by precinct
precinct_target = df.groupby('Precinct')['Target'].value_counts()

precinct_target.plot(kind='bar', figsize=(15,7), color=['skyblue', 'darkblue'])
plt.title('Outcomes by Precinct')
plt.xlabel('Precinct')
plt.xticks(rotation=80)
plt.show()

# %%
# getting target value counts by officer race
officer_races = df.groupby('Officer Race')['Target'].value_counts()

officer_races.plot(kind='bar', figsize=(15,7), color=['skyblue', 'darkblue'])
plt.title('Outcomes by Officer Race')
plt.xlabel('Officer Race')
plt.xticks(rotation=80)
plt.show()

# %%
officer_races = df.groupby('Officer Race')['Target'].value_counts(normalize=True)

officer_races.plot(kind='bar', figsize=(15,7), color=['skyblue', 'darkblue'])

plt.title('Outcomes by Officer Race Normalized')
plt.xlabel('Officer Race')
plt.xticks(rotation=80)
plt.show()

# %%
officer_gender = df.groupby('Officer Gender')['Target'].value_counts()

officer_gender.plot(kind='bar', figsize=(15,7), color=['skyblue', 'darkblue'])
plt.title('Outcomes by Officer Gender')
plt.xticks(rotation=80)
plt.xlabel('Officer Gender')
plt.show()

# %%
officer_gender = df.groupby('Officer Gender')['Target'].value_counts(normalize=True)

officer_gender.plot(kind='bar', figsize=(15,7), color=['skyblue', 'darkblue'])
plt.title('Outcomes by Officer Gender Normalized')
plt.xticks(rotation=80)
plt.xlabel('Officer Gender')
plt.show()

# %%
weapons_race = df.groupby('Subject Perceived Race')['Weapon Flag'].value_counts(normalize=True)

weapons_race.plot(kind='bar', figsize=(15, 7), color=['skyblue', 'darkblue'])
plt.title('Weapon Flag by Race Normalized')
plt.xticks(rotation=80)
plt.xlabel('Subject Race')
plt.show()

# %%
# creating a weapons by race data frame
wdf = pd.DataFrame(df.groupby('Subject Perceived Race')['Weapon Flag'].value_counts())

# calculating the weapons found rate by race
hit_rates = []
for race in races:
    hits = wdf.loc[race]['Weapon Flag'][1]   #number of people in the racial group found with a weapon
    #total number in the racial group stopped
    total = df[df['Subject Perceived Race']\
               == race].value_counts().sum() 
    rate = hits/total
    hit_rates.append([race, rate])

#  calculating the meat weapons found rate
mean_hit_rate = np.array([hit_rates[i][1] for i in range(len(hit_rates))]).mean()

# creating a hit rate data frame and visualization
hr_df = pd.DataFrame(hit_rates, columns = ['Race', 'Hit Rate'])

Race = hr_df['Race']
Rate = hr_df['Hit Rate']

fig, ax = plt.subplots(figsize =(15, 7))
ax.barh(Race, Rate, color=['skyblue', 'darkblue'])
plt.title('Weapons Found Rate by Race')
plt.show()

# %%
print(f'Mean Weapon Found Rate: {mean_hit_rate}')
hit_rates
# Out:
# Mean Weapon Found Rate: 0.04954703397280077
# [['Asian', 0.057291666666666664],
#  ['NA', 0.04648705758055996],
#  ['White', 0.06476661461044594],
#  ['Black', 0.053182400683468606],
#  ['Other', 0.019736842105263157],
#  ['Unknown', 0.05978674790555979],
#  ['N_American', 0.051508462104488596],
#  ['Hispanic', 0.058788598574821854],
#  ['Multi-Racial', 0.048207663782447466],
#  ['P_Islander', 0.03571428571428571]]

# %%
# creating an arrest rate data frame and visualization
arrest_rates = df[df['Target']==1]['Subject Perceived Race'].value_counts(normalize=True)

adf = pd.DataFrame(arrest_rates)
adf.columns = ['Arrest Rate']

Race = adf.index
Rate = adf['Arrest Rate']

fig, ax = plt.subplots(figsize =(15, 7))
ax.barh(Race, Rate, color=['skyblue', 'darkblue'])
plt.title('Arrest Rate by Race')
plt.show()

# %%
mean_arrest_rate = adf['Arrest Rate'].mean()
print(f'Mean Arrest Rate: {mean_arrest_rate}')
arrest_rates
# Out:
# Mean Arrest Rate: 0.1
# White           0.472444
# Black           0.335305
# Unknown         0.050913
# Asian           0.037285
# Hispanic        0.034628
# N_American      0.033942
# NA              0.016885
# Multi-Racial    0.013885
# Other           0.003428
# P_Islander      0.001286
# Name: Subject Perceived Race, dtype: float64

# %% [markdown]
# ## Seattle Census Data
#
# **According to July 1, 2019 US Census Data**
#
# Asian 15.4%
#
# White Non-Hispanic 63.8%
#
# Black 7.3%
#
# Native American 0.5%
#
# Hispanic 6.7%
#
# Multi-Racial 6.9%
#
# Pacific Islander 0.3%
#
# Multi-Racial 6.9%

# %%
# visualizing beat data
bdf = df.groupby('Beat Flag')['Target'].value_counts(normalize=True)
bdf.plot(kind='bar', figsize=(15,7), color=['skyblue', 'darkblue'])
plt.title('Outcomes by Beat Flag')
plt.xlabel('Beat Flag')
plt.show()

# %%
# checking out arrests by officer id
arrests = df[df['Target']==1]
oid = arrests.groupby('Officer ID')['Target'].value_counts()
officer_df = pd.DataFrame(oid)
officer_df.columns = ['Arrests']
officer_df = officer_df.reset_index()
top20 = officer_df.drop('Target', axis=1).sort_values(by='Arrests', ascending=False)[:20]

# %%
# top 20 officers by arrest
top20
# Out:
#     Officer ID  Arrests
# 524       7758      144
# 419       7634      141
# 529       7765      113
# 463       7690      102
# 309       7456       92
# 450       7673       86
# 667       8405       83
# 553       7792       77
# 571       8302       77
# 536       7774       77
# 535       7773       75
# 527       7761       73
# 473       7700       67
# 397       7602       66
# 743       8487       65
# 483       7713       65
# 494       7724       65
# 441       7662       63
# 616       8352       63
# 574       8305       62
